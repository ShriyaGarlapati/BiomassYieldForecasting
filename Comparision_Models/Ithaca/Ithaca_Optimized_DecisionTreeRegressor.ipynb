# %%
############## imports
# general
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score  
# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVC  # support vector machines classification
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.neural_network import MLPClassifier # neural network for classification
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier # adaboost for classification
import xgboost as xgb
# saving models
# from sklearn.externals import joblib
import joblib
import matplotlib.pyplot as plt

# %%
import pandas as pd
import random
import math

# read in time point 1 for training
# train on it - model 1
# test on tp 2
# read tp 2
# add it to xgb - model 2
# test on tp 3
# read tp 3
# add it to xgb - model 3
# test on tp 4
# test model 1
data = pd.read_csv('data_no_2022_synthesized_nonstationary.csv')
data.head()
# Out:
#       yield      radiation         rain  avg_min_temp  avg_max_temp  class
# 0  0.766452   48010.950000   301.990000     12.436900     25.583800      0
# 1  0.768636  373381.000000  3837.770000      3.190400     14.261800      0
# 2  0.657273  328244.109091  3621.756667      4.053685     15.092736      0
# 3  0.912258  145586.280000  1621.280000      5.637700     16.831100      0
# 4  0.532857  159773.140000  1638.650000      5.033200     16.277100      0

# %%
print(len(data))
# Out:
# 20090

# %%
data = data.rename(columns={'Yield (tons/acre)':'yield'})

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
xDf = data[xColumnsToKeep]


yDf = data[yColumnsToKeep]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression, SelectPercentile
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression, SelectPercentile
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.tree import DecisionTreeRegressor  # Import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
import numpy as np

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 4 features

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', DecisionTreeRegressor())  # Use DecisionTreeRegressor here
])

# Define the SMAPE function for reusability
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space for DecisionTreeRegressor
    param = {
        'model__max_depth': trial.suggest_int('max_depth', 1, 20),
        'model__min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'model__min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
        'model__max_features': trial.suggest_categorical('max_features', ['sqrt']),
        'model__criterion': trial.suggest_categorical('criterion', ['absolute_error'])  # Use either MSE or MAE as criterion
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(
                    model__min_samples_split=param['model__min_samples_split'],
                    model__min_samples_leaf=param['model__min_samples_leaf'],
                    model__max_features=param['model__max_features'],
                    model__criterion=param['model__criterion'])

    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat.flatten(), y_pred.flatten())
    correlation = correlation_matrix[0, 1]
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: minimize MAE and SMAPE, maximize R² and correlation
    return mae  # Minimize MAE

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize')  # Minimize the objective
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(
                model__min_samples_split=best_params['min_samples_split'],
                model__min_samples_leaf=best_params['min_samples_leaf'],
                model__max_features=best_params['max_features'],
                model__criterion=best_params['criterion'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)

# Print evaluation metrics
mae = mean_absolute_error(y_test_flat, y_pred)
r2 = r2_score(y_test_flat, y_pred)
correlation_matrix = np.corrcoef(y_test_flat.flatten(), y_pred.flatten())
correlation = correlation_matrix[0, 1]
smape_value = smape(y_test_flat, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-20 18:36:10,499] A new study created in memory with name: no-name-3ced106b-1021-4bfe-892b-77d7ef5e8b26
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:36:17,439] Trial 0 finished with value: 0.23769398550863333 and parameters: {'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 0 with value: 0.23769398550863333.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:36:24,426] Trial 1 finished with value: 0.2362728982571657 and parameters: {'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 1 with value: 0.2362728982571657.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:36:32,019] Trial 2 finished with value: 0.23397436139070082 and parameters: {'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:36:38,226] Trial 3 finished with value: 0.2471061159349194 and parameters: {'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:36:44,944] Trial 4 finished with value: 0.2353236902301559 and parameters: {'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:36:51,440] Trial 5 finished with value: 0.26556158418803966 and parameters: {'max_depth': 1, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:36:57,588] Trial 6 finished with value: 0.25468365673989607 and parameters: {'max_depth': 1, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:37:03,642] Trial 7 finished with value: 0.24357312932498565 and parameters: {'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:37:11,149] Trial 8 finished with value: 0.23463101402678924 and parameters: {'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:37:18,150] Trial 9 finished with value: 0.23521743455663083 and parameters: {'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 2 with value: 0.23397436139070082.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:37
and parameters: {'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:42:45,411] Trial 60 finished with value: 0.23967465557126327 and parameters: {'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:42:52,153] Trial 61 finished with value: 0.24217310596789815 and parameters: {'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:42:58,395] Trial 62 finished with value: 0.23797150714570423 and parameters: {'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:03,827] Trial 63 finished with value: 0.23694922853696862 and parameters: {'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:09,054] Trial 64 finished with value: 0.2379918779242682 and parameters: {'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:15,618] Trial 65 finished with value: 0.23473802952408696 and parameters: {'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:21,778] Trial 66 finished with value: 0.23505834658594435 and parameters: {'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:28,526] Trial 67 finished with value: 0.23432370862396554 and parameters: {'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:35,838] Trial 68 finished with value: 0.24117023991483816 and parameters: {'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:43,002] Trial 69 finished with value: 0.23375448142111876 and parameters: {'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:49,489] Trial 70 finished with value: 0.2375705618610325 and parameters: {'max_depth': 12, 'min_samples_split': 20, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:43:56,682] Trial 71 finished with value: 0.23706902941013405 and parameters: {'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:03,406] Trial 72 finished with value: 0.23463958179837938 and parameters: {'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:09,429] Trial 73 finished with value: 0.23262869192150407 and parameters: {'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:15,383] Trial 74 finished with value: 0.23347869223185475 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:21,429] Trial 75 finished with value: 0.23584494403548975 and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:27,308] Trial 76 finished with value: 0.2988769514072529 and parameters: {'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:33,326] Trial 77 finished with value: 0.23770443535463662 and parameters: {'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:40,311] Trial 78 finished with value: 0.2348311989418053 and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:46,757] Trial 79 finished with value: 0.23455946120071164 and parameters: {'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:53,700] Trial 80 finished with value: 0.23179337040713488 and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:44:59,771] Trial 81 finished with value: 0.23434299286757101 and parameters: {'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:07,212] Trial 82 finished with value: 0.23584445653828962 and parameters: {'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 18 with value: 0.23149128697363677.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:13,886] Trial 83 finished with value: 0.23144686413677446 and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:20,640] Trial 84 finished with value: 0.23336141882060316 and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:28,093] Trial 85 finished with value: 0.23478232271019153 and parameters: {'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:33,832] Trial 86 finished with value: 0.25004460390822486 and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:39,098] Trial 87 finished with value: 0.23463181520215232 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:45,312] Trial 88 finished with value: 0.24039619611943824 and parameters: {'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:50,947] Trial 89 finished with value: 0.23820747016105462 and parameters: {'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:45:58,210] Trial 90 finished with value: 0.24967196012491621 and parameters: {'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:04,166] Trial 91 finished with value: 0.2354067098090378 and parameters: {'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:10,008] Trial 92 finished with value: 0.23334252434321434 and parameters: {'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:16,165] Trial 93 finished with value: 0.23528257651915893 and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:22,076] Trial 94 finished with value: 0.23382224199648294 and parameters: {'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:28,899] Trial 95 finished with value: 0.23779298201602916 and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:34,132] Trial 96 finished with value: 0.23532607878664333 and parameters: {'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:41,667] Trial 97 finished with value: 0.23930299234048857 and parameters: {'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:49,103] Trial 98 finished with value: 0.236723323328195 and parameters: {'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-20 18:46:55,461] Trial 99 finished with value: 0.23383949138740623 and parameters: {'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'criterion': 'absolute_error'}. Best is trial 83 with value: 0.23144686413677446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 19, 'max_features': 'sqrt', 'criterion': 'absolute_error'}
# Mean Absolute Error (MAE): 0.2344761462823859
# R² (Coefficient of Determination): 0.6550170572416998
# Pearson's Correlation Coefficient (R): 0.8231032389668843
# Symmetric Mean Absolute Percentage Error (SMAPE): 7.247087259576699

# %%
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import joblib
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import math

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sktime.utils.plotting import plot_series

# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, matthews_corrcoef
from sktime.performance_metrics.forecasting import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVR  # support vector machines regression
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import AdaBoostRegressor # adaboost for regression
import xgboost as xgb

skt_mape = MeanAbsolutePercentageError(symmetric=False)
skt_smape = MeanAbsolutePercentageError(symmetric=True)
skt_mae = MeanAbsoluteError()
skt_mse = MeanSquaredError()
