# %%
############## imports
# general
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score  
# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVC  # support vector machines classification
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.neural_network import MLPClassifier # neural network for classification
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier # adaboost for classification
import xgboost as xgb
# saving models
# from sklearn.externals import joblib
import joblib
import matplotlib.pyplot as plt

# %%
import pandas as pd
import random
import math

# read in time point 1 for training
# train on it - model 1
# test on tp 2
# read tp 2
# add it to xgb - model 2
# test on tp 3
# read tp 3
# add it to xgb - model 3
# test on tp 4
# test model 1
data = pd.read_csv('data_no_2022_synthesized_nonstationary.csv')
data.head()
# Out:
#       yield      radiation         rain  avg_min_temp  avg_max_temp  class
# 0  2.075882   28787.160000   149.640000      9.869700     23.412900      1
# 1  1.764706   46982.640000   276.920000     11.455500     24.227600      1
# 2  1.780042   46085.863148   270.646917     11.377343     24.187447      1
# 3  1.992485   33663.658872   183.751811     10.294704     23.631245      1
# 4  2.186471  143349.740000  1194.500000      4.153200     15.120800      1

# %%
print(len(data))
# Out:
# 16677

# %%
data = data.rename(columns={'Yield (tons/acre)':'yield'})

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
xDf = data[xColumnsToKeep]


yDf = data[yColumnsToKeep]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression, SelectPercentile
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error


# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# XGBoost model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Create the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb_model)
])

# Train the pipeline
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Mean Squared Error (MSE)
#mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
#rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Absolute Error (MAE): 0.19841962525083517
# R² (Coefficient of Determination): -0.1196720255743251
# Pearson's Correlation Coefficient (R): -0.01730635971433456
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.643739410379126

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array
# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Use cross-validation to evaluate the model (this ensures better generalization)
    score = cross_val_score(pipe, X_train, y_train, scoring='neg_mean_squared_error', cv=3)
    
    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return r2
    # Return the negative mean squared error (we want to minimize this)
    

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')  # Minimize RMSE or MSE
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)


# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-03 22:26:46,279] A new study created in memory with name: no-name-3112d6df-897d-4bf4-8872-aa09aeaee5e2
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:26:46,620] Trial 0 finished with value: -3.21964631844196e-07 and parameters: {'n_estimators': 192, 'max_depth': 9, 'learning_rate': 0.02238619666141628, 'subsample': 0.9370645239698655, 'colsample_bytree': 0.7417560995677764, 'gamma': 0.46024467054083784, 'min_child_weight': 10, 'reg_alpha': 0.8692269846898675, 'reg_lambda': 0.8164102980236003}. Best is trial 0 with value: -3.21964631844196e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:47,027] Trial 1 finished with value: -0.0008761188161914291 and parameters: {'n_estimators': 225, 'max_depth': 8, 'learning_rate': 0.11730632869041756, 'subsample': 0.5080459732024332, 'colsample_bytree': 0.8804859847595472, 'gamma': 0.41630722597310155, 'min_child_weight': 6, 'reg_alpha': 0.41055835564971466, 'reg_lambda': 0.35789004339732433}. Best is trial 0 with value: -3.21964631844196e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:47,857] Trial 2 finished with value: -0.003825180142756235 and parameters: {'n_estimators': 241, 'max_depth': 4, 'learning_rate': 0.04252760002331409, 'subsample': 0.9624823731915411, 'colsample_bytree': 0.6332427666825603, 'gamma': 0.04751909732225462, 'min_child_weight': 6, 'reg_alpha': 0.9317736420965264, 'reg_lambda': 0.49078229634926995}. Best is trial 0 with value: -3.21964631844196e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:49,397] Trial 3 finished with value: -0.0039837263852360305 and parameters: {'n_estimators': 274, 'max_depth': 5, 'learning_rate': 0.01612260697513077, 'subsample': 0.9568274612892906, 'colsample_bytree': 0.5264049939919144, 'gamma': 0.04386309363599922, 'min_child_weight': 8, 'reg_alpha': 0.575551803284301, 'reg_lambda': 0.4393126807285799}. Best is trial 0 with value: -3.21964631844196e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:49,723] Trial 4 finished with value: -0.0009387077892042406 and parameters: {'n_estimators': 177, 'max_depth': 8, 'learning_rate': 0.12745150093071228, 'subsample': 0.5093488767036841, 'colsample_bytree': 0.8561613692417402, 'gamma': 0.4078358564902104, 'min_child_weight': 5, 'reg_alpha': 0.1661584101987421, 'reg_lambda': 0.5714949578520323}. Best is trial 0 with value: -3.21964631844196e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:26:49,890] Trial 5 finished with value: -2.424807705736498e-07 and parameters: {'n_estimators': 85, 'max_depth': 8, 'learning_rate': 0.1127563472815486, 'subsample': 0.8378412580033798, 'colsample_bytree': 0.5597145276501264, 'gamma': 0.40917451814246525, 'min_child_weight': 10, 'reg_alpha': 0.6766981483009321, 'reg_lambda': 0.9336799561194125}. Best is trial 5 with value: -2.424807705736498e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:52,021] Trial 6 finished with value: -0.10155843110750618 and parameters: {'n_estimators': 279, 'max_depth': 6, 'learning_rate': 0.13859629844189136, 'subsample': 0.8716762465381958, 'colsample_bytree': 0.6003386978069307, 'gamma': 0.007384645763013786, 'min_child_weight': 2, 'reg_alpha': 0.10601495942382289, 'reg_lambda': 0.14225310783739453}. Best is trial 5 with value: -2.424807705736498e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:52,431] Trial 7 finished with value: -0.0043454778348948064 and parameters: {'n_estimators': 69, 'max_depth': 4, 'learning_rate': 0.0627628269728344, 'subsample': 0.9185747713684338, 'colsample_bytree': 0.914580408695246, 'gamma': 0.01736073185597925, 'min_child_weight': 9, 'reg_alpha': 0.7395970045418051, 'reg_lambda': 0.15041388232929354}. Best is trial 5 with value: -2.424807705736498e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:53,185] Trial 8 finished with value: -0.004659129861309008 and parameters: {'n_estimators': 103, 'max_depth': 9, 'learning_rate': 0.038603453388835744, 'subsample': 0.5226779058126656, 'colsample_bytree': 0.8017195497898162, 'gamma': 0.14944397666704895, 'min_child_weight': 6, 'reg_alpha': 0.06497035051361277, 'reg_lambda': 0.46890212460731484}. Best is trial 5 with value: -2.424807705736498e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:54,693] Trial 9 finished with value: -0.015284777892223156 and parameters: {'n_estimators': 263, 'max_depth': 6, 'learning_rate': 0.06703339571573842, 'subsample': 0.6538159945287374, 'colsample_bytree': 0.7180058479267335, 'gamma': 0.0775339687934003, 'min_child_weight': 8, 'reg_alpha': 0.5227503800662091, 'reg_lambda': 0.07662341491219149}. Best is trial 5 with value: -2.424807705736498e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:54,936] Trial 10 finished with value: -0.0006712983395724681 and parameters: {'n_estimators': 127, 'max_depth': 7, 'learning_rate': 0.19866056668866788, 'subsample': 0.7914832523300024, 'colsample_bytree': 0.524318301794741, 'gamma': 0.31572814654698667, 'min_child_weight': 2, 'reg_alpha': 0.6715025102699953, 'reg_lambda': 0.9813663191918615}. Best is trial 5 with value: -2.424807705736498e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:26:55,306] Trial 11 finished with value: -3.5686470363227585e-06 and parameters: {'n_estimators': 189, 'max_depth': 10, 'learning_rate': 0.09058966756103694, 'subsample': 0.7756984511637942, 'colsample_bytree': 0.9915563372316214, 'gamma': 0.4906290605767896, 'min_child_weight': 10, 'reg_alpha': 0.9970855835066692, 'reg_lambda': 0.9798914004360126}. Best is trial 5 with value: -2.424807705736498e-07.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:55,594] Trial 12 finished with value: 0.000359123697360908 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.16276140506827164, 'subsample': 0.8524671912093995, 'colsample_bytree': 0.7016478998043201, 'gamma': 0.294063286256252, 'min_child_weight': 10, 'reg_alpha': 0.7936357159952995, 'reg_lambda': 0.772606568456739}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:55,852] Trial 13 finished with value: -0.000162996078422184 and parameters: {'n_estimators': 124, 'max_depth': 10, 'learning_rate': 0.16615238995607287, 'subsample': 0.8415148120605158, 'colsample_bytree': 0.6534704043766787, 'gamma': 0.27472010393634816, 'min_child_weight': 8, 'reg_alpha': 0.3359964009609319, 'reg_lambda': 0.7354660763697911}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:55,987] Trial 14 finished with value: 0.00013311202642130038 and parameters: {'n_estimators': 55, 'max_depth': 8, 'learning_rate': 0.16191382921232783, 'subsample': 0.7245765324648806, 'colsample_bytree': 0.5755606036177342, 'gamma': 0.33407204963867043, 'min_child_weight': 4, 'reg_alpha': 0.7851021088400721, 'reg_lambda': 0.774375914765729}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:56,143] Trial 15 finished with value: -0.0016615773516197585 and parameters: {'n_estimators': 52, 'max_depth': 10, 'learning_rate': 0.16534575682012828, 'subsample': 0.6864303524697255, 'colsample_bytree': 0.6773181492254952, 'gamma': 0.20878838594460739, 'min_child_weight': 4, 'reg_alpha': 0.7839489262163776, 'reg_lambda': 0.7335052715266537}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:56,432] Trial 16 finished with value: -0.00021538825814260143 and parameters: {'n_estimators': 145, 'max_depth': 9, 'learning_rate': 0.19789186787458957, 'subsample': 0.6707167667482287, 'colsample_bytree': 0.7877489512842375, 'gamma': 0.3387412704682268, 'min_child_weight': 4, 'reg_alpha': 0.8403336411448582, 'reg_lambda': 0.6767045600073862}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:56,787] Trial 17 finished with value: -0.00124023548172425 and parameters: {'n_estimators': 152, 'max_depth': 7, 'learning_rate': 0.16154239661709321, 'subsample': 0.7243732612139209, 'colsample_bytree': 0.5944850549541937, 'gamma': 0.2083421577325259, 'min_child_weight': 1, 'reg_alpha': 0.603739847318197, 'reg_lambda': 0.8378708210865267}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:57,006] Trial 18 finished with value: -2.3492843811645514e-05 and parameters: {'n_estimators': 101, 'max_depth': 9, 'learning_rate': 0.14967816935814546, 'subsample': 0.6326644245582307, 'colsample_bytree': 0.6777547379292291, 'gamma': 0.32493897852554715, 'min_child_weight': 3, 'reg_alpha': 0.3610685492623725, 'reg_lambda': 0.6411192488587429}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:57,455] Trial 19 finished with value: -0.001178679652436898 and parameters: {'n_estimators': 213, 'max_depth': 8, 'learning_rate': 0.09167625565092741, 'subsample': 0.591800464689699, 'colsample_bytree': 0.5038662620298198, 'gamma': 0.23798855960526535, 'min_child_weight': 7, 'reg_alpha': 0.7512621168280291, 'reg_lambda': 0.3406141058083952}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:57,750] Trial 20 finished with value: -0.00021175265993922388 and parameters: {'n_estimators': 153, 'max_depth': 10, 'learning_rate': 0.18145539494862817, 'subsample': 0.7300257658548314, 'colsample_bytree': 0.7089315890985, 'gamma': 0.36445473470314044, 'min_child_weight': 4, 'reg_alpha': 0.45211875850537436, 'reg_lambda': 0.8515905960455085}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:57,960] Trial 21 finished with value: 4.479506562338198e-05 and parameters: {'n_estimators': 85, 'max_depth': 8, 'learning_rate': 0.1089693047895683, 'subsample': 0.8291851186453916, 'colsample_bytree': 0.5710728759781584, 'gamma': 0.4106152379343523, 'min_child_weight': 10, 'reg_alpha': 0.6445204012805079, 'reg_lambda': 0.9085193624773644}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:58,094] Trial 22 finished with value: -0.00040817716360930234 and parameters: {'n_estimators': 54, 'max_depth': 7, 'learning_rate': 0.13669083378938227, 'subsample': 0.8848549132127541, 'colsample_bytree': 0.582348812781918, 'gamma': 0.29025809245143874, 'min_child_weight': 9, 'reg_alpha': 0.6552864312262102, 'reg_lambda': 0.8847363612985181}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:26:58,253] Trial 23 finished with value: -6.896445474691149e-07 and parameters: {'n_estimators': 71, 'max_depth': 3, 'learning_rate': 0.09936438730657628, 'subsample': 0.8007768264068447, 'colsample_bytree': 0.6258995888751758, 'gamma': 0.3736182119372243, 'min_child_weight': 9, 'reg_alpha': 0.8605137441231154, 'reg_lambda': 0.7680484168201344}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:26:58,462] Trial 24 finished with value: -6.833190235866482e-09 and parameters: {'n_estimators': 101, 'max_depth': 9, 'learning_rate': 0.18384565258541286, 'subsample': 0.757594916378654, 'colsample_bytree': 0.5556676505452585, 'gamma': 0.44094080917502465, 'min_child_weight': 7, 'reg_alpha': 0.7931546616002277, 'reg_lambda': 0.5878344442747175}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:26:58,763] Trial 25 finished with value: -7.275376553161905e-05 and parameters: {'n_estimators': 124, 'max_depth': 8, 'learning_rate': 0.15003377715454924, 'subsample': 0.8355632637827674, 'colsample_bytree': 0.7842671063658418, 'gamma': 0.16773778379111234, 'min_child_weight': 5, 'reg_alpha': 0.9291367602810686, 'reg_lambda': 0.9088572105896469}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:26:58,941] Trial 26 finished with value: -3.4710622731637386e-07 and parameters: {'n_estimators': 84, 'max_depth': 6, 'learning_rate': 0.07335077487050254, 'subsample': 0.8900852258895178, 'colsample_bytree': 0.6618279118088545, 'gamma': 0.36872641902019976, 'min_child_weight': 3, 'reg_alpha': 0.530374164469828, 'reg_lambda': 0.668732007693886}. Best is trial 12 with value: 0.000359123697360908.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:14,360] Trial 90 finished with value: -0.002185645997908381 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.1590117837370575, 'subsample': 0.8351204530995571, 'colsample_bytree': 0.5965325497343814, 'gamma': 0.1282943127001776, 'min_child_weight': 1, 'reg_alpha': 0.8177778266541676, 'reg_lambda': 0.4589946705350472}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:14,527] Trial 91 finished with value: 0.0003918354893041043 and parameters: {'n_estimators': 59, 'max_depth': 6, 'learning_rate': 0.16733057502503368, 'subsample': 0.8308683975057239, 'colsample_bytree': 0.5698693280718085, 'gamma': 0.25417781918974214, 'min_child_weight': 8, 'reg_alpha': 0.5652507885385787, 'reg_lambda': 0.2941165828033925}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:14,678] Trial 92 finished with value: 6.0756703797237854e-05 and parameters: {'n_estimators': 57, 'max_depth': 6, 'learning_rate': 0.16487678854480967, 'subsample': 0.8519087582238435, 'colsample_bytree': 0.5840625601063218, 'gamma': 0.24755170403442875, 'min_child_weight': 8, 'reg_alpha': 0.5455096121050667, 'reg_lambda': 0.3723799735299077}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:14,867] Trial 93 finished with value: -0.0009719539117321041 and parameters: {'n_estimators': 66, 'max_depth': 7, 'learning_rate': 0.17310516257457534, 'subsample': 0.8109127100663671, 'colsample_bytree': 0.6096500016915999, 'gamma': 0.17684954763932492, 'min_child_weight': 9, 'reg_alpha': 0.622863950621074, 'reg_lambda': 0.1879428156620609}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:15,043] Trial 94 finished with value: 0.0004367019948003925 and parameters: {'n_estimators': 65, 'max_depth': 6, 'learning_rate': 0.16830014505986826, 'subsample': 0.780570440857322, 'colsample_bytree': 0.5425135703625394, 'gamma': 0.22906424608479725, 'min_child_weight': 7, 'reg_alpha': 0.48818002214864076, 'reg_lambda': 0.28556802277372284}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:15,253] Trial 95 finished with value: -0.0005171961438785733 and parameters: {'n_estimators': 64, 'max_depth': 5, 'learning_rate': 0.14972454587729173, 'subsample': 0.7842399350355469, 'colsample_bytree': 0.5116318254342467, 'gamma': 0.19685570601942987, 'min_child_weight': 7, 'reg_alpha': 0.4874050939775617, 'reg_lambda': 0.22275259578039902}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:15,455] Trial 96 finished with value: -0.0012896275683811353 and parameters: {'n_estimators': 77, 'max_depth': 6, 'learning_rate': 0.17727069389636105, 'subsample': 0.7374063380677199, 'colsample_bytree': 0.5407934225849996, 'gamma': 0.23068609543323748, 'min_child_weight': 7, 'reg_alpha': 0.5114313780260619, 'reg_lambda': 0.2800156128731209}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:15,664] Trial 97 finished with value: 1.5419912117176082e-05 and parameters: {'n_estimators': 69, 'max_depth': 4, 'learning_rate': 0.15634292655673246, 'subsample': 0.7570821981712371, 'colsample_bytree': 0.5241052260388163, 'gamma': 0.27261573223168956, 'min_child_weight': 7, 'reg_alpha': 0.45671466315754444, 'reg_lambda': 0.3208906565214172}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:15,896] Trial 98 finished with value: 0.0001567839404184035 and parameters: {'n_estimators': 94, 'max_depth': 8, 'learning_rate': 0.19538744901684327, 'subsample': 0.7909092959526329, 'colsample_bytree': 0.5432554313157893, 'gamma': 0.2101468319859676, 'min_child_weight': 8, 'reg_alpha': 0.43676747803937366, 'reg_lambda': 0.41523944184304584}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:27:16,063] Trial 99 finished with value: 5.5019594634608815e-05 and parameters: {'n_estimators': 50, 'max_depth': 7, 'learning_rate': 0.18652773470868497, 'subsample': 0.7693297907565184, 'colsample_bytree': 0.6307088830215094, 'gamma': 0.1815914675992365, 'min_child_weight': 7, 'reg_alpha': 0.6575242588849939, 'reg_lambda': 0.2496465095048326}. Best is trial 52 with value: 0.0007403985475229469.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'n_estimators': 78, 'max_depth': 3, 'learning_rate': 0.15901119736414054, 'subsample': 0.7767476463304421, 'colsample_bytree': 0.562594028987373, 'gamma': 0.2113441871809522, 'min_child_weight': 7, 'reg_alpha': 0.4997048208865652, 'reg_lambda': 0.3177592528030321}
# Mean Absolute Error (MAE): 0.19018536962747706
# R² (Coefficient of Determination): 0.0007403985475229469
# Pearson's Correlation Coefficient (R): 0.028991664759962944
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.45307518396457

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile
import numpy as np

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return mae

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize')  # Maximize the combined objective
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)

# Print evaluation metrics
mae = mean_absolute_error(y_test_flat, y_pred)
r2 = r2_score(y_test_flat, y_pred)
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]
smape_value = smape(y_test_flat, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-03 21:53:17,759] A new study created in memory with name: no-name-49cc47f6-6c22-41cb-a2f8-085641bc8e29
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:17,959] Trial 0 finished with value: 0.15496834682314697 and parameters: {'n_estimators': 290, 'max_depth': 10, 'learning_rate': 0.17936057727271237, 'subsample': 0.9155136614642183, 'colsample_bytree': 0.716673515055988, 'gamma': 0.12035420015850468, 'min_child_weight': 6, 'reg_alpha': 0.6061661509197223, 'reg_lambda': 0.5288506212429723}. Best is trial 0 with value: 0.15496834682314697.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:18,107] Trial 1 finished with value: 0.1505125440280131 and parameters: {'n_estimators': 253, 'max_depth': 8, 'learning_rate': 0.16903109222561571, 'subsample': 0.8787659716878826, 'colsample_bytree': 0.7994930235781348, 'gamma': 0.39598381286333584, 'min_child_weight': 10, 'reg_alpha': 0.45881408971618753, 'reg_lambda': 0.2882091990558542}. Best is trial 1 with value: 0.1505125440280131.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:18,283] Trial 2 finished with value: 0.15523774768040857 and parameters: {'n_estimators': 231, 'max_depth': 9, 'learning_rate': 0.06806292922237274, 'subsample': 0.671391106105546, 'colsample_bytree': 0.5348445013654884, 'gamma': 0.28413076398792875, 'min_child_weight': 7, 'reg_alpha': 0.7438229957830844, 'reg_lambda': 0.2562125366882295}. Best is trial 1 with value: 0.1505125440280131.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:18,464] Trial 3 finished with value: 0.1567653707293863 and parameters: {'n_estimators': 283, 'max_depth': 9, 'learning_rate': 0.18816105278304135, 'subsample': 0.5604787803282596, 'colsample_bytree': 0.5167967692200643, 'gamma': 0.42041400063378653, 'min_child_weight': 9, 'reg_alpha': 0.3846750001149537, 'reg_lambda': 0.09040293278377487}. Best is trial 1 with value: 0.1505125440280131.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:18,726] Trial 4 finished with value: 0.15085514581782378 and parameters: {'n_estimators': 286, 'max_depth': 6, 'learning_rate': 0.08638872038198961, 'subsample': 0.5958554424301779, 'colsample_bytree': 0.875706674260688, 'gamma': 0.10850339578247942, 'min_child_weight': 4, 'reg_alpha': 0.9560075031800773, 'reg_lambda': 0.976439319302243}. Best is trial 1 with value: 0.1505125440280131.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:18,857] Trial 5 finished with value: 0.15010472633853972 and parameters: {'n_estimators': 67, 'max_depth': 7, 'learning_rate': 0.08463459063482831, 'subsample': 0.6812216529371985, 'colsample_bytree': 0.8346095389695944, 'gamma': 0.26061194649167596, 'min_child_weight': 2, 'reg_alpha': 0.8154173697066419, 'reg_lambda': 0.9124566089378846}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:19,107] Trial 6 finished with value: 0.15452206340966315 and parameters: {'n_estimators': 220, 'max_depth': 7, 'learning_rate': 0.05744810017963472, 'subsample': 0.9051301557086491, 'colsample_bytree': 0.6749858219181395, 'gamma': 0.22863743201382386, 'min_child_weight': 3, 'reg_alpha': 0.08584561313685357, 'reg_lambda': 0.1485502902773166}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:19,320] Trial 7 finished with value: 0.15438098842560793 and parameters: {'n_estimators': 77, 'max_depth': 10, 'learning_rate': 0.07005733792916048, 'subsample': 0.8989607778197268, 'colsample_bytree': 0.7216307686966894, 'gamma': 0.10588972079398695, 'min_child_weight': 6, 'reg_alpha': 0.4858685975920204, 'reg_lambda': 0.38394166340746316}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:19,466] Trial 8 finished with value: 0.15643969644271277 and parameters: {'n_estimators': 88, 'max_depth': 8, 'learning_rate': 0.05246595724588121, 'subsample': 0.6519185802024324, 'colsample_bytree': 0.5096234720717823, 'gamma': 0.4870759620530197, 'min_child_weight': 6, 'reg_alpha': 0.31180380300501376, 'reg_lambda': 0.7563440011284976}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:19,668] Trial 9 finished with value: 0.15456485400564127 and parameters: {'n_estimators': 286, 'max_depth': 7, 'learning_rate': 0.18643590762996437, 'subsample': 0.935122932220757, 'colsample_bytree': 0.5908968095934806, 'gamma': 0.08951807338137402, 'min_child_weight': 5, 'reg_alpha': 0.41483660550493384, 'reg_lambda': 0.7741496922482197}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:19,761] Trial 10 finished with value: 0.1576457226718851 and parameters: {'n_estimators': 136, 'max_depth': 3, 'learning_rate': 0.12817925285951634, 'subsample': 0.7688550898058516, 'colsample_bytree': 0.9671894104755663, 'gamma': 0.2777162862971716, 'min_child_weight': 1, 'reg_alpha': 0.9364734863846287, 'reg_lambda': 0.9935235624634168}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:19,892] Trial 11 finished with value: 0.15740039125557884 and parameters: {'n_estimators': 157, 'max_depth': 4, 'learning_rate': 0.12161443017329791, 'subsample': 0.7889972887294574, 'colsample_bytree': 0.829748490692956, 'gamma': 0.36975702833497315, 'min_child_weight': 10, 'reg_alpha': 0.7392451953645977, 'reg_lambda': 0.5215016556981388}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:20,175] Trial 12 finished with value: 0.15580532096049593 and parameters: {'n_estimators': 193, 'max_depth': 5, 'learning_rate': 0.018527959037296246, 'subsample': 0.8168959431634518, 'colsample_bytree': 0.8252818569024267, 'gamma': 0.356731409775582, 'min_child_weight': 1, 'reg_alpha': 0.6407334884911424, 'reg_lambda': 0.3603876917214694}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:20,290] Trial 13 finished with value: 0.1515810377865817 and parameters: {'n_estimators': 113, 'max_depth': 6, 'learning_rate': 0.14971132501672724, 'subsample': 0.9894013267971546, 'colsample_bytree': 0.9316708102501945, 'gamma': 0.2004064225320959, 'min_child_weight': 8, 'reg_alpha': 0.18401710672817972, 'reg_lambda': 0.738857146056138}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:20,454] Trial 14 finished with value: 0.1505839681176035 and parameters: {'n_estimators': 231, 'max_depth': 8, 'learning_rate': 0.14470556981903188, 'subsample': 0.70378661866459, 'colsample_bytree': 0.794219572650649, 'gamma': 0.4936109353914576, 'min_child_weight': 3, 'reg_alpha': 0.8251540433449425, 'reg_lambda': 0.6256480080561264}. Best is trial 5 with value: 0.15010472633853972.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:20,614] Trial 15 finished with value: 0.14955005099166616 and parameters: {'n_estimators': 52, 'max_depth': 8, 'learning_rate': 0.09867373241233823, 'subsample': 0.8361699179651974, 'colsample_bytree': 0.8922672244686073, 'gamma': 0.0033957891002103224, 'min_child_weight': 10, 'reg_alpha': 0.5763064327592144, 'reg_lambda': 0.29784206903892846}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:20,722] Trial 16 finished with value: 0.1534560864453099 and parameters: {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1104354782134078, 'subsample': 0.5158399593273815, 'colsample_bytree': 0.8983699452244545, 'gamma': 0.011033630009525206, 'min_child_weight': 2, 'reg_alpha': 0.5813525994584868, 'reg_lambda': 0.007084827646999969}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:20,866] Trial 17 finished with value: 0.14985509373493272 and parameters: {'n_estimators': 52, 'max_depth': 7, 'learning_rate': 0.09265630833028146, 'subsample': 0.7182343425921296, 'colsample_bytree': 0.9874334106134023, 'gamma': 0.007064251303107449, 'min_child_weight': 8, 'reg_alpha': 0.8338795523386651, 'reg_lambda': 0.8721826676105037}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:21,205] Trial 18 finished with value: 0.15033278883654932 and parameters: {'n_estimators': 107, 'max_depth': 9, 'learning_rate': 0.03016323877117673, 'subsample': 0.83689429276078, 'colsample_bytree': 0.9959631432007611, 'gamma': 0.01631928156480918, 'min_child_weight': 8, 'reg_alpha': 0.27654442447981314, 'reg_lambda': 0.41018267428284494}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:21,306] Trial 19 finished with value: 0.15373840271954625 and parameters: {'n_estimators': 51, 'max_depth': 5, 'learning_rate': 0.10199650435548697, 'subsample': 0.7297613239179002, 'colsample_bytree': 0.9378162226023731, 'gamma': 0.16359536041560924, 'min_child_weight': 9, 'reg_alpha': 0.6851214938586404, 'reg_lambda': 0.20855786206071522}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:21,577] Trial 20 finished with value: 0.15108450921650052 and parameters: {'n_estimators': 130, 'max_depth': 6, 'learning_rate': 0.03872713297460316, 'subsample': 0.6101752964588781, 'colsample_bytree': 0.9954512408746286, 'gamma': 0.05220444008860459, 'min_child_weight': 8, 'reg_alpha': 0.8746875672615149, 'reg_lambda': 0.628270111772358}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:21,712] Trial 21 finished with value: 0.15010003644034203 and parameters: {'n_estimators': 80, 'max_depth': 7, 'learning_rate': 0.09109409783824675, 'subsample': 0.7120954517495863, 'colsample_bytree': 0.87685694756058, 'gamma': 0.17094624120125865, 'min_child_weight': 10, 'reg_alpha': 0.8141556379408583, 'reg_lambda': 0.8586901971373598}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:21,904] Trial 22 finished with value: 0.14984666105502067 and parameters: {'n_estimators': 90, 'max_depth': 8, 'learning_rate': 0.0998931212394218, 'subsample': 0.7398036862866104, 'colsample_bytree': 0.884995418953565, 'gamma': 0.06076009453582794, 'min_child_weight': 10, 'reg_alpha': 0.566969172156317, 'reg_lambda': 0.8545904051976635}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:22,113] Trial 23 finished with value: 0.1499357929986004 and parameters: {'n_estimators': 99, 'max_depth': 8, 'learning_rate': 0.11104308945976783, 'subsample': 0.8458371175038304, 'colsample_bytree': 0.9217163568320347, 'gamma': 0.040064292863146535, 'min_child_weight': 9, 'reg_alpha': 0.5527427514827168, 'reg_lambda': 0.8357157176895655}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:22,273] Trial 24 finished with value: 0.15012569203723689 and parameters: {'n_estimators': 67, 'max_depth': 8, 'learning_rate': 0.13302707261353064, 'subsample': 0.7634282453502657, 'colsample_bytree': 0.8691049880074406, 'gamma': 0.06467803847607237, 'min_child_weight': 9, 'reg_alpha': 0.5410342240434716, 'reg_lambda': 0.6644463403761829}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:22,679] Trial 25 finished with value: 0.15089072463498218 and parameters: {'n_estimators': 127, 'max_depth': 9, 'learning_rate': 0.09996492226981343, 'subsample': 0.7908046746373376, 'colsample_bytree': 0.9579982159978638, 'gamma': 0.0009635592778109991, 'min_child_weight': 7, 'reg_alpha': 0.7014057047535062, 'reg_lambda': 0.46964741744425936}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:22,826] Trial 26 finished with value: 0.15002371068974554 and parameters: {'n_estimators': 152, 'max_depth': 7, 'learning_rate': 0.06851395885023498, 'subsample': 0.7360012634522985, 'colsample_bytree': 0.7667272922704483, 'gamma': 0.14055704491386856, 'min_child_weight': 10, 'reg_alpha': 0.3564416273846047, 'reg_lambda': 0.9009720111426753}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:23,011] Trial 27 finished with value: 0.14994098149104065 and parameters: {'n_estimators': 58, 'max_depth': 9, 'learning_rate': 0.07916777422016906, 'subsample': 0.6490021868776131, 'colsample_bytree': 0.9068399400657722, 'gamma': 0.07090497956322192, 'min_child_weight': 7, 'reg_alpha': 0.6637579115030249, 'reg_lambda': 0.5858219510661979}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:23,195] Trial 28 finished with value: 0.14993257668781113 and parameters: {'n_estimators': 92, 'max_depth': 8, 'learning_rate': 0.15071574527362638, 'subsample': 0.8614485705683103, 'colsample_bytree': 0.955362555444512, 'gamma': 0.03366454379367363, 'min_child_weight': 8, 'reg_alpha': 0.48138770898937744, 'reg_lambda': 0.69222078308694}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:23,340] Trial 29 finished with value: 0.15452123581260668 and parameters: {'n_estimators': 75, 'max_depth': 10, 'learning_rate': 0.11324043988895527, 'subsample': 0.9541958835418871, 'colsample_bytree': 0.6589184472944549, 'gamma': 0.13677390900580022, 'min_child_weight': 9, 'reg_alpha': 0.6057010724157237, 'reg_lambda': 0.46518831194024174}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:23,503] Trial 30 finished with value: 0.15086948389218444 and parameters: {'n_estimators': 190, 'max_depth': 6, 'learning_rate': 0.16921352725272815, 'subsample': 0.8293737617043847, 'colsample_bytree': 0.8567814148744424, 'gamma': 0.08031130008288413, 'min_child_weight': 10, 'reg_alpha': 0.9902678211766714, 'reg_lambda': 0.8097538290024422}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:23,682] Trial 31 finished with value: 0.15015928480391869 and parameters: {'n_estimators': 94, 'max_depth': 8, 'learning_rate': 0.15837682386346608, 'subsample': 0.8711022919508584, 'colsample_bytree': 0.9598946874877575, 'gamma': 0.03790236694095879, 'min_child_weight': 8, 'reg_alpha': 0.4774069725923402, 'reg_lambda': 0.6998706906526941}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:24,019] Trial 32 finished with value: 0.15208175678230884 and parameters: {'n_estimators': 111, 'max_depth': 8, 'learning_rate': 0.13482853006884335, 'subsample': 0.7979327525482786, 'colsample_bytree': 0.9752140137599409, 'gamma': 0.0006861263320796936, 'min_child_weight': 7, 'reg_alpha': 0.2385649667759921, 'reg_lambda': 0.8956972583013095}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:24,184] Trial 33 finished with value: 0.1501387936085123 and parameters: {'n_estimators': 92, 'max_depth': 7, 'learning_rate': 0.19990970477428915, 'subsample': 0.8532513919433734, 'colsample_bytree': 0.9475548367886621, 'gamma': 0.03546091542226826, 'min_child_weight': 5, 'reg_alpha': 0.5196246763085408, 'reg_lambda': 0.7131287692024653}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:24,388] Trial 34 finished with value: 0.14965948912798627 and parameters: {'n_estimators': 65, 'max_depth': 9, 'learning_rate': 0.09542041775595249, 'subsample': 0.7435189927573215, 'colsample_bytree': 0.9042032030450065, 'gamma': 0.036941651071722856, 'min_child_weight': 10, 'reg_alpha': 0.7467687719677436, 'reg_lambda': 0.32184830570769046}. Best is trial 15 with value: 0.14955005099166616.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:24,551] Trial 35 finished with value: 0.14935618216573407 and parameters: {'n_estimators': 63, 'max_depth': 9, 'learning_rate': 0.094929695141997, 'subsample': 0.7570664093102467, 'colsample_bytree': 0.9001188398912063, 'gamma': 0.09606287734114684, 'min_child_weight': 10, 'reg_alpha': 0.7686286673870314, 'reg_lambda': 0.3002389376833146}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:24,728] Trial 36 finished with value: 0.1496965107599562 and parameters: {'n_estimators': 64, 'max_depth': 10, 'learning_rate': 0.07900034193437225, 'subsample': 0.7504757580646952, 'colsample_bytree': 0.7847732804018683, 'gamma': 0.11714609878972336, 'min_child_weight': 10, 'reg_alpha': 0.7522042210549987, 'reg_lambda': 0.3105820530342367}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:24,850] Trial 37 finished with value: 0.1499106907039598 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.07779617055861829, 'subsample': 0.6814156661946259, 'colsample_bytree': 0.7982790460511149, 'gamma': 0.11743846460358856, 'min_child_weight': 9, 'reg_alpha': 0.7639065386226505, 'reg_lambda': 0.311538749099631}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:25,031] Trial 38 finished with value: 0.14998390110395574 and parameters: {'n_estimators': 70, 'max_depth': 9, 'learning_rate': 0.05607845604748366, 'subsample': 0.7622782598987425, 'colsample_bytree': 0.7783840954509599, 'gamma': 0.22157641487050062, 'min_child_weight': 10, 'reg_alpha': 0.752412368753723, 'reg_lambda': 0.22566270532166757}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:25,297] Trial 39 finished with value: 0.15404067502120158 and parameters: {'n_estimators': 268, 'max_depth': 10, 'learning_rate': 0.11952908068996754, 'subsample': 0.8125495293341243, 'colsample_bytree': 0.730479041386766, 'gamma': 0.09814612346863692, 'min_child_weight': 10, 'reg_alpha': 0.641104562838304, 'reg_lambda': 0.29523590935545374}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:25,432] Trial 40 finished with value: 0.1503184988650197 and parameters: {'n_estimators': 120, 'max_depth': 9, 'learning_rate': 0.07872574774691725, 'subsample': 0.6342204953932133, 'colsample_bytree': 0.8408229573312078, 'gamma': 0.31162565637169115, 'min_child_weight': 9, 'reg_alpha': 0.8962941051089781, 'reg_lambda': 0.14624173835648718}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:25,634] Trial 41 finished with value: 0.1498600752402862 and parameters: {'n_estimators': 82, 'max_depth': 10, 'learning_rate': 0.09783715138824509, 'subsample': 0.6901201033191666, 'colsample_bytree': 0.8904472516035582, 'gamma': 0.06733112643982209, 'min_child_weight': 10, 'reg_alpha': 0.7328952332822678, 'reg_lambda': 0.3438513661787239}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:25,782] Trial 42 finished with value: 0.1550414139506278 and parameters: {'n_estimators': 62, 'max_depth': 9, 'learning_rate': 0.08639388060152432, 'subsample': 0.7484170839023263, 'colsample_bytree': 0.6721326544206654, 'gamma': 0.1414200308960249, 'min_child_weight': 10, 'reg_alpha': 0.787655646372758, 'reg_lambda': 0.15694757259153228}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:25,952] Trial 43 finished with value: 0.1496685155754155 and parameters: {'n_estimators': 79, 'max_depth': 10, 'learning_rate': 0.10427181414600464, 'subsample': 0.7767237818392786, 'colsample_bytree': 0.915192166747147, 'gamma': 0.09147088186319481, 'min_child_weight': 9, 'reg_alpha': 0.705035560890762, 'reg_lambda': 0.42505759002122556}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:26,134] Trial 44 finished with value: 0.14966176264522998 and parameters: {'n_estimators': 73, 'max_depth': 10, 'learning_rate': 0.06586559742936038, 'subsample': 0.7782139537778169, 'colsample_bytree': 0.8530875838745064, 'gamma': 0.17239826872999237, 'min_child_weight': 9, 'reg_alpha': 0.7075830533932286, 'reg_lambda': 0.42005666723873564}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:26,351] Trial 45 finished with value: 0.15073308542123243 and parameters: {'n_estimators': 76, 'max_depth': 10, 'learning_rate': 0.042225877288224314, 'subsample': 0.782209827206808, 'colsample_bytree': 0.9088344543704938, 'gamma': 0.1780720268074632, 'min_child_weight': 9, 'reg_alpha': 0.6107051312892663, 'reg_lambda': 0.4139480379920223}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:26,551] Trial 46 finished with value: 0.149424916840731 and parameters: {'n_estimators': 104, 'max_depth': 9, 'learning_rate': 0.06329081392914712, 'subsample': 0.890673543752281, 'colsample_bytree': 0.8511707244386072, 'gamma': 0.09012856292276693, 'min_child_weight': 9, 'reg_alpha': 0.4293072259420519, 'reg_lambda': 0.2584522184956327}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:26,738] Trial 47 finished with value: 0.14980233152489147 and parameters: {'n_estimators': 104, 'max_depth': 9, 'learning_rate': 0.06192542372244177, 'subsample': 0.9348893818623902, 'colsample_bytree': 0.825798820124726, 'gamma': 0.22850887818152557, 'min_child_weight': 9, 'reg_alpha': 0.4203411041584664, 'reg_lambda': 0.2514835392895649}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:27,014] Trial 48 finished with value: 0.14948577428562945 and parameters: {'n_estimators': 146, 'max_depth': 9, 'learning_rate': 0.04463249340152592, 'subsample': 0.8813869575128406, 'colsample_bytree': 0.8534351878538585, 'gamma': 0.19593107538120771, 'min_child_weight': 6, 'reg_alpha': 0.07555047832038586, 'reg_lambda': 0.34448608612984}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:27,276] Trial 49 finished with value: 0.1495199282448343 and parameters: {'n_estimators': 147, 'max_depth': 9, 'learning_rate': 0.04958126931217166, 'subsample': 0.8990469010484473, 'colsample_bytree': 0.8076043223254132, 'gamma': 0.2548405907487147, 'min_child_weight': 4, 'reg_alpha': 0.001681037745084768, 'reg_lambda': 0.1771985638545408}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:27,657] Trial 50 finished with value: 0.15128333513582118 and parameters: {'n_estimators': 147, 'max_depth': 9, 'learning_rate': 0.019432351739132162, 'subsample': 0.8896762188448815, 'colsample_bytree': 0.8127861082940275, 'gamma': 0.3018880940569628, 'min_child_weight': 4, 'reg_alpha': 0.02198655343450794, 'reg_lambda': 0.0546062587769363}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:27,890] Trial 51 finished with value: 0.14960692043393672 and parameters: {'n_estimators': 168, 'max_depth': 9, 'learning_rate': 0.0484813755037839, 'subsample': 0.9283748785960371, 'colsample_bytree': 0.8511543740823931, 'gamma': 0.24809500174977878, 'min_child_weight': 4, 'reg_alpha': 0.07367816998060328, 'reg_lambda': 0.1898637828848768}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:28,071] Trial 52 finished with value: 0.14952969389807053 and parameters: {'n_estimators': 164, 'max_depth': 9, 'learning_rate': 0.04532710415336514, 'subsample': 0.9190670621020228, 'colsample_bytree': 0.7523624452557449, 'gamma': 0.24872136264484482, 'min_child_weight': 3, 'reg_alpha': 0.16379335459783734, 'reg_lambda': 0.2001888200437066}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:28,456] Trial 53 finished with value: 0.15475144092213478 and parameters: {'n_estimators': 184, 'max_depth': 9, 'learning_rate': 0.027322243635508087, 'subsample': 0.9654565209773979, 'colsample_bytree': 0.7471947805015812, 'gamma': 0.19974607057259713, 'min_child_weight': 3, 'reg_alpha': 0.15480571963195927, 'reg_lambda': 0.25942387450858895}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:28,822] Trial 54 finished with value: 0.17305926665986207 and parameters: {'n_estimators': 140, 'max_depth': 8, 'learning_rate': 0.010165271755220459, 'subsample': 0.9129492182998167, 'colsample_bytree': 0.8040337889313945, 'gamma': 0.2531777506025289, 'min_child_weight': 2, 'reg_alpha': 7.110650540564922e-05, 'reg_lambda': 0.09168792378366836}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:29,063] Trial 55 finished with value: 0.14962996939832376 and parameters: {'n_estimators': 165, 'max_depth': 8, 'learning_rate': 0.04842063243933622, 'subsample': 0.8933888640437003, 'colsample_bytree': 0.7564919807993153, 'gamma': 0.2789444112146544, 'min_child_weight': 5, 'reg_alpha': 0.12840347673037, 'reg_lambda': 0.10057911076084802}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:29,285] Trial 56 finished with value: 0.15511058350180199 and parameters: {'n_estimators': 202, 'max_depth': 9, 'learning_rate': 0.03676551600469419, 'subsample': 0.9988817673074237, 'colsample_bytree': 0.7166017484150532, 'gamma': 0.3461031201950294, 'min_child_weight': 4, 'reg_alpha': 0.058874439004245195, 'reg_lambda': 0.25969334331135624}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:29,457] Trial 57 finished with value: 0.15692012137869316 and parameters: {'n_estimators': 159, 'max_depth': 3, 'learning_rate': 0.05948033866414517, 'subsample': 0.8841080300620703, 'colsample_bytree': 0.8176070945731546, 'gamma': 0.19567041637901933, 'min_child_weight': 3, 'reg_alpha': 0.11265120609524651, 'reg_lambda': 0.18258272153468705}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:29,793] Trial 58 finished with value: 0.14949422121307054 and parameters: {'n_estimators': 211, 'max_depth': 9, 'learning_rate': 0.03212682370889913, 'subsample': 0.9575828147688856, 'colsample_bytree': 0.8784109695832377, 'gamma': 0.3001354452094886, 'min_child_weight': 6, 'reg_alpha': 0.24113588609388056, 'reg_lambda': 0.376555059491016}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:30,011] Trial 59 finished with value: 0.1497179824602112 and parameters: {'n_estimators': 210, 'max_depth': 9, 'learning_rate': 0.029195601725037074, 'subsample': 0.9683437031580588, 'colsample_bytree': 0.8691372353259063, 'gamma': 0.41754424631984544, 'min_child_weight': 6, 'reg_alpha': 0.19625147854203706, 'reg_lambda': 0.369102271568824}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:30,249] Trial 60 finished with value: 0.15722273597550304 and parameters: {'n_estimators': 237, 'max_depth': 4, 'learning_rate': 0.04319306194550877, 'subsample': 0.9484750825945487, 'colsample_bytree': 0.5571493389448623, 'gamma': 0.3146082867338792, 'min_child_weight': 6, 'reg_alpha': 0.32585446896910414, 'reg_lambda': 0.2403573519473607}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:30,542] Trial 61 finished with value: 0.14971879055139398 and parameters: {'n_estimators': 142, 'max_depth': 9, 'learning_rate': 0.03368834352597146, 'subsample': 0.919296404077462, 'colsample_bytree': 0.8387417100596073, 'gamma': 0.33667901629361013, 'min_child_weight': 4, 'reg_alpha': 0.2313889349834037, 'reg_lambda': 0.13423689630792776}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:30,674] Trial 62 finished with value: 0.1495507903065844 and parameters: {'n_estimators': 125, 'max_depth': 8, 'learning_rate': 0.051796700557483394, 'subsample': 0.9037557772827434, 'colsample_bytree': 0.93051166592221, 'gamma': 0.2666588368735955, 'min_child_weight': 3, 'reg_alpha': 0.4374964566548464, 'reg_lambda': 0.3443484894081728}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:30,835] Trial 63 finished with value: 0.14978207264499174 and parameters: {'n_estimators': 173, 'max_depth': 9, 'learning_rate': 0.04427588750706467, 'subsample': 0.8750602702397001, 'colsample_bytree': 0.8811490771946893, 'gamma': 0.3787140532751009, 'min_child_weight': 5, 'reg_alpha': 0.38067617339405635, 'reg_lambda': 0.2689801384990478}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:31,276] Trial 64 finished with value: 0.15499826540182682 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.024589813220830356, 'subsample': 0.8266273408964364, 'colsample_bytree': 0.6959865086828283, 'gamma': 0.29220878975559156, 'min_child_weight': 7, 'reg_alpha': 0.04885084063486045, 'reg_lambda': 0.20508278182601158}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:31,485] Trial 65 finished with value: 0.1496195204913683 and parameters: {'n_estimators': 182, 'max_depth': 9, 'learning_rate': 0.07088588860011139, 'subsample': 0.8617132124103102, 'colsample_bytree': 0.8704241747852631, 'gamma': 0.24071667633098764, 'min_child_weight': 6, 'reg_alpha': 0.11042087944692175, 'reg_lambda': 0.4684289169416641}. Best is trial 35 with value: 0.14935618216573407.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:34,952] Trial 79 finished with value: 0.14942552439551893 and parameters: {'n_estimators': 201, 'max_depth': 8, 'learning_rate': 0.09196650840531109, 'subsample': 0.8539707956299476, 'colsample_bytree': 0.9474897376385839, 'gamma': 0.1825723915373089, 'min_child_weight': 6, 'reg_alpha': 0.0891933113587639, 'reg_lambda': 0.36745800797724315}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:35,173] Trial 80 finished with value: 0.14953891048438733 and parameters: {'n_estimators': 262, 'max_depth': 8, 'learning_rate': 0.0912210634987349, 'subsample': 0.8577572621095964, 'colsample_bytree': 0.950195625261272, 'gamma': 0.18402702027748433, 'min_child_weight': 7, 'reg_alpha': 0.03312582425957783, 'reg_lambda': 0.35282426502000896}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:35,407] Trial 81 finished with value: 0.14931031632712266 and parameters: {'n_estimators': 211, 'max_depth': 8, 'learning_rate': 0.08241037970344724, 'subsample': 0.8812865814922174, 'colsample_bytree': 0.997975137927488, 'gamma': 0.10624434630558219, 'min_child_weight': 6, 'reg_alpha': 0.10045162257272501, 'reg_lambda': 0.3801422068608213}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:35,612] Trial 82 finished with value: 0.14950054439453786 and parameters: {'n_estimators': 194, 'max_depth': 7, 'learning_rate': 0.08903071480862913, 'subsample': 0.8824951146083928, 'colsample_bytree': 0.9933984820850149, 'gamma': 0.1064320040918885, 'min_child_weight': 6, 'reg_alpha': 0.09727731645796583, 'reg_lambda': 0.43553836066723783}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:35,839] Trial 83 finished with value: 0.1493646125553455 and parameters: {'n_estimators': 211, 'max_depth': 8, 'learning_rate': 0.0818839543644416, 'subsample': 0.8444443067117122, 'colsample_bytree': 0.9658599419065564, 'gamma': 0.12835969156869048, 'min_child_weight': 5, 'reg_alpha': 0.1479016512949478, 'reg_lambda': 0.4928872755559375}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:36,074] Trial 84 finished with value: 0.14930688041480109 and parameters: {'n_estimators': 229, 'max_depth': 8, 'learning_rate': 0.08333768096889967, 'subsample': 0.8489696640323378, 'colsample_bytree': 0.9600453721945768, 'gamma': 0.12982642813742967, 'min_child_weight': 5, 'reg_alpha': 0.13625546236692063, 'reg_lambda': 0.4858448734215464}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:36,259] Trial 85 finished with value: 0.14943685383600722 and parameters: {'n_estimators': 224, 'max_depth': 8, 'learning_rate': 0.07713082118363244, 'subsample': 0.8231928910477757, 'colsample_bytree': 0.9642031097595355, 'gamma': 0.08090938076286802, 'min_child_weight': 4, 'reg_alpha': 0.14487517617095802, 'reg_lambda': 0.4838090432267903}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:36,453] Trial 86 finished with value: 0.14957481025167133 and parameters: {'n_estimators': 207, 'max_depth': 7, 'learning_rate': 0.10935834317742434, 'subsample': 0.8510800064485076, 'colsample_bytree': 0.9431075824385924, 'gamma': 0.11295426308706003, 'min_child_weight': 5, 'reg_alpha': 0.13009149332497233, 'reg_lambda': 0.531942257216681}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:36,678] Trial 87 finished with value: 0.1493786332653251 and parameters: {'n_estimators': 217, 'max_depth': 8, 'learning_rate': 0.08182807686160874, 'subsample': 0.83956602660056, 'colsample_bytree': 0.9989818036377263, 'gamma': 0.14580202045410443, 'min_child_weight': 4, 'reg_alpha': 0.04922444257811512, 'reg_lambda': 0.593684273216286}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:36,921] Trial 88 finished with value: 0.14929734397432326 and parameters: {'n_estimators': 216, 'max_depth': 8, 'learning_rate': 0.06693428126712983, 'subsample': 0.8385201933476784, 'colsample_bytree': 0.9997734816921389, 'gamma': 0.14259544122137188, 'min_child_weight': 4, 'reg_alpha': 0.17425275794826797, 'reg_lambda': 0.590104481895981}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:37,173] Trial 89 finished with value: 0.14927974397766053 and parameters: {'n_estimators': 243, 'max_depth': 8, 'learning_rate': 0.06707927127142953, 'subsample': 0.8385896098062268, 'colsample_bytree': 0.9864799200843519, 'gamma': 0.1491699185571667, 'min_child_weight': 4, 'reg_alpha': 0.04993395859041713, 'reg_lambda': 0.5731410711881293}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:37,401] Trial 90 finished with value: 0.14962000601630407 and parameters: {'n_estimators': 246, 'max_depth': 7, 'learning_rate': 0.08153149517708694, 'subsample': 0.8127464360925394, 'colsample_bytree': 0.9852770581737355, 'gamma': 0.1399870244319762, 'min_child_weight': 4, 'reg_alpha': 0.050811251303254056, 'reg_lambda': 0.5998048318164573}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:37,645] Trial 91 finished with value: 0.1493111059175685 and parameters: {'n_estimators': 215, 'max_depth': 8, 'learning_rate': 0.06598512563498327, 'subsample': 0.8659023233061359, 'colsample_bytree': 0.9980534456582648, 'gamma': 0.15255511424607918, 'min_child_weight': 4, 'reg_alpha': 0.027758988173923554, 'reg_lambda': 0.5819118599947648}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:37,882] Trial 92 finished with value: 0.1494439171934171 and parameters: {'n_estimators': 216, 'max_depth': 8, 'learning_rate': 0.0672756412607146, 'subsample': 0.8004082913406474, 'colsample_bytree': 0.9984993335957578, 'gamma': 0.16618183089192337, 'min_child_weight': 3, 'reg_alpha': 0.02687163546470145, 'reg_lambda': 0.5691640033872899}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:38,104] Trial 93 finished with value: 0.14936799035977294 and parameters: {'n_estimators': 229, 'max_depth': 8, 'learning_rate': 0.0949386818947203, 'subsample': 0.8334964138125053, 'colsample_bytree': 0.9679562378219774, 'gamma': 0.12485118351371231, 'min_child_weight': 4, 'reg_alpha': 0.1144332454203929, 'reg_lambda': 0.6335250717895535}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:38,337] Trial 94 finished with value: 0.1494819796545392 and parameters: {'n_estimators': 229, 'max_depth': 8, 'learning_rate': 0.09683239274599177, 'subsample': 0.8653544491372127, 'colsample_bytree': 0.9711678113489781, 'gamma': 0.12291230862416493, 'min_child_weight': 4, 'reg_alpha': 0.17947605452571513, 'reg_lambda': 0.6761802670525391}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:38,671] Trial 95 finished with value: 0.149676958614639 and parameters: {'n_estimators': 251, 'max_depth': 7, 'learning_rate': 0.07323803369816761, 'subsample': 0.8336460247941172, 'colsample_bytree': 0.9664650024877064, 'gamma': 0.052545365928507656, 'min_child_weight': 3, 'reg_alpha': 0.11453553584228854, 'reg_lambda': 0.6527208857140361}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:38,942] Trial 96 finished with value: 0.14953183698195524 and parameters: {'n_estimators': 229, 'max_depth': 8, 'learning_rate': 0.06694024038716005, 'subsample': 0.8182679853222461, 'colsample_bytree': 0.917049252078027, 'gamma': 0.10419651347644501, 'min_child_weight': 4, 'reg_alpha': 0.151041734631582, 'reg_lambda': 0.6438338741827668}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:39,216] Trial 97 finished with value: 0.14989440443529184 and parameters: {'n_estimators': 239, 'max_depth': 7, 'learning_rate': 0.07477710780004342, 'subsample': 0.792927758260902, 'colsample_bytree': 0.960147990716464, 'gamma': 0.08270175516686575, 'min_child_weight': 4, 'reg_alpha': 0.06099900160353314, 'reg_lambda': 0.6189889253755452}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:39,363] Trial 98 finished with value: 0.15084527772791734 and parameters: {'n_estimators': 261, 'max_depth': 6, 'learning_rate': 0.10731041801635575, 'subsample': 0.8391629754542548, 'colsample_bytree': 0.985699237039704, 'gamma': 0.16193403028103465, 'min_child_weight': 3, 'reg_alpha': 0.10769959072472099, 'reg_lambda': 0.5718932938822566}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 21:53:39,578] Trial 99 finished with value: 0.1495768038398309 and parameters: {'n_estimators': 191, 'max_depth': 8, 'learning_rate': 0.09501117830152014, 'subsample': 0.8487835894428897, 'colsample_bytree': 0.9328244645915894, 'gamma': 0.09890448815475489, 'min_child_weight': 4, 'reg_alpha': 0.022305224669447288, 'reg_lambda': 0.493880997744673}. Best is trial 72 with value: 0.14924403410706633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'n_estimators': 176, 'max_depth': 8, 'learning_rate': 0.050859977729431634, 'subsample': 0.8721229765890861, 'colsample_bytree': 0.8872405422185361, 'gamma': 0.15684120115170655, 'min_child_weight': 4, 'reg_alpha': 0.13795914933052095, 'reg_lambda': 0.38642883792929195}
# Mean Absolute Error (MAE): 0.14924403410706633
# R² (Coefficient of Determination): 0.839258480388664
# Pearson's Correlation Coefficient (R): 0.9163300011492882
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.845892845129084

# %%
target_yearDf=pd.read_csv('target_yearDf.csv')

# %%
print(len(target_yearDf))
# Out:
# 4

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
target_xDf = target_yearDf[xColumnsToKeep]


target_yDf = target_yearDf[yColumnsToKeep]

# %%
# Print values in the specified format
#print(f"Model: {aModelList[0][2]}")  # Model name
print(f"Test Data (x): \n{target_xDf.head()}")  # Test features
print(f"Test Data (y): \n{target_yDf.head()}")  # Test targets
#print(f"N: {N}")  # Number of iterations
print(f"Train Data (x): \n{target_xDf.head()}")  # Training features
print(f"Train Data (y): \n{target_yDf.head()}")  # Training targets
#print(f"Working Directory: {workingDir}")
#print(f"Number of Features: {numFeatures}")

# Assuming 'xgbModel' is trained earlier in the pipeline
#xgb_model = xgb.XGBRegressor()
#xgb_model.fit(target_xDf, target_yDf.values.ravel())  # Fit model with training data
y_pred = pipe.predict(target_xDf)  # Predict on test data

# Compute metrics
mae = mean_absolute_error(target_yDf, y_pred)
r_squared = r2_score(target_yDf, y_pred)
r_score = np.corrcoef(target_yDf.values.flatten(), y_pred)[0, 1]


print("\nPerformance Metrics:")
print(f"Avg MAE: {mae}")
print(f"Avg R squared: {r_squared}")

print(f"R Score (Correlation): {r_score:.4f}")

# Scatter plot of true yield vs predicted yield
plt.figure(figsize=(8, 6))
plt.scatter(target_yDf, y_pred, alpha=0.6, label="True vs Predicted")
plt.plot([target_yDf.min(), target_yDf.max()], [target_yDf.min(), target_yDf.max()], 'r--', lw=2, label="Perfect Fit")
plt.xlabel("True Yield (tons/acre)")
plt.ylabel("Predicted Yield (tons/acre)")
plt.title("Scatter Plot: True vs Predicted Yield")
plt.legend()
plt.grid()
plt.show()
# Out:
# Test Data (x):
#    radiation     rain  avg_max_temp  avg_min_temp
# 0  139394.32  1558.36       14.0410        3.8191
# 1  128788.79  1489.74       13.4155        3.2282
# 2  163036.37  1766.96       15.5743        5.2067
# 3  150841.93  1573.22       14.8536        4.5008
# Test Data (y):
#       yield
# 0  1.387857
# 1  1.694643
# 2  1.457500
# 3  1.036071
# Train Data (x):
#    radiation     rain  avg_max_temp  avg_min_temp
# 0  139394.32  1558.36       14.0410        3.8191
# 1  128788.79  1489.74       13.4155        3.2282
# 2  163036.37  1766.96       15.5743        5.2067
# 3  150841.93  1573.22       14.8536        4.5008
# Train Data (y):
#       yield
# 0  1.387857
# 1  1.694643
# 2  1.457500
# 3  1.036071
#
# Performance Metrics:
# Avg MAE: 0.2778473198413849
# Avg R squared: -1.217374563217163
# R Score (Correlation): -0.5730

# %%
all_yearsDf=pd.read_csv("all_years.csv")

# %%
m1,r2=actualTest(all_yearsDf, target_yearDf, target_xDf, target_yDf, pipe)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.9774
# Date:                Thu, 03 Apr 2025   Prob (F-statistic):              0.427
# Time:                        21:54:09   Log-Likelihood:                0.89769
# No. Observations:                   4   AIC:                             2.205
# Df Residuals:                       2   BIC:                            0.9772
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.9655     28.900      1.037      0.409     -94.381     154.312
# x1           -17.3153     17.514     -0.989      0.427     -92.672      58.042
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.379
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.635
# Skew:                           0.848   Prob(JB):                        0.728
# Kurtosis:                       2.037   Cond. No.                         477.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 23.545%
# skt smape: 19.47%
# skt mae: 0.278
# skt mse: 0.123
# skt rmse: 0.351
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
def actualTest(all_yearsDf, target_yearDf, xTest, yTest, model):
    #print("Length of all_yearsDf----This is used for plotting graph ", len(all_yearsDf))
    #print("Length of final_yearDf-----This is used for adjusting the predicted values: ", len(final_yearDf))
    #print("Length of target_yearDf-------This is used for comparing predicted values to true values-----these are true values ", len(target_yearDf))
    #print("boost_xDf: ",len(boost_xDf))
    #print("boost_yDf: ", len(boost_yDf))
    #print("Length of xTest: ", len(xTest))
    #print("Length of yTest: ", len(yTest))
    #print("test results on our test data: ")
    #print(yTest)
    
    #model = model.fit(boost_xDf, boost_yDf, xgb_model=model.get_booster())
    # get predictions
    pred = model.predict(xTest)
    #trainPred = model.predict(xTrain)
    #print("Length of predictions are: ", len(pred))

    #adj_pred = []
    #for i in range(len(pred)):
    #    adj_pred.append(final_yearDf['yield'][i] + pred[i])
    #print('adjusted predictions: ')
    #print(adj_pred)
    #print("Predictions are: ")
    #print(pred)
    #print("Length of adjusted predictions: ", len(adj_pred))
    pred_Df = pd.DataFrame(pred)
    #print(adj_pred_Df)
    #adj_pred_Df=pd.DataFrame(pred)
    # find errors
    meanAbsoluteError = mean_absolute_error(target_yearDf['yield'], pred_Df)

#     plt.scatter(yTest, pred, label='Truth vs Prediction')
#     p1 = max(max(pred), max(yTest['Yield (tons/acre)']))
#     p2 = min(min(pred), min(yTest['Yield (tons/acre)']))
#     plt.plot([p1, p2], [p1, p2], color='k', label='Perfect Predictions')
#     plt.xlabel('True Yields')
#     plt.ylabel('Predicted Yields')
#     plt.legend()
    #print("Plotting--------")
    pred_ts = []
    len_tsDf = len(all_yearsDf)
    #print("len_tsDf----Length of all_yearsDf----", len_tsDf)
    for i in range(len_tsDf - len(pred), len_tsDf):
        pred_ts.append(i)
    #print("Length of pred_ts is: ", len(pred_ts))
    #print("This is the index calculated for plotting time-series graph: ", pred_ts)    
    pred_df = pd.DataFrame(pred, index = pred_ts, columns = ['yield'])
    #print("Lengths of all_yearsDf and Lengths of pred_Df are: ", len(all_yearsDf['yield']), len(pred_df))
    #print("Head and shape of pred_Df")
    #print(pred_df.head())  # Check structure
    #print(pred_df.shape)   # Compare with all_yearsDf
    #print(all_yearsDf.index)
    plot_series(pd.Series(all_yearsDf['yield']), pred_df, labels=["y", "y_pred"])


    #plt.figure(figsize=(10, 6))

    # Plot actual yield using its index
    #plt.plot(all_yearsDf.index, all_yearsDf['yield'], label="Actual Yield", linestyle="-", color="blue")

    # Plot predicted yield using its index (from pred_df)
    #plt.plot(pred_df.index, pred_df['yield'], label="Predicted Yield", linestyle="--", color="red")

    #plt.xlabel("Index")  # The x-axis will now be the index of each DataFrame
    #plt.ylabel("Yield")
    #plt.legend()
    #plt.title("Actual vs. Predicted Yield")
    #plt.show()

    # find the R values
    r = np.corrcoef(target_yearDf['yield'], pred)[0,1]
    
    # find the R^2 coefficient of determination
    # defining the variables
#     r2x = xTest.tolist()
#     r2y = yTest.tolist()

    # adding the constant term
    r2pred = sm.add_constant(pred)

    # performing the regression
    # and fitting the model
    yTargetYield = target_yearDf['yield']
    result = sm.OLS(yTargetYield, r2pred).fit()

    # printing the summary table
    print(result.summary())
    print('skt mape: ' + str(round(skt_mape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt smape: ' + str(round(skt_smape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt mae: ' + str(round(skt_mae(yTargetYield, pred_Df), 3)))
    print('skt mse: ' + str(round(skt_mse(yTargetYield, pred_Df), 3)))
    print('skt rmse: ' + str(round(math.sqrt(skt_mse(yTargetYield, pred_Df)), 3)) + '\n\n')
    
    #accuracy = accuracy_score(yTest, pred)
    
    return(meanAbsoluteError, r)
    

#     # add the errors and R Squared to average values
#     avgMAE += meanAbsoluteError
#     avgRSq += rSq

#     # check to see which metric should be optimized
#     if metricToOptimize == 'r2':
#         # check to see if any of these are the best values
#         if (rSq > bestRSq):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     elif metricToOptimize == 'mae':
#         # check to see if any of these are the best values
#         if (meanAbsoluteError < bestMAE):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     else:
#         raise ValueError("The input 'metricToOptimize' does not have a valid input. It must be 'r2' or 'mae'.")

# %%
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import joblib
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import math

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sktime.utils.plotting import plot_series

# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, matthews_corrcoef
from sktime.performance_metrics.forecasting import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVR  # support vector machines regression
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import AdaBoostRegressor # adaboost for regression
import xgboost as xgb

skt_mape = MeanAbsolutePercentageError(symmetric=False)
skt_smape = MeanAbsolutePercentageError(symmetric=True)
skt_mae = MeanAbsoluteError()
skt_mse = MeanSquaredError()
