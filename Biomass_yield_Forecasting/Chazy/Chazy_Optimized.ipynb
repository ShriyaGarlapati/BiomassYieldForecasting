# %%
############## imports
# general
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score  
# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVC  # support vector machines classification
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.neural_network import MLPClassifier # neural network for classification
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier # adaboost for classification
import xgboost as xgb
# saving models
# from sklearn.externals import joblib
import joblib
import matplotlib.pyplot as plt

# %%
import pandas as pd
import random
import math

# read in time point 1 for training
# train on it - model 1
# test on tp 2
# read tp 2
# add it to xgb - model 2
# test on tp 3
# read tp 3
# add it to xgb - model 3
# test on tp 4
# test model 1
data = pd.read_csv('data_no_2022_synthesized_nonstationary.csv')
data.head()
# Out:
#       yield      radiation         rain  avg_min_temp  avg_max_temp  class
# 0  0.809200  145274.020000  1297.630000      4.401100     15.289500      0
# 1  1.167907  203030.745814  2084.233023      4.758874     15.199581      0
# 2  1.113023  310635.705814  3084.353023      3.781560     14.165670      0
# 3  0.925263  338567.680000  3485.850000      3.229000     13.564300      0
# 4  0.620526  354783.880000  3698.570000      3.694600     14.047700      0

# %%
print(len(data))
# Out:
# 20050

# %%
data = data.rename(columns={'Yield (tons/acre)':'yield'})

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
xDf = data[xColumnsToKeep]


yDf = data[yColumnsToKeep]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression, SelectPercentile
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error


# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# XGBoost model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Create the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb_model)
])

# Train the pipeline
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Mean Squared Error (MSE)
#mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
#rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Absolute Error (MAE): 0.20882622728993222
# R² (Coefficient of Determination): 0.6545820289516127
# Pearson's Correlation Coefficient (R): 0.8096159798731012
# Symmetric Mean Absolute Percentage Error (SMAPE): 6.299452998195523

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile

# %%
# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array
# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Use cross-validation to evaluate the model (this ensures better generalization)
    score = cross_val_score(pipe, X_train, y_train, scoring='neg_mean_squared_error', cv=3)
    
    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return r2
    # Return the negative mean squared error (we want to minimize this)
    

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')  # Minimize RMSE or MSE
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)


# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-05 20:20:56,739] A new study created in memory with name: no-name-602d46e5-e750-436b-86bf-fb56bc22061d
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:20:57,170] Trial 0 finished with value: 0.6680569652601446 and parameters: {'n_estimators': 95, 'max_depth': 9, 'learning_rate': 0.17870855460010213, 'subsample': 0.5234576982910276, 'colsample_bytree': 0.7674781271143705, 'gamma': 0.4730441154117932, 'min_child_weight': 3, 'reg_alpha': 0.7742297968751634, 'reg_lambda': 0.6936075564909744}. Best is trial 0 with value: 0.6680569652601446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:20:57,421] Trial 1 finished with value: 0.6113888157441842 and parameters: {'n_estimators': 56, 'max_depth': 3, 'learning_rate': 0.15225141820703952, 'subsample': 0.8872497795261265, 'colsample_bytree': 0.5380284234427058, 'gamma': 0.24310899684953075, 'min_child_weight': 5, 'reg_alpha': 0.13753661773463233, 'reg_lambda': 0.09764872435299665}. Best is trial 0 with value: 0.6680569652601446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:20:58,867] Trial 2 finished with value: 0.6329584439719036 and parameters: {'n_estimators': 194, 'max_depth': 6, 'learning_rate': 0.01289633992067619, 'subsample': 0.5133051543159824, 'colsample_bytree': 0.7890116895296349, 'gamma': 0.21341178627270052, 'min_child_weight': 5, 'reg_alpha': 0.25730857805038576, 'reg_lambda': 0.7416276466453413}. Best is trial 0 with value: 0.6680569652601446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:20:59,244] Trial 3 finished with value: 0.49989416410146237 and parameters: {'n_estimators': 81, 'max_depth': 3, 'learning_rate': 0.024664369001576262, 'subsample': 0.8474426368485112, 'colsample_bytree': 0.8918890448628114, 'gamma': 0.12798313435849412, 'min_child_weight': 4, 'reg_alpha': 0.8836129967679981, 'reg_lambda': 0.20057640148880185}. Best is trial 0 with value: 0.6680569652601446.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:20:59,855] Trial 4 finished with value: 0.6691587392050544 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.09569275978178152, 'subsample': 0.55660601557979, 'colsample_bytree': 0.8205896386616796, 'gamma': 0.47094538650560774, 'min_child_weight': 6, 'reg_alpha': 0.2261634555752886, 'reg_lambda': 0.7562693474756114}. Best is trial 4 with value: 0.6691587392050544.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:00,327] Trial 5 finished with value: 0.674903478063633 and parameters: {'n_estimators': 137, 'max_depth': 8, 'learning_rate': 0.17391513296928238, 'subsample': 0.9596432288661483, 'colsample_bytree': 0.8322271228748213, 'gamma': 0.27424693034710534, 'min_child_weight': 5, 'reg_alpha': 0.6337961465378059, 'reg_lambda': 0.045706744883209915}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:01,035] Trial 6 finished with value: 0.6041474626869288 and parameters: {'n_estimators': 169, 'max_depth': 3, 'learning_rate': 0.05189971939913332, 'subsample': 0.6499117327391608, 'colsample_bytree': 0.7371679179496706, 'gamma': 0.4882858415206775, 'min_child_weight': 5, 'reg_alpha': 0.7720174576726455, 'reg_lambda': 0.309980844155456}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:02,574] Trial 7 finished with value: 0.6322383488418266 and parameters: {'n_estimators': 253, 'max_depth': 5, 'learning_rate': 0.02442682485095274, 'subsample': 0.8658251045379659, 'colsample_bytree': 0.5084660829674703, 'gamma': 0.029114360411463702, 'min_child_weight': 2, 'reg_alpha': 0.7650944439354614, 'reg_lambda': 0.10603273997583762}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:03,086] Trial 8 finished with value: 0.6123983887836528 and parameters: {'n_estimators': 124, 'max_depth': 3, 'learning_rate': 0.07799344823754577, 'subsample': 0.7766876168295129, 'colsample_bytree': 0.5149563412338316, 'gamma': 0.28744992553053217, 'min_child_weight': 3, 'reg_alpha': 0.8093147185544127, 'reg_lambda': 0.6582931061558615}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:03,648] Trial 9 finished with value: 0.6668651239449543 and parameters: {'n_estimators': 79, 'max_depth': 7, 'learning_rate': 0.07923596553529878, 'subsample': 0.6398653091673928, 'colsample_bytree': 0.9413075739157755, 'gamma': 0.429805074608498, 'min_child_weight': 8, 'reg_alpha': 0.7896393113883602, 'reg_lambda': 0.3200698681727474}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:04,486] Trial 10 finished with value: 0.6306877053420418 and parameters: {'n_estimators': 224, 'max_depth': 10, 'learning_rate': 0.14399676521761523, 'subsample': 0.9916200780496884, 'colsample_bytree': 0.6734473105524689, 'gamma': 0.3312924517089361, 'min_child_weight': 10, 'reg_alpha': 0.49424670816731353, 'reg_lambda': 0.9662892641978623}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:05,064] Trial 11 finished with value: 0.6712384471309691 and parameters: {'n_estimators': 146, 'max_depth': 8, 'learning_rate': 0.12387221780061272, 'subsample': 0.6553457909227105, 'colsample_bytree': 0.8595545776231608, 'gamma': 0.39232941089712553, 'min_child_weight': 7, 'reg_alpha': 0.5080326332682552, 'reg_lambda': 0.47763491714652423}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:05,832] Trial 12 finished with value: 0.6707477102228399 and parameters: {'n_estimators': 296, 'max_depth': 8, 'learning_rate': 0.1465789406674238, 'subsample': 0.6981390264250178, 'colsample_bytree': 0.9988482858416989, 'gamma': 0.3817484900120237, 'min_child_weight': 7, 'reg_alpha': 0.535120382138523, 'reg_lambda': 0.47796622256813115}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:06,274] Trial 13 finished with value: 0.6724090416354062 and parameters: {'n_estimators': 128, 'max_depth': 9, 'learning_rate': 0.1999544957112518, 'subsample': 0.9913164423769909, 'colsample_bytree': 0.8554342219955975, 'gamma': 0.352304947371818, 'min_child_weight': 9, 'reg_alpha': 0.5260755661088525, 'reg_lambda': 0.4569954127286733}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:06,831] Trial 14 finished with value: 0.6294597792773806 and parameters: {'n_estimators': 115, 'max_depth': 10, 'learning_rate': 0.19953411116408376, 'subsample': 0.9901451882337334, 'colsample_bytree': 0.6889527780564563, 'gamma': 0.21128259205016955, 'min_child_weight': 10, 'reg_alpha': 0.6160027813547404, 'reg_lambda': 0.35562317258376747}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:07,291] Trial 15 finished with value: 0.6733885703438104 and parameters: {'n_estimators': 191, 'max_depth': 9, 'learning_rate': 0.1881569717221587, 'subsample': 0.9290121020537564, 'colsample_bytree': 0.9018885353784047, 'gamma': 0.3252601445195994, 'min_child_weight': 9, 'reg_alpha': 0.3426646808155482, 'reg_lambda': 0.01398829650145924}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:07,980] Trial 16 finished with value: 0.6722295920692773 and parameters: {'n_estimators': 201, 'max_depth': 8, 'learning_rate': 0.16936387361481764, 'subsample': 0.9219648804077903, 'colsample_bytree': 0.9327271641063588, 'gamma': 0.12241728284502273, 'min_child_weight': 1, 'reg_alpha': 0.35937044659102624, 'reg_lambda': 0.02748153630888106}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:08,764] Trial 17 finished with value: 0.6628493971383058 and parameters: {'n_estimators': 241, 'max_depth': 5, 'learning_rate': 0.12273561740966613, 'subsample': 0.7845116112175614, 'colsample_bytree': 0.9435810353365255, 'gamma': 0.29548258258161186, 'min_child_weight': 8, 'reg_alpha': 0.04745103868253614, 'reg_lambda': 0.196501159814217}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:09,451] Trial 18 finished with value: 0.6745847948312867 and parameters: {'n_estimators': 179, 'max_depth': 9, 'learning_rate': 0.17581592859578812, 'subsample': 0.9236275588227623, 'colsample_bytree': 0.9977947917182473, 'gamma': 0.14819109963995314, 'min_child_weight': 6, 'reg_alpha': 0.3932152954020713, 'reg_lambda': 0.03879929218973188}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:21:10,177] Trial 19 finished with value: 0.6660384048412804 and parameters: {'n_estimators': 166, 'max_depth': 6, 'learning_rate': 0.1673178210018535, 'subsample': 0.8113467672385404, 'colsample_bytree': 0.9855145424035789, 'gamma': 0.14346355318061, 'min_child_weight': 6, 'reg_alpha': 0.647985284869165, 'reg_lambda': 0.19979512108798791}. Best is trial 5 with value: 0.674903478063633.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [W 2025-04-05 20:21:11,632] Trial 20 failed with parameters: {'n_estimators': 216, 'max_depth': 10, 'learning_rate': 0.11616138311281675, 'subsample': 0.9371805410359905, 'colsample_bytree': 0.6728356527970961, 'gamma': 0.040736288138902677, 'min_child_weight': 4, 'reg_alpha': 0.38654153206170666, 'reg_lambda': 0.5875577139631822} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/zn/_j79f2r529s6w4hp6tkpln8c0000gn/T/ipykernel_31023/1807375505.py", line 60, in objective
#     pipe.fit(X_train, y_train)
#     ~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/pipeline.py", line 662, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/sklearn.py", line 1247, in fit
#     self._Booster = train(
#                     ~~~~~^
#         params,
#         ^^^^^^^
#     ...<9 lines>...
#         callbacks=self.callbacks,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py", line 183, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#     ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py", line 2247, in update
#     _LIB.XGBoosterUpdateOneIter(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self.handle, ctypes.c_int(iteration), dtrain.handle
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# KeyboardInterrupt
# [W 2025-04-05 20:21:11,638] Trial 20 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 93
#      88     # Return the negative mean squared error (we want to minimize this)
#      89
#      90
#      91 # Create a study object and optimize the objective function
#      92 study = optuna.create_study(direction='maximize')  # Minimize RMSE or MSE
# ---> 93 study.optimize(objective, n_trials=100)  # Perform 100 trials
#      95 # Get the best hyperparameters found by Optuna
#      96 best_params = study.best_params
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[61], line 60, in objective(trial)
#      57 score = cross_val_score(pipe, X_train, y_train, scoring='neg_mean_squared_error', cv=3)
#      59 # Train the model on the training data
# ---> 60 pipe.fit(X_train, y_train)
#      62 # Make predictions
#      63 y_pred = pipe.predict(X_test)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/pipeline.py:662, in Pipeline.fit(self, X, y, **params)
#     656     if self._final_estimator != "passthrough":
#     657         last_step_params = self._get_metadata_for_step(
#     658             step_idx=len(self) - 1,
#     659             step_params=routed_params[self.steps[-1][0]],
#     660             all_params=params,
#     661         )
# --> 662         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     664 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/sklearn.py:1247, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1244 else:
#    1245     obj = None
# -> 1247 self._Booster = train(
#    1248     params,
#    1249     train_dmatrix,
#    1250     self.get_num_boosting_rounds(),
#    1251     evals=evals,
#    1252     early_stopping_rounds=self.early_stopping_rounds,
#    1253     evals_result=evals_result,
#    1254     obj=obj,
#    1255     custom_metric=metric,
#    1256     verbose_eval=verbose,
#    1257     xgb_model=model,
#    1258     callbacks=self.callbacks,
#    1259 )
#    1261 self._set_evaluation_result(evals_result)
#    1262 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/xgboost/core.py:2247, in Booster.update(self, dtrain, iteration, fobj)
#    2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
# -> 2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#    2251 else:
#    2252     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile
import numpy as np

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return mae

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize')  # Maximize the combined objective
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)

# Print evaluation metrics
mae = mean_absolute_error(y_test_flat, y_pred)
r2 = r2_score(y_test_flat, y_pred)
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]
smape_value = smape(y_test_flat, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-05 20:23:15,251] A new study created in memory with name: no-name-9b274fad-8581-443d-b701-4843422c432c
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:15,411] Trial 0 finished with value: 0.2260306063063163 and parameters: {'n_estimators': 285, 'max_depth': 4, 'learning_rate': 0.11268377469997005, 'subsample': 0.5031691176188632, 'colsample_bytree': 0.6386370224516549, 'gamma': 0.3871528928483896, 'min_child_weight': 3, 'reg_alpha': 0.27255400691871123, 'reg_lambda': 0.6560301394242909}. Best is trial 0 with value: 0.2260306063063163.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:15,580] Trial 1 finished with value: 0.22143162496038502 and parameters: {'n_estimators': 141, 'max_depth': 3, 'learning_rate': 0.11907772616579514, 'subsample': 0.6124526281430611, 'colsample_bytree': 0.9467280855427426, 'gamma': 0.03556762751210929, 'min_child_weight': 7, 'reg_alpha': 0.4708490241985911, 'reg_lambda': 0.5146151607156405}. Best is trial 1 with value: 0.22143162496038502.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:15,872] Trial 2 finished with value: 0.22131128423428478 and parameters: {'n_estimators': 183, 'max_depth': 8, 'learning_rate': 0.07428717603508656, 'subsample': 0.6519191228584085, 'colsample_bytree': 0.5692004811386433, 'gamma': 0.15943555507021995, 'min_child_weight': 10, 'reg_alpha': 0.49497651357596484, 'reg_lambda': 0.6523319422176888}. Best is trial 2 with value: 0.22131128423428478.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:15,972] Trial 3 finished with value: 0.20723537327634695 and parameters: {'n_estimators': 52, 'max_depth': 6, 'learning_rate': 0.18457615142913986, 'subsample': 0.7216333984415746, 'colsample_bytree': 0.7985758989564535, 'gamma': 0.22424900703253953, 'min_child_weight': 2, 'reg_alpha': 0.4892837648838668, 'reg_lambda': 0.5744582766823296}. Best is trial 3 with value: 0.20723537327634695.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:16,211] Trial 4 finished with value: 0.21137626338584567 and parameters: {'n_estimators': 244, 'max_depth': 5, 'learning_rate': 0.07259339152580224, 'subsample': 0.6365845902283519, 'colsample_bytree': 0.8926685398166453, 'gamma': 0.3349327036285898, 'min_child_weight': 10, 'reg_alpha': 0.2412369894486487, 'reg_lambda': 0.4394261498817661}. Best is trial 3 with value: 0.20723537327634695.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:16,348] Trial 5 finished with value: 0.22568396673118174 and parameters: {'n_estimators': 121, 'max_depth': 3, 'learning_rate': 0.14593560756678822, 'subsample': 0.6140386826829323, 'colsample_bytree': 0.8804457136636976, 'gamma': 0.34029835689974747, 'min_child_weight': 2, 'reg_alpha': 0.8328242484981588, 'reg_lambda': 0.23125401563761472}. Best is trial 3 with value: 0.20723537327634695.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:16,602] Trial 6 finished with value: 0.2223639762534274 and parameters: {'n_estimators': 243, 'max_depth': 7, 'learning_rate': 0.06837324207512321, 'subsample': 0.7565240257266508, 'colsample_bytree': 0.6396368049469194, 'gamma': 0.22934031672629585, 'min_child_weight': 8, 'reg_alpha': 0.7199951419895234, 'reg_lambda': 0.10553574591968151}. Best is trial 3 with value: 0.20723537327634695.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:16,988] Trial 7 finished with value: 0.20742548595602558 and parameters: {'n_estimators': 210, 'max_depth': 6, 'learning_rate': 0.030713974709599606, 'subsample': 0.6486555224696231, 'colsample_bytree': 0.9760397068229276, 'gamma': 0.258939506087798, 'min_child_weight': 1, 'reg_alpha': 0.680283537605631, 'reg_lambda': 0.19551573272022504}. Best is trial 3 with value: 0.20723537327634695.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,100] Trial 8 finished with value: 0.22984861484249855 and parameters: {'n_estimators': 170, 'max_depth': 3, 'learning_rate': 0.1040582936465058, 'subsample': 0.8859914924606518, 'colsample_bytree': 0.8371716876228879, 'gamma': 0.3715778047155801, 'min_child_weight': 4, 'reg_alpha': 0.8979518374018204, 'reg_lambda': 0.9495856506596413}. Best is trial 3 with value: 0.20723537327634695.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,199] Trial 9 finished with value: 0.2193006056985914 and parameters: {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.18892102638451694, 'subsample': 0.9759277569637645, 'colsample_bytree': 0.848109274030564, 'gamma': 0.36899981818232797, 'min_child_weight': 7, 'reg_alpha': 0.13814371664916747, 'reg_lambda': 0.41391410668539397}. Best is trial 3 with value: 0.20723537327634695.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,304] Trial 10 finished with value: 0.20645386294567444 and parameters: {'n_estimators': 61, 'max_depth': 10, 'learning_rate': 0.1989624188523225, 'subsample': 0.7939056534603209, 'colsample_bytree': 0.7504088071639895, 'gamma': 0.4969332306004946, 'min_child_weight': 5, 'reg_alpha': 0.02773775775764742, 'reg_lambda': 0.9497276757875226}. Best is trial 10 with value: 0.20645386294567444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,427] Trial 11 finished with value: 0.2257882431453106 and parameters: {'n_estimators': 51, 'max_depth': 10, 'learning_rate': 0.19843836310162466, 'subsample': 0.7913385736543412, 'colsample_bytree': 0.7415512176702851, 'gamma': 0.4937640081070982, 'min_child_weight': 5, 'reg_alpha': 0.0031236937613306377, 'reg_lambda': 0.9827550180190242}. Best is trial 10 with value: 0.20645386294567444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,521] Trial 12 finished with value: 0.205562953160048 and parameters: {'n_estimators': 51, 'max_depth': 10, 'learning_rate': 0.1692112468963437, 'subsample': 0.8573200273126946, 'colsample_bytree': 0.7520412387072554, 'gamma': 0.4962276361016046, 'min_child_weight': 4, 'reg_alpha': 0.391187393671271, 'reg_lambda': 0.7913867476768397}. Best is trial 12 with value: 0.205562953160048.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,675] Trial 13 finished with value: 0.22308430142004076 and parameters: {'n_estimators': 94, 'max_depth': 10, 'learning_rate': 0.15861575904107506, 'subsample': 0.8566356117171462, 'colsample_bytree': 0.7130947774012095, 'gamma': 0.49853933665723776, 'min_child_weight': 5, 'reg_alpha': 0.32622095737132834, 'reg_lambda': 0.8297386874079047}. Best is trial 12 with value: 0.205562953160048.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,824] Trial 14 finished with value: 0.22285993787098352 and parameters: {'n_estimators': 95, 'max_depth': 9, 'learning_rate': 0.16011550630462903, 'subsample': 0.8910582379409364, 'colsample_bytree': 0.6951963899997862, 'gamma': 0.44415696711397884, 'min_child_weight': 4, 'reg_alpha': 0.005103533658565598, 'reg_lambda': 0.816136892391233}. Best is trial 12 with value: 0.205562953160048.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:17,939] Trial 15 finished with value: 0.20519210168862617 and parameters: {'n_estimators': 90, 'max_depth': 9, 'learning_rate': 0.169811906863128, 'subsample': 0.9941121628154967, 'colsample_bytree': 0.8001314835963603, 'gamma': 0.4350514736279087, 'min_child_weight': 6, 'reg_alpha': 0.13515459105118488, 'reg_lambda': 0.8065438799414515}. Best is trial 15 with value: 0.20519210168862617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:18,054] Trial 16 finished with value: 0.2053042128757712 and parameters: {'n_estimators': 87, 'max_depth': 8, 'learning_rate': 0.1353675799011722, 'subsample': 0.9446087861711445, 'colsample_bytree': 0.802053886417102, 'gamma': 0.42978323477757757, 'min_child_weight': 7, 'reg_alpha': 0.34184288491160636, 'reg_lambda': 0.7945460083007846}. Best is trial 15 with value: 0.20519210168862617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:18,193] Trial 17 finished with value: 0.22388065795463788 and parameters: {'n_estimators': 96, 'max_depth': 8, 'learning_rate': 0.13626386965362755, 'subsample': 0.9996034015715807, 'colsample_bytree': 0.5140163836226439, 'gamma': 0.4251098901941943, 'min_child_weight': 8, 'reg_alpha': 0.19226715523774157, 'reg_lambda': 0.7195933857842212}. Best is trial 15 with value: 0.20519210168862617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:18,550] Trial 18 finished with value: 0.20729221574349543 and parameters: {'n_estimators': 123, 'max_depth': 8, 'learning_rate': 0.13048953698958055, 'subsample': 0.9636173777982894, 'colsample_bytree': 0.796755069201993, 'gamma': 0.009828407079705614, 'min_child_weight': 7, 'reg_alpha': 0.13449131442183376, 'reg_lambda': 0.8626577417327419}. Best is trial 15 with value: 0.20519210168862617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:18,715] Trial 19 finished with value: 0.20410977820428197 and parameters: {'n_estimators': 78, 'max_depth': 9, 'learning_rate': 0.09489846480092823, 'subsample': 0.9331161262901451, 'colsample_bytree': 0.9228921187854308, 'gamma': 0.29309154683376515, 'min_child_weight': 6, 'reg_alpha': 0.6551210253843682, 'reg_lambda': 0.3122895165452614}. Best is trial 19 with value: 0.20410977820428197.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:18,905] Trial 20 finished with value: 0.20363627834106726 and parameters: {'n_estimators': 121, 'max_depth': 9, 'learning_rate': 0.09374473476465475, 'subsample': 0.9242373113285849, 'colsample_bytree': 0.9259357708527709, 'gamma': 0.2898341282194241, 'min_child_weight': 6, 'reg_alpha': 0.6354200657893032, 'reg_lambda': 0.2866575234999179}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:19,085] Trial 21 finished with value: 0.2039958628735698 and parameters: {'n_estimators': 120, 'max_depth': 9, 'learning_rate': 0.09308003625585456, 'subsample': 0.922781549438314, 'colsample_bytree': 0.9173330192818459, 'gamma': 0.2832007033109937, 'min_child_weight': 6, 'reg_alpha': 0.6231580008638056, 'reg_lambda': 0.3211179507774576}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:19,308] Trial 22 finished with value: 0.20411765514587016 and parameters: {'n_estimators': 124, 'max_depth': 9, 'learning_rate': 0.0839017752752245, 'subsample': 0.900024100024896, 'colsample_bytree': 0.9308929469620637, 'gamma': 0.2862659959601718, 'min_child_weight': 6, 'reg_alpha': 0.6286312651620547, 'reg_lambda': 0.2989963273859472}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:19,584] Trial 23 finished with value: 0.20664108420760874 and parameters: {'n_estimators': 162, 'max_depth': 7, 'learning_rate': 0.04992682342565671, 'subsample': 0.930537808847022, 'colsample_bytree': 0.9853005175455943, 'gamma': 0.18265225517542344, 'min_child_weight': 8, 'reg_alpha': 0.6031121491321586, 'reg_lambda': 0.0026567299385339416}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:19,787] Trial 24 finished with value: 0.20380691951793023 and parameters: {'n_estimators': 121, 'max_depth': 9, 'learning_rate': 0.08741241475355782, 'subsample': 0.8475946618300377, 'colsample_bytree': 0.9167750533612485, 'gamma': 0.2976708011760945, 'min_child_weight': 6, 'reg_alpha': 0.7691663985548882, 'reg_lambda': 0.3373174010870261}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:20,094] Trial 25 finished with value: 0.2036776964276196 and parameters: {'n_estimators': 197, 'max_depth': 9, 'learning_rate': 0.05919719258330117, 'subsample': 0.8338890779805284, 'colsample_bytree': 0.8881410620969886, 'gamma': 0.1596311781926183, 'min_child_weight': 9, 'reg_alpha': 0.779742703270242, 'reg_lambda': 0.3622618640849465}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:20,568] Trial 26 finished with value: 0.22018037263186072 and parameters: {'n_estimators': 194, 'max_depth': 7, 'learning_rate': 0.013292305357162325, 'subsample': 0.8285495369564339, 'colsample_bytree': 0.9972110036465808, 'gamma': 0.12241649372523383, 'min_child_weight': 9, 'reg_alpha': 0.7638152375984795, 'reg_lambda': 0.40840123642773407}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:21,001] Trial 27 finished with value: 0.2044251223335594 and parameters: {'n_estimators': 217, 'max_depth': 8, 'learning_rate': 0.048105435252363625, 'subsample': 0.8153631950759987, 'colsample_bytree': 0.8706961972711262, 'gamma': 0.1318866222360147, 'min_child_weight': 9, 'reg_alpha': 0.9872117518735488, 'reg_lambda': 0.1988809687240798}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:21,405] Trial 28 finished with value: 0.2041917782431691 and parameters: {'n_estimators': 147, 'max_depth': 9, 'learning_rate': 0.05919516241440709, 'subsample': 0.743846070431774, 'colsample_bytree': 0.9589273357816066, 'gamma': 0.07426319215587074, 'min_child_weight': 9, 'reg_alpha': 0.8028362132518583, 'reg_lambda': 0.3392845960015907}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:21,713] Trial 29 finished with value: 0.2046217363260958 and parameters: {'n_estimators': 269, 'max_depth': 10, 'learning_rate': 0.10380105501094265, 'subsample': 0.6997807796405635, 'colsample_bytree': 0.9025469368094636, 'gamma': 0.19589720149805928, 'min_child_weight': 3, 'reg_alpha': 0.9047201059431972, 'reg_lambda': 0.5362118746229604}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:21,971] Trial 30 finished with value: 0.2083401591784276 and parameters: {'n_estimators': 195, 'max_depth': 7, 'learning_rate': 0.03232689323431893, 'subsample': 0.5293901174569178, 'colsample_bytree': 0.8427145962854304, 'gamma': 0.32488049696282284, 'min_child_weight': 8, 'reg_alpha': 0.8968168950707398, 'reg_lambda': 0.11732319973583549}. Best is trial 20 with value: 0.20363627834106726.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:22,172] Trial 31 finished with value: 0.20336146894949786 and parameters: {'n_estimators': 117, 'max_depth': 9, 'learning_rate': 0.08880004920985915, 'subsample': 0.8534981425282752, 'colsample_bytree': 0.9180886366189422, 'gamma': 0.27510300712031627, 'min_child_weight': 6, 'reg_alpha': 0.595380327819235, 'reg_lambda': 0.3772905351741841}. Best is trial 31 with value: 0.20336146894949786.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:22,350] Trial 32 finished with value: 0.20333980851939595 and parameters: {'n_estimators': 136, 'max_depth': 9, 'learning_rate': 0.11298085235951456, 'subsample': 0.8540572000011006, 'colsample_bytree': 0.9550531321859592, 'gamma': 0.24391204489823207, 'min_child_weight': 5, 'reg_alpha': 0.5739484880851696, 'reg_lambda': 0.4674707515688148}. Best is trial 32 with value: 0.20333980851939595.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:22,525] Trial 33 finished with value: 0.20504420947888496 and parameters: {'n_estimators': 140, 'max_depth': 8, 'learning_rate': 0.1159082948970822, 'subsample': 0.7777057558555802, 'colsample_bytree': 0.9557587263843542, 'gamma': 0.24841116148992215, 'min_child_weight': 5, 'reg_alpha': 0.5615124162114837, 'reg_lambda': 0.46302397622405256}. Best is trial 32 with value: 0.20333980851939595.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:22,708] Trial 34 finished with value: 0.2036951811698194 and parameters: {'n_estimators': 160, 'max_depth': 10, 'learning_rate': 0.11988942749920338, 'subsample': 0.8817692866983696, 'colsample_bytree': 0.9540424763841908, 'gamma': 0.19269958178447744, 'min_child_weight': 3, 'reg_alpha': 0.5472979505052757, 'reg_lambda': 0.5680751887674806}. Best is trial 32 with value: 0.20333980851939595.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:22,898] Trial 35 finished with value: 0.2032250168550522 and parameters: {'n_estimators': 135, 'max_depth': 9, 'learning_rate': 0.08116908448024142, 'subsample': 0.8188835133580558, 'colsample_bytree': 0.8733940791279511, 'gamma': 0.15040108560316678, 'min_child_weight': 4, 'reg_alpha': 0.44591146840900076, 'reg_lambda': 0.6347935729292575}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:23,164] Trial 36 finished with value: 0.20349239552357296 and parameters: {'n_estimators': 106, 'max_depth': 8, 'learning_rate': 0.07850396395138069, 'subsample': 0.811400893384174, 'colsample_bytree': 0.8637291327577449, 'gamma': 0.0714455304152865, 'min_child_weight': 4, 'reg_alpha': 0.44059235336205055, 'reg_lambda': 0.6642735167782717}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:23,453] Trial 37 finished with value: 0.20425729314770114 and parameters: {'n_estimators': 109, 'max_depth': 8, 'learning_rate': 0.07548052834968508, 'subsample': 0.7021568252279894, 'colsample_bytree': 0.8262800548312673, 'gamma': 0.08090933562925517, 'min_child_weight': 4, 'reg_alpha': 0.42700626685652854, 'reg_lambda': 0.6358400203911267}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:23,696] Trial 38 finished with value: 0.20866178103215913 and parameters: {'n_estimators': 137, 'max_depth': 5, 'learning_rate': 0.12264965039722069, 'subsample': 0.7548464482770675, 'colsample_bytree': 0.8671938159833534, 'gamma': 0.06809655870434028, 'min_child_weight': 2, 'reg_alpha': 0.47799220545172566, 'reg_lambda': 0.6398800502175748}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:23,953] Trial 39 finished with value: 0.20389933493771234 and parameters: {'n_estimators': 177, 'max_depth': 8, 'learning_rate': 0.10855679025247256, 'subsample': 0.7978871143679371, 'colsample_bytree': 0.8635829866298906, 'gamma': 0.12465491535650489, 'min_child_weight': 3, 'reg_alpha': 0.5360386741803899, 'reg_lambda': 0.4945076830527792}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:24,123] Trial 40 finished with value: 0.20754933100163248 and parameters: {'n_estimators': 107, 'max_depth': 6, 'learning_rate': 0.08208699910814102, 'subsample': 0.721623689442028, 'colsample_bytree': 0.8921376828916424, 'gamma': 0.21902142128271251, 'min_child_weight': 4, 'reg_alpha': 0.4166570480831692, 'reg_lambda': 0.7153390065388329}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:24,287] Trial 41 finished with value: 0.20413406096520179 and parameters: {'n_estimators': 68, 'max_depth': 9, 'learning_rate': 0.09922460461834379, 'subsample': 0.8628990239887666, 'colsample_bytree': 0.9471433626389432, 'gamma': 0.2612680297633619, 'min_child_weight': 5, 'reg_alpha': 0.684804271299578, 'reg_lambda': 0.5951156212838999}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:24,618] Trial 42 finished with value: 0.20376214723800087 and parameters: {'n_estimators': 106, 'max_depth': 9, 'learning_rate': 0.06862177470359668, 'subsample': 0.8147983377184851, 'colsample_bytree': 0.9772847413357163, 'gamma': 0.04868709203066102, 'min_child_weight': 4, 'reg_alpha': 0.506752356877992, 'reg_lambda': 0.7149801035651173}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:24,916] Trial 43 finished with value: 0.20364328537399534 and parameters: {'n_estimators': 134, 'max_depth': 10, 'learning_rate': 0.07684125878163688, 'subsample': 0.8750977961765164, 'colsample_bytree': 0.9297605636244566, 'gamma': 0.10278161634560953, 'min_child_weight': 5, 'reg_alpha': 0.5882562771880826, 'reg_lambda': 0.2631550085000991}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:25,117] Trial 44 finished with value: 0.20421105656100497 and parameters: {'n_estimators': 156, 'max_depth': 9, 'learning_rate': 0.08982740944613328, 'subsample': 0.9072955594438076, 'colsample_bytree': 0.8230132465777085, 'gamma': 0.3457514500750638, 'min_child_weight': 3, 'reg_alpha': 0.45207404343812807, 'reg_lambda': 0.4979892356411658}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:25,361] Trial 45 finished with value: 0.205702683289823 and parameters: {'n_estimators': 132, 'max_depth': 7, 'learning_rate': 0.06116391179050937, 'subsample': 0.8325989234863844, 'colsample_bytree': 0.9060495868874694, 'gamma': 0.1552573509452979, 'min_child_weight': 2, 'reg_alpha': 0.36787858532387435, 'reg_lambda': 0.3999651041135289}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:25,548] Trial 46 finished with value: 0.2217064429790634 and parameters: {'n_estimators': 78, 'max_depth': 8, 'learning_rate': 0.10743470587547158, 'subsample': 0.9599627427981746, 'colsample_bytree': 0.6375070571418744, 'gamma': 0.22234225783489686, 'min_child_weight': 5, 'reg_alpha': 0.5169273218973237, 'reg_lambda': 0.5528075815710596}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:25,744] Trial 47 finished with value: 0.20496540008582 and parameters: {'n_estimators': 112, 'max_depth': 10, 'learning_rate': 0.09724252912536252, 'subsample': 0.7767624766466613, 'colsample_bytree': 0.9996901184403029, 'gamma': 0.3163475984821172, 'min_child_weight': 7, 'reg_alpha': 0.28763518251602443, 'reg_lambda': 0.4451669190167426}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:26,165] Trial 48 finished with value: 0.20521773050206538 and parameters: {'n_estimators': 148, 'max_depth': 8, 'learning_rate': 0.08097837733713241, 'subsample': 0.9123082593665964, 'colsample_bytree': 0.7788862349036815, 'gamma': 0.002512707276174392, 'min_child_weight': 6, 'reg_alpha': 0.45958853283158996, 'reg_lambda': 0.6144033409655725}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:26,443] Trial 49 finished with value: 0.20439522367233387 and parameters: {'n_estimators': 165, 'max_depth': 10, 'learning_rate': 0.06806663455876466, 'subsample': 0.811657532455201, 'colsample_bytree': 0.9717762919710158, 'gamma': 0.26614947278697826, 'min_child_weight': 1, 'reg_alpha': 0.5741155821451923, 'reg_lambda': 0.26067389820964415}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:26,593] Trial 50 finished with value: 0.20390203911491364 and parameters: {'n_estimators': 99, 'max_depth': 9, 'learning_rate': 0.12784438963796366, 'subsample': 0.8453666132238074, 'colsample_bytree': 0.8574392037396613, 'gamma': 0.24208988582128774, 'min_child_weight': 4, 'reg_alpha': 0.6668831785316969, 'reg_lambda': 0.6942529833881582}. Best is trial 35 with value: 0.2032250168550522.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:26,885] Trial 51 finished with value: 0.202750140181202 and parameters: {'n_estimators': 132, 'max_depth': 10, 'learning_rate': 0.07849923642864118, 'subsample': 0.8820774095931057, 'colsample_bytree': 0.936165457725294, 'gamma': 0.10389338464339727, 'min_child_weight': 5, 'reg_alpha': 0.7121799741124646, 'reg_lambda': 0.25903012647533596}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:27,201] Trial 52 finished with value: 0.20441053254603628 and parameters: {'n_estimators': 131, 'max_depth': 10, 'learning_rate': 0.11219390217660899, 'subsample': 0.879409968375862, 'colsample_bytree': 0.9341410615242735, 'gamma': 0.05173605890831367, 'min_child_weight': 5, 'reg_alpha': 0.7051750344370058, 'reg_lambda': 0.37213118047681193}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:27,455] Trial 53 finished with value: 0.20312431808557957 and parameters: {'n_estimators': 114, 'max_depth': 10, 'learning_rate': 0.10189083965126178, 'subsample': 0.8570992801695669, 'colsample_bytree': 0.8956206893083121, 'gamma': 0.09508324575066907, 'min_child_weight': 6, 'reg_alpha': 0.7275410803584461, 'reg_lambda': 0.16284153279046998}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:27,629] Trial 54 finished with value: 0.20284994500711945 and parameters: {'n_estimators': 85, 'max_depth': 10, 'learning_rate': 0.10276921348451779, 'subsample': 0.8604937156629067, 'colsample_bytree': 0.8831399220460858, 'gamma': 0.1035789552744043, 'min_child_weight': 4, 'reg_alpha': 0.8554227182591094, 'reg_lambda': 0.1659902566323698}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:27,793] Trial 55 finished with value: 0.20354907625035748 and parameters: {'n_estimators': 83, 'max_depth': 10, 'learning_rate': 0.1481258363477358, 'subsample': 0.8714518140209172, 'colsample_bytree': 0.8833668975987702, 'gamma': 0.09824615340374603, 'min_child_weight': 5, 'reg_alpha': 0.7424515272289024, 'reg_lambda': 0.12399014254471191}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:28,055] Trial 56 finished with value: 0.20405060902603064 and parameters: {'n_estimators': 69, 'max_depth': 10, 'learning_rate': 0.1013272488240503, 'subsample': 0.8501730234305537, 'colsample_bytree': 0.9058584310741873, 'gamma': 0.023047011847559182, 'min_child_weight': 7, 'reg_alpha': 0.8435006068904233, 'reg_lambda': 0.1731145825280198}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:28,268] Trial 57 finished with value: 0.2043696222140165 and parameters: {'n_estimators': 113, 'max_depth': 10, 'learning_rate': 0.08766888072146756, 'subsample': 0.7872724021512228, 'colsample_bytree': 0.941238171458908, 'gamma': 0.14815330195764428, 'min_child_weight': 6, 'reg_alpha': 0.847080542139649, 'reg_lambda': 0.15595325817946373}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:28,498] Trial 58 finished with value: 0.20326424376679086 and parameters: {'n_estimators': 146, 'max_depth': 10, 'learning_rate': 0.11270052103987772, 'subsample': 0.8942921490676489, 'colsample_bytree': 0.9693257681074414, 'gamma': 0.10270821450436246, 'min_child_weight': 7, 'reg_alpha': 0.7230767081719969, 'reg_lambda': 0.04649201707823841}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:28,727] Trial 59 finished with value: 0.20373005312507894 and parameters: {'n_estimators': 174, 'max_depth': 10, 'learning_rate': 0.12576920612884226, 'subsample': 0.8993893629132208, 'colsample_bytree': 0.9679253044828218, 'gamma': 0.10207232605600924, 'min_child_weight': 7, 'reg_alpha': 0.7210996941441621, 'reg_lambda': 0.042125164989403927}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:28,971] Trial 60 finished with value: 0.2216288202661859 and parameters: {'n_estimators': 153, 'max_depth': 10, 'learning_rate': 0.14389885835944916, 'subsample': 0.9561492863438984, 'colsample_bytree': 0.6689463322451045, 'gamma': 0.17819471063045064, 'min_child_weight': 4, 'reg_alpha': 0.966138402914658, 'reg_lambda': 0.07073537668079033}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:29,187] Trial 61 finished with value: 0.20297010170855648 and parameters: {'n_estimators': 145, 'max_depth': 10, 'learning_rate': 0.10741846853281252, 'subsample': 0.8976609396020674, 'colsample_bytree': 0.9844776697247677, 'gamma': 0.0942580892346038, 'min_child_weight': 7, 'reg_alpha': 0.8154322172015546, 'reg_lambda': 0.2439565613708722}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:29,426] Trial 62 finished with value: 0.20315554654550683 and parameters: {'n_estimators': 142, 'max_depth': 10, 'learning_rate': 0.11320982801541696, 'subsample': 0.8918174689924164, 'colsample_bytree': 0.9846305649615348, 'gamma': 0.08803714253095711, 'min_child_weight': 7, 'reg_alpha': 0.8225157054143502, 'reg_lambda': 0.21404088871612806}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:29,646] Trial 63 finished with value: 0.20415100933335986 and parameters: {'n_estimators': 145, 'max_depth': 10, 'learning_rate': 0.13595296550495006, 'subsample': 0.8934224994339417, 'colsample_bytree': 0.9860556206125652, 'gamma': 0.09185388556202889, 'min_child_weight': 8, 'reg_alpha': 0.8196524725021931, 'reg_lambda': 0.22619020777562288}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:29,858] Trial 64 finished with value: 0.20320424019988584 and parameters: {'n_estimators': 143, 'max_depth': 10, 'learning_rate': 0.11871500031031504, 'subsample': 0.9362848245176766, 'colsample_bytree': 0.9866371410527462, 'gamma': 0.11565465083151646, 'min_child_weight': 7, 'reg_alpha': 0.8752162612351411, 'reg_lambda': 0.07017451047183391}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:30,135] Trial 65 finished with value: 0.2029934716693301 and parameters: {'n_estimators': 128, 'max_depth': 10, 'learning_rate': 0.1045908131204506, 'subsample': 0.9423224172945317, 'colsample_bytree': 0.9868425741981095, 'gamma': 0.040275361173184254, 'min_child_weight': 7, 'reg_alpha': 0.8871897244993938, 'reg_lambda': 0.14938780871381677}. Best is trial 51 with value: 0.202750140181202.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:33,552] Trial 79 finished with value: 0.20320187908464657 and parameters: {'n_estimators': 187, 'max_depth': 9, 'learning_rate': 0.14192047650524575, 'subsample': 0.990753412928214, 'colsample_bytree': 0.9216050787773974, 'gamma': 0.06304113871485278, 'min_child_weight': 5, 'reg_alpha': 0.9289748014941813, 'reg_lambda': 0.14173452695955482}. Best is trial 75 with value: 0.20226408401645296.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:33,901] Trial 80 finished with value: 0.2219204543477871 and parameters: {'n_estimators': 217, 'max_depth': 9, 'learning_rate': 0.12235722546423998, 'subsample': 0.9702280613448494, 'colsample_bytree': 0.5791104479658107, 'gamma': 0.03716808275650889, 'min_child_weight': 8, 'reg_alpha': 0.9028547105122384, 'reg_lambda': 0.2802938306040375}. Best is trial 75 with value: 0.20226408401645296.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:34,136] Trial 81 finished with value: 0.2021450508740201 and parameters: {'n_estimators': 203, 'max_depth': 9, 'learning_rate': 0.11761767901186672, 'subsample': 0.9559307865414625, 'colsample_bytree': 0.8994748444318422, 'gamma': 0.0764377275835009, 'min_child_weight': 6, 'reg_alpha': 0.8061567332324501, 'reg_lambda': 0.19744285852822838}. Best is trial 81 with value: 0.2021450508740201.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:34,371] Trial 82 finished with value: 0.20193318123843226 and parameters: {'n_estimators': 191, 'max_depth': 9, 'learning_rate': 0.11489202069501671, 'subsample': 0.9518955727754218, 'colsample_bytree': 0.9319123361784993, 'gamma': 0.07952763896748534, 'min_child_weight': 6, 'reg_alpha': 0.8117364682200425, 'reg_lambda': 0.19486611971009687}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:34,578] Trial 83 finished with value: 0.20222141620924036 and parameters: {'n_estimators': 200, 'max_depth': 9, 'learning_rate': 0.1322465677103036, 'subsample': 0.9985068515285739, 'colsample_bytree': 0.9316764327170184, 'gamma': 0.0801065418278043, 'min_child_weight': 7, 'reg_alpha': 0.810358489955603, 'reg_lambda': 0.19860867023336382}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:34,785] Trial 84 finished with value: 0.20274000496696637 and parameters: {'n_estimators': 204, 'max_depth': 9, 'learning_rate': 0.12955612857990634, 'subsample': 0.9846295625224629, 'colsample_bytree': 0.9228665414017264, 'gamma': 0.07757703675207787, 'min_child_weight': 6, 'reg_alpha': 0.8020812686776883, 'reg_lambda': 0.1333916129430806}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:34,977] Trial 85 finished with value: 0.20299432379157262 and parameters: {'n_estimators': 205, 'max_depth': 9, 'learning_rate': 0.15155526933058625, 'subsample': 0.9952838806888776, 'colsample_bytree': 0.9229112675737604, 'gamma': 0.07834679728028543, 'min_child_weight': 6, 'reg_alpha': 0.7582549387793086, 'reg_lambda': 0.10479496399767138}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:35,190] Trial 86 finished with value: 0.2032437723115476 and parameters: {'n_estimators': 233, 'max_depth': 9, 'learning_rate': 0.13223405299137786, 'subsample': 0.9606421828458577, 'colsample_bytree': 0.879768842918241, 'gamma': 0.139084878596568, 'min_child_weight': 5, 'reg_alpha': 0.7986299399088441, 'reg_lambda': 0.01295821573612499}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:35,391] Trial 87 finished with value: 0.2030391270317037 and parameters: {'n_estimators': 189, 'max_depth': 9, 'learning_rate': 0.14114490536789093, 'subsample': 0.9858952325991065, 'colsample_bytree': 0.8493935718828878, 'gamma': 0.07466186411965463, 'min_child_weight': 6, 'reg_alpha': 0.8217425863051274, 'reg_lambda': 0.20476071605905333}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:35,797] Trial 88 finished with value: 0.20676486428281246 and parameters: {'n_estimators': 215, 'max_depth': 9, 'learning_rate': 0.12791890863091984, 'subsample': 0.5774951907393227, 'colsample_bytree': 0.9094693781140306, 'gamma': 0.11249257600809148, 'min_child_weight': 5, 'reg_alpha': 0.7825961717724591, 'reg_lambda': 0.19099347670835135}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:35,953] Trial 89 finished with value: 0.20334586010117686 and parameters: {'n_estimators': 201, 'max_depth': 9, 'learning_rate': 0.15811847676571628, 'subsample': 0.9783872060376557, 'colsample_bytree': 0.9319418236405669, 'gamma': 0.0800836092449519, 'min_child_weight': 6, 'reg_alpha': 0.7493837464758895, 'reg_lambda': 0.3250436200379194}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:36,153] Trial 90 finished with value: 0.2042379955166515 and parameters: {'n_estimators': 225, 'max_depth': 8, 'learning_rate': 0.11672491793846534, 'subsample': 0.9998277717660871, 'colsample_bytree': 0.8952775179849932, 'gamma': 0.16913545138514585, 'min_child_weight': 5, 'reg_alpha': 0.8391350206795736, 'reg_lambda': 0.22864308239394726}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:36,374] Trial 91 finished with value: 0.20239646148727997 and parameters: {'n_estimators': 210, 'max_depth': 9, 'learning_rate': 0.12485030362264309, 'subsample': 0.950192474668324, 'colsample_bytree': 0.9359991522291832, 'gamma': 0.08826390228184676, 'min_child_weight': 7, 'reg_alpha': 0.9787498509025464, 'reg_lambda': 0.12447695968771377}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:36,602] Trial 92 finished with value: 0.20301773060046427 and parameters: {'n_estimators': 209, 'max_depth': 9, 'learning_rate': 0.12425481233164574, 'subsample': 0.9538641688086273, 'colsample_bytree': 0.9448926475034098, 'gamma': 0.08537557561500865, 'min_child_weight': 6, 'reg_alpha': 0.953481359777729, 'reg_lambda': 0.12995486723834937}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:36,798] Trial 93 finished with value: 0.2039411546873951 and parameters: {'n_estimators': 193, 'max_depth': 8, 'learning_rate': 0.13889365890366792, 'subsample': 0.9672369086892301, 'colsample_bytree': 0.8819620876930797, 'gamma': 0.0677344859782062, 'min_child_weight': 7, 'reg_alpha': 0.9697090695405521, 'reg_lambda': 0.1030428779274945}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:37,061] Trial 94 finished with value: 0.20272991855228448 and parameters: {'n_estimators': 251, 'max_depth': 9, 'learning_rate': 0.11619958792055163, 'subsample': 0.9267241631247827, 'colsample_bytree': 0.9151509839026112, 'gamma': 0.08986914390019217, 'min_child_weight': 6, 'reg_alpha': 0.8034036917624641, 'reg_lambda': 0.17748393292596099}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:37,211] Trial 95 finished with value: 0.20352751916318215 and parameters: {'n_estimators': 211, 'max_depth': 9, 'learning_rate': 0.13166552569084478, 'subsample': 0.9285033993151113, 'colsample_bytree': 0.9047741981262482, 'gamma': 0.1265635019505249, 'min_child_weight': 7, 'reg_alpha': 0.6904855152588637, 'reg_lambda': 0.17747564166668234}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:37,453] Trial 96 finished with value: 0.2029497870992224 and parameters: {'n_estimators': 266, 'max_depth': 8, 'learning_rate': 0.11658712161436802, 'subsample': 0.9524664304640322, 'colsample_bytree': 0.947476302303296, 'gamma': 0.10532169196458345, 'min_child_weight': 6, 'reg_alpha': 0.7747082873755635, 'reg_lambda': 0.19952377845860014}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:37,710] Trial 97 finished with value: 0.20305574993723124 and parameters: {'n_estimators': 261, 'max_depth': 8, 'learning_rate': 0.11600735728028774, 'subsample': 0.9532177097121314, 'colsample_bytree': 0.9467174622446126, 'gamma': 0.1147334922098516, 'min_child_weight': 5, 'reg_alpha': 0.7765659583511484, 'reg_lambda': 0.08232002901730937}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:37,919] Trial 98 finished with value: 0.20336483198218258 and parameters: {'n_estimators': 256, 'max_depth': 9, 'learning_rate': 0.1370050241766194, 'subsample': 0.9310269945210167, 'colsample_bytree': 0.9349514729786559, 'gamma': 0.14244165259447195, 'min_child_weight': 6, 'reg_alpha': 0.7994237162022473, 'reg_lambda': 0.04393751828639819}. Best is trial 82 with value: 0.20193318123843226.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 20:23:38,140] Trial 99 finished with value: 0.203651978686261 and parameters: {'n_estimators': 272, 'max_depth': 8, 'learning_rate': 0.12840366346627272, 'subsample': 0.9649691446188614, 'colsample_bytree': 0.9156922242589716, 'gamma': 0.10358658841539281, 'min_child_weight': 6, 'reg_alpha': 0.6603102411784867, 'reg_lambda': 0.12571826545538942}. Best is trial 82 with value: 0.20193318123843226.
# Best hyperparameters: {'n_estimators': 191, 'max_depth': 9, 'learning_rate': 0.11489202069501671, 'subsample': 0.9518955727754218, 'colsample_bytree': 0.9319123361784993, 'gamma': 0.07952763896748534, 'min_child_weight': 6, 'reg_alpha': 0.8117364682200425, 'reg_lambda': 0.19486611971009687}
# Mean Absolute Error (MAE): 0.20193318123843226
# R² (Coefficient of Determination): 0.6779604393817714
# Pearson's Correlation Coefficient (R): 0.8234386132198883
# Symmetric Mean Absolute Percentage Error (SMAPE): 6.086208501553166
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
target_yearDf=pd.read_csv('target_yearDf.csv')

# %%
print(len(target_yearDf))
# Out:
# 5

# %%
print(len(target_yearDf))
# Out:
# 5

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
target_xDf = target_yearDf[xColumnsToKeep]


target_yDf = target_yearDf[yColumnsToKeep]

# %%
# Print values in the specified format
#print(f"Model: {aModelList[0][2]}")  # Model name
print(f"Test Data (x): \n{target_xDf.head()}")  # Test features
print(f"Test Data (y): \n{target_yDf.head()}")  # Test targets
#print(f"N: {N}")  # Number of iterations
print(f"Train Data (x): \n{target_xDf.head()}")  # Training features
print(f"Train Data (y): \n{target_yDf.head()}")  # Training targets
#print(f"Working Directory: {workingDir}")
#print(f"Number of Features: {numFeatures}")

# Assuming 'xgbModel' is trained earlier in the pipeline
#xgb_model = xgb.XGBRegressor()
#xgb_model.fit(target_xDf, target_yDf.values.ravel())  # Fit model with training data
y_pred = pipe.predict(target_xDf)  # Predict on test data

# Compute metrics
mae = mean_absolute_error(target_yDf, y_pred)
r_squared = r2_score(target_yDf, y_pred)
r_score = np.corrcoef(target_yDf.values.flatten(), y_pred)[0, 1]


print("\nPerformance Metrics:")
print(f"Avg MAE: {mae}")
print(f"Avg R squared: {r_squared}")

print(f"R Score (Correlation): {r_score:.4f}")

# Scatter plot of true yield vs predicted yield
plt.figure(figsize=(8, 6))
plt.scatter(target_yDf, y_pred, alpha=0.6, label="True vs Predicted")
plt.plot([target_yDf.min(), target_yDf.max()], [target_yDf.min(), target_yDf.max()], 'r--', lw=2, label="Perfect Fit")
plt.xlabel("True Yield (tons/acre)")
plt.ylabel("Predicted Yield (tons/acre)")
plt.title("Scatter Plot: True vs Predicted Yield")
plt.legend()
plt.grid()
plt.show()
# Out:
# Test Data (x):
#        radiation         rain  avg_max_temp  avg_min_temp
# 0  332803.830000  2976.890000     13.933900      3.177600
# 1  362512.740000  3171.580000     14.866300      4.027300
# 2  343470.115070  3020.184287     14.274653      3.460948
# 3  345866.210000  3029.910000     14.351200      3.524600
# 4  349533.590373  3061.121176     14.464681      3.635349
# Test Data (y):
#       yield
# 0  3.160833
# 1  1.452500
# 2  1.991104
# 3  1.728333
# 4  1.667565
# Train Data (x):
#        radiation         rain  avg_max_temp  avg_min_temp
# 0  332803.830000  2976.890000     13.933900      3.177600
# 1  362512.740000  3171.580000     14.866300      4.027300
# 2  343470.115070  3020.184287     14.274653      3.460948
# 3  345866.210000  3029.910000     14.351200      3.524600
# 4  349533.590373  3061.121176     14.464681      3.635349
# Train Data (y):
#       yield
# 0  3.160833
# 1  1.452500
# 2  1.991104
# 3  1.728333
# 4  1.667565
#
# Performance Metrics:
# Avg MAE: 1.0520741939544678
# Avg R squared: -2.948740005493164
# R Score (Correlation): 0.7338

# %%
all_yearsDf=pd.read_csv("all_years.csv")

# %%
m1,r2=actualTest(all_yearsDf, target_yearDf, target_xDf, target_yDf, pipe)
# Out:
# 1.0556280745646027
# R:  0.6446789359643905
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     2.134
# Date:                Sat, 05 Apr 2025   Prob (F-statistic):              0.240
# Time:                        11:39:42   Log-Likelihood:                -3.2412
# No. Observations:                   5   AIC:                             10.48
# Df Residuals:                       3   BIC:                             9.701
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -13.6422     10.712     -1.274      0.293     -47.733      20.449
# x1            16.5625     11.339      1.461      0.240     -19.523      52.648
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.012
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.616
# Skew:                          -0.824   Prob(JB):                        0.735
# Kurtosis:                       2.510   Cond. No.                         80.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 49.418%
# skt smape: 67.294%
# skt mae: 1.056
# skt mse: 1.463
# skt rmse: 1.209
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
def actualTest(all_yearsDf, target_yearDf, xTest, yTest, model):
    #print("Length of all_yearsDf----This is used for plotting graph ", len(all_yearsDf))
    #print("Length of final_yearDf-----This is used for adjusting the predicted values: ", len(final_yearDf))
    #print("Length of target_yearDf-------This is used for comparing predicted values to true values-----these are true values ", len(target_yearDf))
    #print("boost_xDf: ",len(boost_xDf))
    #print("boost_yDf: ", len(boost_yDf))
    #print("Length of xTest: ", len(xTest))
    #print("Length of yTest: ", len(yTest))
    #print("test results on our test data: ")
    #print(yTest)
    
    #model = model.fit(boost_xDf, boost_yDf, xgb_model=model.get_booster())
    # get predictions
    pred = model.predict(xTest)
    #trainPred = model.predict(xTrain)
    #print("Length of predictions are: ", len(pred))

    #adj_pred = []
    #for i in range(len(pred)):
    #    adj_pred.append(final_yearDf['yield'][i] + pred[i])
    #print('adjusted predictions: ')
    #print(adj_pred)
    #print("Predictions are: ")
    #print(pred)
    #print("Length of adjusted predictions: ", len(adj_pred))
    pred_Df = pd.DataFrame(pred)
    #print(adj_pred_Df)
    #adj_pred_Df=pd.DataFrame(pred)
    # find errors
    meanAbsoluteError = mean_absolute_error(target_yearDf['yield'], pred_Df)
    print(meanAbsoluteError)
#     plt.scatter(yTest, pred, label='Truth vs Prediction')
#     p1 = max(max(pred), max(yTest['Yield (tons/acre)']))
#     p2 = min(min(pred), min(yTest['Yield (tons/acre)']))
#     plt.plot([p1, p2], [p1, p2], color='k', label='Perfect Predictions')
#     plt.xlabel('True Yields')
#     plt.ylabel('Predicted Yields')
#     plt.legend()
    #print("Plotting--------")
    pred_ts = []
    len_tsDf = len(all_yearsDf)
    #print("len_tsDf----Length of all_yearsDf----", len_tsDf)
    for i in range(len_tsDf - len(pred), len_tsDf):
        pred_ts.append(i)
    #print("Length of pred_ts is: ", len(pred_ts))
    #print("This is the index calculated for plotting time-series graph: ", pred_ts)    
    pred_df = pd.DataFrame(pred, index = pred_ts, columns = ['yield'])
    #print("Lengths of all_yearsDf and Lengths of pred_Df are: ", len(all_yearsDf['yield']), len(pred_df))
    #print("Head and shape of pred_Df")
    #print(pred_df.head())  # Check structure
    #print(pred_df.shape)   # Compare with all_yearsDf
    #print(all_yearsDf.index)
    plot_series(pd.Series(all_yearsDf['yield']), pred_df, labels=["y", "y_pred"])


    #plt.figure(figsize=(10, 6))

    # Plot actual yield using its index
    #plt.plot(all_yearsDf.index, all_yearsDf['yield'], label="Actual Yield", linestyle="-", color="blue")

    # Plot predicted yield using its index (from pred_df)
    #plt.plot(pred_df.index, pred_df['yield'], label="Predicted Yield", linestyle="--", color="red")

    #plt.xlabel("Index")  # The x-axis will now be the index of each DataFrame
    #plt.ylabel("Yield")
    #plt.legend()
    #plt.title("Actual vs. Predicted Yield")
    #plt.show()

    # find the R values
    r = np.corrcoef(target_yearDf['yield'], pred)[0,1]
    print("R: ", r)
    # find the R^2 coefficient of determination
    # defining the variables
#     r2x = xTest.tolist()
#     r2y = yTest.tolist()

    # adding the constant term
    r2pred = sm.add_constant(pred)

    # performing the regression
    # and fitting the model
    yTargetYield = target_yearDf['yield']
    result = sm.OLS(yTargetYield, r2pred).fit()

    # printing the summary table
    print(result.summary())
    print('skt mape: ' + str(round(skt_mape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt smape: ' + str(round(skt_smape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt mae: ' + str(round(skt_mae(yTargetYield, pred_Df), 3)))
    print('skt mse: ' + str(round(skt_mse(yTargetYield, pred_Df), 3)))
    print('skt rmse: ' + str(round(math.sqrt(skt_mse(yTargetYield, pred_Df)), 3)) + '\n\n')
    
    #accuracy = accuracy_score(yTest, pred)
    
    return(meanAbsoluteError, r)
    

#     # add the errors and R Squared to average values
#     avgMAE += meanAbsoluteError
#     avgRSq += rSq

#     # check to see which metric should be optimized
#     if metricToOptimize == 'r2':
#         # check to see if any of these are the best values
#         if (rSq > bestRSq):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     elif metricToOptimize == 'mae':
#         # check to see if any of these are the best values
#         if (meanAbsoluteError < bestMAE):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     else:
#         raise ValueError("The input 'metricToOptimize' does not have a valid input. It must be 'r2' or 'mae'.")

# %%
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import joblib
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import math

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sktime.utils.plotting import plot_series

# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, matthews_corrcoef
from sktime.performance_metrics.forecasting import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVR  # support vector machines regression
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import AdaBoostRegressor # adaboost for regression
import xgboost as xgb

skt_mape = MeanAbsolutePercentageError(symmetric=False)
skt_smape = MeanAbsolutePercentageError(symmetric=True)
skt_mae = MeanAbsoluteError()
skt_mse = MeanSquaredError()

# %%
all_yearsDf_Cobleskill=pd.read_csv("all_years_Cobleskill.csv")

# %%
all_yearsDf_LeRoy=pd.read_csv("all_years_LeRoy.csv")

# %%
all_yearsDf_Perry=pd.read_csv("all_years_Perry.csv")

# %%
mae,r=actualTest_nonlocal(all_yearsDf_LeRoy, pipe)
print("MAE: ", mae)
print("R: ", r)
# Out:
# MAE:  0.47119625777834706
# R value is:  0.24067309807782977
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                 -0.036
# Method:                 Least Squares   F-statistic:                    0.6148
# Date:                Sat, 05 Apr 2025   Prob (F-statistic):              0.451
# Time:                        11:44:11   Log-Likelihood:                -11.563
# No. Observations:                  12   AIC:                             27.13
# Df Residuals:                      10   BIC:                             28.10
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9826      0.828      1.187      0.263      -0.862       2.827
# x1             0.4397      0.561      0.784      0.451      -0.810       1.689
# ==============================================================================
# Omnibus:                        1.982   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.371   Jarque-Bera (JB):                0.710
# Skew:                           0.594   Prob(JB):                        0.701
# Kurtosis:                       3.091   Cond. No.                         8.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 31.435%
# skt smape: 29.505%
# skt mae: 0.471
# skt mse: 0.475
# skt rmse: 0.689
#
#
# MAE:  0.47119625777834706
# R:  0.24067309807782977
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=12 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
mae, r=actualTest(all_yearsDf_Cobleskill,pipe)
# Out:
# MAE:  0.6354405926410635
# R value is:  -0.05964777274088203
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.1928
# Date:                Fri, 04 Apr 2025   Prob (F-statistic):              0.662
# Time:                        23:02:14   Log-Likelihood:                -44.505
# No. Observations:                  56   AIC:                             93.01
# Df Residuals:                      54   BIC:                             97.06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0752      0.335      6.191      0.000       1.403       2.747
# x1            -0.0931      0.212     -0.439      0.662      -0.518       0.332
# ==============================================================================
# Omnibus:                        3.364   Durbin-Watson:                   1.659
# Prob(Omnibus):                  0.186   Jarque-Bera (JB):                1.704
# Skew:                           0.002   Prob(JB):                        0.427
# Kurtosis:                       2.145   Cond. No.                         10.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 32.052%
# skt smape: 36.201%
# skt mae: 0.635
# skt mse: 0.579
# skt rmse: 0.761
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
mae,r=actualTest_nonlocal(all_yearsDf_Perry,pipe)
print("MAE: ", mae)
print("R: ", r)
# Out:
# MAE:  0.35180552787100494
# R value is:  0.4821684536328193
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.190
# Method:                 Least Squares   F-statistic:                     5.452
# Date:                Sat, 05 Apr 2025   Prob (F-statistic):             0.0313
# Time:                        11:53:19   Log-Likelihood:                -10.622
# No. Observations:                  20   AIC:                             25.24
# Df Residuals:                      18   BIC:                             27.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5545      0.467      1.186      0.251      -0.428       1.537
# x1             0.6898      0.295      2.335      0.031       0.069       1.310
# ==============================================================================
# Omnibus:                        1.118   Durbin-Watson:                   1.355
# Prob(Omnibus):                  0.572   Jarque-Bera (JB):                0.982
# Skew:                           0.353   Prob(JB):                        0.612
# Kurtosis:                       2.175   Cond. No.                         10.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 22.597%
# skt smape: 22.803%
# skt mae: 0.352
# skt mse: 0.185
# skt rmse: 0.43
#
#
# MAE:  0.35180552787100494
# R:  0.4821684536328193
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
def actualTest_nonlocal(all_yearsDf, model):
    #print("Length of all_yearsDf----This is used for plotting graph ", len(all_yearsDf))
    #print("Length of final_yearDf-----This is used for adjusting the predicted values: ", len(final_yearDf))
    #print("Length of target_yearDf-------This is used for comparing predicted values to true values-----these are true values ", len(target_yearDf))
    #print("boost_xDf: ",len(boost_xDf))
    #print("boost_yDf: ", len(boost_yDf))
    #print("Length of xTest: ", len(xTest))
    #print("Length of yTest: ", len(yTest))
    #print("test results on our test data: ")
    #print(yTest)
    xTest = all_yearsDf[["radiation", "rain", "avg_max_temp", "avg_min_temp"]]
    yTest=all_yearsDf[["yield"]]
    #model = model.fit(boost_xDf, boost_yDf, xgb_model=model.get_booster())
    # get predictions
    pred = model.predict(xTest)
    #trainPred = model.predict(xTrain)
    #print("Length of predictions are: ", len(pred))

    #adj_pred = []
    #for i in range(len(pred)):
    #    adj_pred.append(final_yearDf['yield'][i] + pred[i])
    #print('adjusted predictions: ')
    #print(adj_pred)
    #print("Predictions are: ")
    #print(pred)
    #print("Length of adjusted predictions: ", len(adj_pred))
    pred_Df = pd.DataFrame(pred)
    #print(adj_pred_Df)
    #adj_pred_Df=pd.DataFrame(pred)
    # find errors
    meanAbsoluteError = mean_absolute_error(yTest, pred_Df)
    print("MAE: ", meanAbsoluteError)
#     plt.scatter(yTest, pred, label='Truth vs Prediction')
#     p1 = max(max(pred), max(yTest['Yield (tons/acre)']))
#     p2 = min(min(pred), min(yTest['Yield (tons/acre)']))
#     plt.plot([p1, p2], [p1, p2], color='k', label='Perfect Predictions')
#     plt.xlabel('True Yields')
#     plt.ylabel('Predicted Yields')
#     plt.legend()
    #print("Plotting--------")
    pred_ts = []
    len_tsDf = len(all_yearsDf)
    #print("len_tsDf----Length of all_yearsDf----", len_tsDf)
    for i in range(len_tsDf - len(pred), len_tsDf):
        pred_ts.append(i)
    #print("Length of pred_ts is: ", len(pred_ts))
    #print("This is the index calculated for plotting time-series graph: ", pred_ts)    
    pred_df = pd.DataFrame(pred, index = pred_ts, columns = ['yield'])
    #print("Lengths of all_yearsDf and Lengths of pred_Df are: ", len(all_yearsDf['yield']), len(pred_df))
    #print("Head and shape of pred_Df")
    #print(pred_df.head())  # Check structure
    #print(pred_df.shape)   # Compare with all_yearsDf
    #print(all_yearsDf.index)
    plot_series(pd.Series(all_yearsDf['yield']), pred_df, labels=["y", "y_pred"])


    #plt.figure(figsize=(10, 6))

    # Plot actual yield using its index
    #plt.plot(all_yearsDf.index, all_yearsDf['yield'], label="Actual Yield", linestyle="-", color="blue")

    # Plot predicted yield using its index (from pred_df)
    #plt.plot(pred_df.index, pred_df['yield'], label="Predicted Yield", linestyle="--", color="red")

    #plt.xlabel("Index")  # The x-axis will now be the index of each DataFrame
    #plt.ylabel("Yield")
    #plt.legend()
    #plt.title("Actual vs. Predicted Yield")
    #plt.show()

    # find the R values
    r = np.corrcoef(all_yearsDf['yield'], pred)[0,1]
    print("R value is: ", r)
    # find the R^2 coefficient of determination
    # defining the variables
#     r2x = xTest.tolist()
#     r2y = yTest.tolist()

    # adding the constant term
    r2pred = sm.add_constant(pred)
    
    # performing the regression
    # and fitting the model
    yTargetYield = all_yearsDf['yield']
    result = sm.OLS(yTargetYield, r2pred).fit()

    # printing the summary table
    print(result.summary())
    print('skt mape: ' + str(round(skt_mape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt smape: ' + str(round(skt_smape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt mae: ' + str(round(skt_mae(yTargetYield, pred_Df), 3)))
    print('skt mse: ' + str(round(skt_mse(yTargetYield, pred_Df), 3)))
    print('skt rmse: ' + str(round(math.sqrt(skt_mse(yTargetYield, pred_Df)), 3)) + '\n\n')
    
    #accuracy = accuracy_score(yTest, pred)
    
    return(meanAbsoluteError, r)
    

#     # add the errors and R Squared to average values
#     avgMAE += meanAbsoluteError
#     avgRSq += rSq

#     # check to see which metric should be optimized
#     if metricToOptimize == 'r2':
#         # check to see if any of these are the best values
#         if (rSq > bestRSq):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     elif metricToOptimize == 'mae':
#         # check to see if any of these are the best values
#         if (meanAbsoluteError < bestMAE):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     else:
#         raise ValueError("The input 'metricToOptimize' does not have a valid input. It must be 'r2' or 'mae'.")
