# %%
############## imports
# general
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score  
# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVC  # support vector machines classification
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.neural_network import MLPClassifier # neural network for classification
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier # adaboost for classification
import xgboost as xgb
# saving models
# from sklearn.externals import joblib
import joblib
import matplotlib.pyplot as plt

# %%
import pandas as pd
import random
import math

# read in time point 1 for training
# train on it - model 1
# test on tp 2
# read tp 2
# add it to xgb - model 2
# test on tp 3
# read tp 3
# add it to xgb - model 3
# test on tp 4
# test model 1
data = pd.read_csv('data_no_2022_synthesized_nonstationary.csv')
data.head()
# Out:
#       yield      radiation         rain  avg_min_temp  avg_max_temp  class
# 0  1.171667  348407.310000  3980.270000      1.541400     13.087000      0
# 1  1.309167  361326.060000  4070.120000      1.832000     13.404900      0
# 2  0.736667  389742.630000  4309.980000      2.660600     14.300500      0
# 3  1.080919   50713.795823   731.511134     11.641739     23.182754      0
# 4  1.040800   51755.170000   743.940000     11.648900     23.193700      0

# %%
print(len(data))
# Out:
# 20053

# %%
data = data.rename(columns={'Yield (tons/acre)':'yield'})

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
xDf = data[xColumnsToKeep]


yDf = data[yColumnsToKeep]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression, SelectPercentile
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error


# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# XGBoost model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Create the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb_model)
])

# Train the pipeline
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Mean Squared Error (MSE)
#mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
#rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Absolute Error (MAE): 0.17875058421973192
# R² (Coefficient of Determination): 0.7403184065525219
# Pearson's Correlation Coefficient (R): 0.8607051684003988
# Symmetric Mean Absolute Percentage Error (SMAPE): 5.042809104366764

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile
import numpy as np

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return mae

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize')  # Maximize the combined objective
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)

# Print evaluation metrics
mae = mean_absolute_error(y_test_flat, y_pred)
r2 = r2_score(y_test_flat, y_pred)
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]
smape_value = smape(y_test_flat, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-19 10:17:39,607] A new study created in memory with name: no-name-2637da3e-943b-4e17-9471-9353b23ea443
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:39,765] Trial 0 finished with value: 0.17567249392720982 and parameters: {'n_estimators': 136, 'max_depth': 9, 'learning_rate': 0.15053834906081745, 'subsample': 0.7769915258523636, 'colsample_bytree': 0.8058943137161309, 'gamma': 0.2383256747484267, 'min_child_weight': 2, 'reg_alpha': 0.5056082569495589, 'reg_lambda': 0.1505385961975917}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:39,953] Trial 1 finished with value: 0.21329482938515615 and parameters: {'n_estimators': 106, 'max_depth': 5, 'learning_rate': 0.027226640228124783, 'subsample': 0.5434756267274199, 'colsample_bytree': 0.6931728623486603, 'gamma': 0.18454135173938246, 'min_child_weight': 4, 'reg_alpha': 0.6070066039438676, 'reg_lambda': 0.5410017623389943}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:40,139] Trial 2 finished with value: 0.17754109209810903 and parameters: {'n_estimators': 136, 'max_depth': 4, 'learning_rate': 0.0710212794345186, 'subsample': 0.6158957676146355, 'colsample_bytree': 0.7892795551591039, 'gamma': 0.16883892918651477, 'min_child_weight': 10, 'reg_alpha': 0.4088690593420117, 'reg_lambda': 0.4867793253008602}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:40,464] Trial 3 finished with value: 0.1861755757999384 and parameters: {'n_estimators': 209, 'max_depth': 4, 'learning_rate': 0.04754326072118497, 'subsample': 0.8759376387564112, 'colsample_bytree': 0.6047909650653023, 'gamma': 0.035445131955143316, 'min_child_weight': 5, 'reg_alpha': 0.5663694704026421, 'reg_lambda': 0.8444294494444089}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:40,710] Trial 4 finished with value: 0.1853130814073316 and parameters: {'n_estimators': 211, 'max_depth': 4, 'learning_rate': 0.07266924354944866, 'subsample': 0.627283895266237, 'colsample_bytree': 0.6296954665847889, 'gamma': 0.18212595471080545, 'min_child_weight': 8, 'reg_alpha': 0.3181217118547237, 'reg_lambda': 0.04615198913313978}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:41,330] Trial 5 finished with value: 0.17878214345280952 and parameters: {'n_estimators': 247, 'max_depth': 7, 'learning_rate': 0.015644533711951427, 'subsample': 0.6002654691157074, 'colsample_bytree': 0.8980655313033465, 'gamma': 0.2177291686446749, 'min_child_weight': 9, 'reg_alpha': 0.19682940773070967, 'reg_lambda': 0.20457076258056617}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:41,450] Trial 6 finished with value: 0.18989444185949497 and parameters: {'n_estimators': 78, 'max_depth': 4, 'learning_rate': 0.09124924828599575, 'subsample': 0.5260477690827916, 'colsample_bytree': 0.6639495479966877, 'gamma': 0.25278713836588806, 'min_child_weight': 2, 'reg_alpha': 0.949130001827397, 'reg_lambda': 0.7766428586643782}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:41,548] Trial 7 finished with value: 0.17636119285973528 and parameters: {'n_estimators': 126, 'max_depth': 8, 'learning_rate': 0.14707996938597875, 'subsample': 0.6332264280220363, 'colsample_bytree': 0.8804172610935361, 'gamma': 0.30107624287938034, 'min_child_weight': 2, 'reg_alpha': 0.93476429830388, 'reg_lambda': 0.7583004964424878}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:41,656] Trial 8 finished with value: 0.17795190811007014 and parameters: {'n_estimators': 150, 'max_depth': 5, 'learning_rate': 0.1627947381373947, 'subsample': 0.9989427785795392, 'colsample_bytree': 0.785614184668266, 'gamma': 0.48020173232028684, 'min_child_weight': 4, 'reg_alpha': 0.8081951421194056, 'reg_lambda': 0.40639649026485736}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:41,773] Trial 9 finished with value: 0.19603076049982837 and parameters: {'n_estimators': 184, 'max_depth': 3, 'learning_rate': 0.1711809006690909, 'subsample': 0.8487725032744023, 'colsample_bytree': 0.7126947379039292, 'gamma': 0.4939630100166504, 'min_child_weight': 4, 'reg_alpha': 0.05130091887987431, 'reg_lambda': 0.3795352220431163}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:41,950] Trial 10 finished with value: 0.18776749499144657 and parameters: {'n_estimators': 296, 'max_depth': 10, 'learning_rate': 0.12935112054977374, 'subsample': 0.7549452595771983, 'colsample_bytree': 0.5165464849546806, 'gamma': 0.37267252631313663, 'min_child_weight': 1, 'reg_alpha': 0.6971224653546619, 'reg_lambda': 0.00710236826648028}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:42,070] Trial 11 finished with value: 0.1768338690930304 and parameters: {'n_estimators': 52, 'max_depth': 9, 'learning_rate': 0.13789962481675222, 'subsample': 0.7240930008307849, 'colsample_bytree': 0.9631472223928217, 'gamma': 0.31917882088432425, 'min_child_weight': 2, 'reg_alpha': 0.9929147721089218, 'reg_lambda': 0.6588583621633481}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:42,198] Trial 12 finished with value: 0.17728230488306249 and parameters: {'n_estimators': 117, 'max_depth': 8, 'learning_rate': 0.18997161439578175, 'subsample': 0.7268321549426318, 'colsample_bytree': 0.8670173572299071, 'gamma': 0.3397988125130681, 'min_child_weight': 1, 'reg_alpha': 0.7927624163570581, 'reg_lambda': 0.9851061347231885}. Best is trial 0 with value: 0.17567249392720982.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:42,439] Trial 13 finished with value: 0.17565888748333466 and parameters: {'n_estimators': 156, 'max_depth': 8, 'learning_rate': 0.12762039443715842, 'subsample': 0.8034639707876503, 'colsample_bytree': 0.8664228272971114, 'gamma': 0.1132751551464149, 'min_child_weight': 7, 'reg_alpha': 0.44444428859954027, 'reg_lambda': 0.21178497187475476}. Best is trial 13 with value: 0.17565888748333466.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:42,805] Trial 14 finished with value: 0.17822129186696983 and parameters: {'n_estimators': 165, 'max_depth': 10, 'learning_rate': 0.11247518503416572, 'subsample': 0.8130011650782595, 'colsample_bytree': 0.9703452675554551, 'gamma': 0.07882920895604789, 'min_child_weight': 7, 'reg_alpha': 0.4115628075958001, 'reg_lambda': 0.2226800016373532}. Best is trial 13 with value: 0.17565888748333466.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:42,986] Trial 15 finished with value: 0.17600163622016696 and parameters: {'n_estimators': 189, 'max_depth': 7, 'learning_rate': 0.1941002179566491, 'subsample': 0.9316683805449221, 'colsample_bytree': 0.8165410101080975, 'gamma': 0.1084121414107232, 'min_child_weight': 6, 'reg_alpha': 0.24135008912555622, 'reg_lambda': 0.21275522214081716}. Best is trial 13 with value: 0.17565888748333466.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:43,271] Trial 16 finished with value: 0.17936850504548885 and parameters: {'n_estimators': 83, 'max_depth': 9, 'learning_rate': 0.11204173280599115, 'subsample': 0.7517707232876745, 'colsample_bytree': 0.8355947376474544, 'gamma': 0.009440579885801492, 'min_child_weight': 7, 'reg_alpha': 0.4830663734992581, 'reg_lambda': 0.09623514987702031}. Best is trial 13 with value: 0.17565888748333466.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:43,582] Trial 17 finished with value: 0.17750995362118782 and parameters: {'n_estimators': 267, 'max_depth': 8, 'learning_rate': 0.1611094042674033, 'subsample': 0.7950201753869784, 'colsample_bytree': 0.9256228299856717, 'gamma': 0.10346245340144522, 'min_child_weight': 5, 'reg_alpha': 0.6312100477055089, 'reg_lambda': 0.3289210148518704}. Best is trial 13 with value: 0.17565888748333466.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:43,740] Trial 18 finished with value: 0.18812022413462035 and parameters: {'n_estimators': 157, 'max_depth': 6, 'learning_rate': 0.12526501251192634, 'subsample': 0.6893043825723597, 'colsample_bytree': 0.746491285099289, 'gamma': 0.4024064774371226, 'min_child_weight': 7, 'reg_alpha': 0.05647730133058393, 'reg_lambda': 0.12463813701494864}. Best is trial 13 with value: 0.17565888748333466.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:43,980] Trial 19 finished with value: 0.1880136975755017 and parameters: {'n_estimators': 213, 'max_depth': 9, 'learning_rate': 0.09259522895477357, 'subsample': 0.9030841477039817, 'colsample_bytree': 0.7431208811436517, 'gamma': 0.2585125293114735, 'min_child_weight': 3, 'reg_alpha': 0.44216494376099685, 'reg_lambda': 0.2866700984175481}. Best is trial 13 with value: 0.17565888748333466.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:44,139] Trial 20 finished with value: 0.17511632714908457 and parameters: {'n_estimators': 95, 'max_depth': 6, 'learning_rate': 0.1480742691413851, 'subsample': 0.8165113841212467, 'colsample_bytree': 0.9266969437100105, 'gamma': 0.10921847306262167, 'min_child_weight': 6, 'reg_alpha': 0.3138018105962122, 'reg_lambda': 0.14980803342033172}. Best is trial 20 with value: 0.17511632714908457.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:44,285] Trial 21 finished with value: 0.1744951917388444 and parameters: {'n_estimators': 97, 'max_depth': 6, 'learning_rate': 0.1482615076618919, 'subsample': 0.8153759310536928, 'colsample_bytree': 0.9946910334819764, 'gamma': 0.13652896054810787, 'min_child_weight': 6, 'reg_alpha': 0.3306297285475948, 'reg_lambda': 0.14361484115716738}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:44,413] Trial 22 finished with value: 0.1747259181055303 and parameters: {'n_estimators': 92, 'max_depth': 6, 'learning_rate': 0.17906682851863337, 'subsample': 0.840668343255309, 'colsample_bytree': 0.997481743931306, 'gamma': 0.1281654059531193, 'min_child_weight': 6, 'reg_alpha': 0.30090734044855155, 'reg_lambda': 0.27351793690841186}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:44,533] Trial 23 finished with value: 0.1749086947786819 and parameters: {'n_estimators': 90, 'max_depth': 6, 'learning_rate': 0.1776578339352331, 'subsample': 0.8472691284553012, 'colsample_bytree': 0.9896725997448749, 'gamma': 0.15037312926923085, 'min_child_weight': 6, 'reg_alpha': 0.29596071768265714, 'reg_lambda': 0.3035237211923245}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:44,624] Trial 24 finished with value: 0.17512395539656028 and parameters: {'n_estimators': 52, 'max_depth': 6, 'learning_rate': 0.1794140083163896, 'subsample': 0.9652761742057474, 'colsample_bytree': 0.9909464954152698, 'gamma': 0.15052425270280625, 'min_child_weight': 8, 'reg_alpha': 0.16510114931968337, 'reg_lambda': 0.482516304808395}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:44,750] Trial 25 finished with value: 0.1746694228914826 and parameters: {'n_estimators': 66, 'max_depth': 5, 'learning_rate': 0.1816243247847372, 'subsample': 0.8479149126703915, 'colsample_bytree': 0.9973753375532792, 'gamma': 0.06606740798840688, 'min_child_weight': 6, 'reg_alpha': 0.32292963251544815, 'reg_lambda': 0.29966095432990114}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:44,878] Trial 26 finished with value: 0.17564328720943517 and parameters: {'n_estimators': 69, 'max_depth': 5, 'learning_rate': 0.1827581748292424, 'subsample': 0.9155531710476715, 'colsample_bytree': 0.940211387053882, 'gamma': 0.055675830459503806, 'min_child_weight': 5, 'reg_alpha': 0.15562213379933093, 'reg_lambda': 0.40935642944399536}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:45,080] Trial 27 finished with value: 0.17623424730723986 and parameters: {'n_estimators': 108, 'max_depth': 5, 'learning_rate': 0.19742039488748186, 'subsample': 0.8847615584614442, 'colsample_bytree': 0.9494890048439109, 'gamma': 0.010951714530820278, 'min_child_weight': 8, 'reg_alpha': 0.3521599536783571, 'reg_lambda': 0.5829725892362194}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:45,245] Trial 28 finished with value: 0.17691459729742323 and parameters: {'n_estimators': 69, 'max_depth': 7, 'learning_rate': 0.1620032190074494, 'subsample': 0.8561377525225125, 'colsample_bytree': 0.9974917753454462, 'gamma': 0.05923734662674519, 'min_child_weight': 6, 'reg_alpha': 0.25115842548161865, 'reg_lambda': 0.27213348711973673}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:45,358] Trial 29 finished with value: 0.18763301098033214 and parameters: {'n_estimators': 136, 'max_depth': 3, 'learning_rate': 0.15114852327525155, 'subsample': 0.9438235291882919, 'colsample_bytree': 0.9070697582493802, 'gamma': 0.22538247847073928, 'min_child_weight': 5, 'reg_alpha': 0.1020516962030098, 'reg_lambda': 0.0779136285095095}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:45,512] Trial 30 finished with value: 0.17583374645916397 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.1681461959532461, 'subsample': 0.6905116914408526, 'colsample_bytree': 0.9647366048174566, 'gamma': 0.1440354041641193, 'min_child_weight': 9, 'reg_alpha': 0.36275610346150844, 'reg_lambda': 0.1482531216599254}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:45,635] Trial 31 finished with value: 0.1751490328532417 and parameters: {'n_estimators': 83, 'max_depth': 6, 'learning_rate': 0.18134997310999376, 'subsample': 0.8459846987338815, 'colsample_bytree': 0.9930640663514168, 'gamma': 0.13562217027979734, 'min_child_weight': 6, 'reg_alpha': 0.25743662562911596, 'reg_lambda': 0.332755910799121}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:45,760] Trial 32 finished with value: 0.17564332352245832 and parameters: {'n_estimators': 92, 'max_depth': 6, 'learning_rate': 0.17625111764455126, 'subsample': 0.7731890784217306, 'colsample_bytree': 0.9982783751102855, 'gamma': 0.18859969611497412, 'min_child_weight': 6, 'reg_alpha': 0.5440459996261005, 'reg_lambda': 0.3007588906393388}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:45,897] Trial 33 finished with value: 0.17617680249012474 and parameters: {'n_estimators': 62, 'max_depth': 7, 'learning_rate': 0.1998692865912263, 'subsample': 0.8327233379133638, 'colsample_bytree': 0.9226071724647829, 'gamma': 0.0749705370632248, 'min_child_weight': 4, 'reg_alpha': 0.2832085081535869, 'reg_lambda': 0.4656350042559773}. Best is trial 21 with value: 0.1744951917388444.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,020] Trial 34 finished with value: 0.17436025729520463 and parameters: {'n_estimators': 117, 'max_depth': 5, 'learning_rate': 0.15316842021307725, 'subsample': 0.8717689939387636, 'colsample_bytree': 0.959361780159866, 'gamma': 0.20221003512051822, 'min_child_weight': 5, 'reg_alpha': 0.3630871788866247, 'reg_lambda': 0.3720015150045266}. Best is trial 34 with value: 0.17436025729520463.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,141] Trial 35 finished with value: 0.17695053408085082 and parameters: {'n_estimators': 103, 'max_depth': 4, 'learning_rate': 0.15433204530609695, 'subsample': 0.8836348316774133, 'colsample_bytree': 0.9555254748885841, 'gamma': 0.2093080762710473, 'min_child_weight': 3, 'reg_alpha': 0.37195596469811737, 'reg_lambda': 0.5898636617380368}. Best is trial 34 with value: 0.17436025729520463.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,272] Trial 36 finished with value: 0.17423750538402558 and parameters: {'n_estimators': 121, 'max_depth': 5, 'learning_rate': 0.1394570660230036, 'subsample': 0.8758915911461644, 'colsample_bytree': 0.8913524427941403, 'gamma': 0.17640457413828625, 'min_child_weight': 5, 'reg_alpha': 0.216888319111886, 'reg_lambda': 0.44045051974425187}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,382] Trial 37 finished with value: 0.1783369141807407 and parameters: {'n_estimators': 122, 'max_depth': 4, 'learning_rate': 0.1423020570783681, 'subsample': 0.9641283238221792, 'colsample_bytree': 0.8996491155090762, 'gamma': 0.27879304482571193, 'min_child_weight': 3, 'reg_alpha': 0.19834286735589568, 'reg_lambda': 0.43270217911009917}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,519] Trial 38 finished with value: 0.17430393162256783 and parameters: {'n_estimators': 139, 'max_depth': 5, 'learning_rate': 0.13805653725124611, 'subsample': 0.8722124025123468, 'colsample_bytree': 0.825959683541968, 'gamma': 0.1833898847510432, 'min_child_weight': 5, 'reg_alpha': 0.5098195374679846, 'reg_lambda': 0.5377072280172867}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,651] Trial 39 finished with value: 0.17728529229041765 and parameters: {'n_estimators': 141, 'max_depth': 4, 'learning_rate': 0.13461908622767485, 'subsample': 0.9050052662337019, 'colsample_bytree': 0.8474201804350153, 'gamma': 0.17625913665263804, 'min_child_weight': 5, 'reg_alpha': 0.5225990291684477, 'reg_lambda': 0.5237813537039896}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,750] Trial 40 finished with value: 0.17461809801072692 and parameters: {'n_estimators': 119, 'max_depth': 5, 'learning_rate': 0.11832317061007788, 'subsample': 0.8774373297882816, 'colsample_bytree': 0.8012737926208557, 'gamma': 0.20961516053482313, 'min_child_weight': 4, 'reg_alpha': 0.6531729170657651, 'reg_lambda': 0.6146296853069809}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:46,882] Trial 41 finished with value: 0.17501052064701564 and parameters: {'n_estimators': 115, 'max_depth': 5, 'learning_rate': 0.11640581127774066, 'subsample': 0.8846190019593545, 'colsample_bytree': 0.791348789018075, 'gamma': 0.19833478304797542, 'min_child_weight': 4, 'reg_alpha': 0.6074267590891154, 'reg_lambda': 0.6800474869668152}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:47,029] Trial 42 finished with value: 0.17542394805847128 and parameters: {'n_estimators': 130, 'max_depth': 5, 'learning_rate': 0.10124569382346933, 'subsample': 0.7824409068956059, 'colsample_bytree': 0.814588668313658, 'gamma': 0.2425140503895922, 'min_child_weight': 4, 'reg_alpha': 0.711250384130388, 'reg_lambda': 0.5784328663270261}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:47,163] Trial 43 finished with value: 0.1745768136117003 and parameters: {'n_estimators': 140, 'max_depth': 5, 'learning_rate': 0.1368933476800305, 'subsample': 0.8674082019197983, 'colsample_bytree': 0.7698119486776929, 'gamma': 0.2241954167148967, 'min_child_weight': 5, 'reg_alpha': 0.4740284830020523, 'reg_lambda': 0.6376941443765051}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:47,373] Trial 44 finished with value: 0.1797427734873909 and parameters: {'n_estimators': 142, 'max_depth': 4, 'learning_rate': 0.037396954700521304, 'subsample': 0.9264350368055593, 'colsample_bytree': 0.7686060035478552, 'gamma': 0.2708223974415611, 'min_child_weight': 5, 'reg_alpha': 0.4654997569070478, 'reg_lambda': 0.7196235247699236}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:47,531] Trial 45 finished with value: 0.18670035307819097 and parameters: {'n_estimators': 175, 'max_depth': 4, 'learning_rate': 0.1365135044318787, 'subsample': 0.8680396759008608, 'colsample_bytree': 0.6861259625086688, 'gamma': 0.17280526055826287, 'min_child_weight': 5, 'reg_alpha': 0.41043506690673803, 'reg_lambda': 0.8439329898845133}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:47,657] Trial 46 finished with value: 0.17534844689030415 and parameters: {'n_estimators': 146, 'max_depth': 5, 'learning_rate': 0.15804028262347117, 'subsample': 0.8241203671012892, 'colsample_bytree': 0.8830430012227002, 'gamma': 0.2985647969726144, 'min_child_weight': 5, 'reg_alpha': 0.5587003074689898, 'reg_lambda': 0.5396932936622153}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:47,826] Trial 47 finished with value: 0.1877403816929378 and parameters: {'n_estimators': 130, 'max_depth': 3, 'learning_rate': 0.0678817797613577, 'subsample': 0.789027356590706, 'colsample_bytree': 0.844565305456259, 'gamma': 0.23446294135359966, 'min_child_weight': 4, 'reg_alpha': 0.48841120649373515, 'reg_lambda': 0.36690368542268703}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:47,982] Trial 48 finished with value: 0.18672913834239405 and parameters: {'n_estimators': 112, 'max_depth': 7, 'learning_rate': 0.14365228561798596, 'subsample': 0.9968655297333012, 'colsample_bytree': 0.7231769522852567, 'gamma': 0.1543645005843798, 'min_child_weight': 3, 'reg_alpha': 0.38880693165081, 'reg_lambda': 0.6482948141582174}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:48,150] Trial 49 finished with value: 0.18586150250633635 and parameters: {'n_estimators': 166, 'max_depth': 5, 'learning_rate': 0.12652639229093626, 'subsample': 0.9502409200932908, 'colsample_bytree': 0.5494130162426667, 'gamma': 0.16627430584995553, 'min_child_weight': 7, 'reg_alpha': 0.43541862927148545, 'reg_lambda': 0.4496121364944468}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:48,376] Trial 50 finished with value: 0.17883705654817228 and parameters: {'n_estimators': 203, 'max_depth': 4, 'learning_rate': 0.1038159788151677, 'subsample': 0.5694107701531561, 'colsample_bytree': 0.8593195186315752, 'gamma': 0.19827137431498715, 'min_child_weight': 5, 'reg_alpha': 0.5119804172098998, 'reg_lambda': 0.7808596440665133}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:48,503] Trial 51 finished with value: 0.1748121236788849 and parameters: {'n_estimators': 123, 'max_depth': 5, 'learning_rate': 0.1303909502644966, 'subsample': 0.8713976985382726, 'colsample_bytree': 0.7691893417688931, 'gamma': 0.22820636549403267, 'min_child_weight': 4, 'reg_alpha': 0.6851308573814769, 'reg_lambda': 0.6365007447501861}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:48,619] Trial 52 finished with value: 0.1750476814554813 and parameters: {'n_estimators': 108, 'max_depth': 5, 'learning_rate': 0.1421961845026005, 'subsample': 0.8742025257144501, 'colsample_bytree': 0.8248212778615313, 'gamma': 0.21126766302408043, 'min_child_weight': 4, 'reg_alpha': 0.7949014460178594, 'reg_lambda': 0.7133221335250842}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:48,772] Trial 53 finished with value: 0.17486822883317657 and parameters: {'n_estimators': 160, 'max_depth': 6, 'learning_rate': 0.11965649527371736, 'subsample': 0.9095796655781018, 'colsample_bytree': 0.7947469112472537, 'gamma': 0.2506793403598104, 'min_child_weight': 5, 'reg_alpha': 0.7456046985248681, 'reg_lambda': 0.6158553140538521}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:48,878] Trial 54 finished with value: 0.17465259018172158 and parameters: {'n_estimators': 149, 'max_depth': 5, 'learning_rate': 0.12059323460553963, 'subsample': 0.8913258302625221, 'colsample_bytree': 0.8831331207333082, 'gamma': 0.18664060312035374, 'min_child_weight': 3, 'reg_alpha': 0.6004133402075534, 'reg_lambda': 0.5219039197465315}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:49,036] Trial 55 finished with value: 0.1743607104186954 and parameters: {'n_estimators': 132, 'max_depth': 6, 'learning_rate': 0.10998180585574649, 'subsample': 0.8165780317166936, 'colsample_bytree': 0.7612683191810179, 'gamma': 0.20642407204901742, 'min_child_weight': 4, 'reg_alpha': 0.2123711514118134, 'reg_lambda': 0.007287869196691471}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:49,295] Trial 56 finished with value: 0.18553005361908562 and parameters: {'n_estimators': 135, 'max_depth': 6, 'learning_rate': 0.08036721596825724, 'subsample': 0.804504329517342, 'colsample_bytree': 0.6375195221100861, 'gamma': 0.0975047448829392, 'min_child_weight': 7, 'reg_alpha': 0.2223822093506877, 'reg_lambda': 0.0070912911488292246}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:49,515] Trial 57 finished with value: 0.17550372274297743 and parameters: {'n_estimators': 181, 'max_depth': 6, 'learning_rate': 0.16702776648760104, 'subsample': 0.7687880346851387, 'colsample_bytree': 0.7673746624375376, 'gamma': 0.1305718675767795, 'min_child_weight': 5, 'reg_alpha': 0.11969830172363605, 'reg_lambda': 0.08301631689646122}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:49,706] Trial 58 finished with value: 0.1870946280838673 and parameters: {'n_estimators': 153, 'max_depth': 7, 'learning_rate': 0.10910372601502558, 'subsample': 0.8139549428855943, 'colsample_bytree': 0.7004213912020038, 'gamma': 0.28343347539000596, 'min_child_weight': 6, 'reg_alpha': 0.008727044600919331, 'reg_lambda': 0.19224547889803184}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:49,864] Trial 59 finished with value: 0.17563108446618117 and parameters: {'n_estimators': 79, 'max_depth': 6, 'learning_rate': 0.0955677003622831, 'subsample': 0.7223015451467377, 'colsample_bytree': 0.9346794003803586, 'gamma': 0.16423256870303762, 'min_child_weight': 4, 'reg_alpha': 0.3445087540858057, 'reg_lambda': 0.05539534507915622}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:50,088] Trial 60 finished with value: 0.1757594329168045 and parameters: {'n_estimators': 165, 'max_depth': 6, 'learning_rate': 0.15420702703364117, 'subsample': 0.8264546353132486, 'colsample_bytree': 0.9742507817348345, 'gamma': 0.08887812725454558, 'min_child_weight': 5, 'reg_alpha': 0.19805996970633027, 'reg_lambda': 0.5013822123731421}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:50,235] Trial 61 finished with value: 0.18586077137446413 and parameters: {'n_estimators': 120, 'max_depth': 5, 'learning_rate': 0.13153972430680969, 'subsample': 0.865967302478077, 'colsample_bytree': 0.7348682757840606, 'gamma': 0.21354184382422106, 'min_child_weight': 4, 'reg_alpha': 0.28331434350567336, 'reg_lambda': 0.5515891571520328}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:50,365] Trial 62 finished with value: 0.17554116553855897 and parameters: {'n_estimators': 132, 'max_depth': 5, 'learning_rate': 0.12421608069606488, 'subsample': 0.8945341500006383, 'colsample_bytree': 0.8069069297518421, 'gamma': 0.2603618663602946, 'min_child_weight': 4, 'reg_alpha': 0.6448056683048069, 'reg_lambda': 0.37187779554698647}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:50,504] Trial 63 finished with value: 0.17623362959668748 and parameters: {'n_estimators': 116, 'max_depth': 4, 'learning_rate': 0.1401962231337082, 'subsample': 0.8575602716003008, 'colsample_bytree': 0.7602099167430209, 'gamma': 0.1219394577605554, 'min_child_weight': 3, 'reg_alpha': 0.4505663805367636, 'reg_lambda': 0.1173936033073798}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:50,620] Trial 64 finished with value: 0.1745535668643441 and parameters: {'n_estimators': 97, 'max_depth': 5, 'learning_rate': 0.1474212021399804, 'subsample': 0.8331526747565322, 'colsample_bytree': 0.8378010843271874, 'gamma': 0.19825246400161392, 'min_child_weight': 6, 'reg_alpha': 0.39717542519881066, 'reg_lambda': 0.6153350430243767}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:50,749] Trial 65 finished with value: 0.1744124376139403 and parameters: {'n_estimators': 98, 'max_depth': 6, 'learning_rate': 0.14798947114722152, 'subsample': 0.8339974961702492, 'colsample_bytree': 0.8293998241657665, 'gamma': 0.1881383638009169, 'min_child_weight': 6, 'reg_alpha': 0.40993705483541176, 'reg_lambda': 0.24232504518280062}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:53,651] Trial 79 finished with value: 0.17475949652410888 and parameters: {'n_estimators': 114, 'max_depth': 6, 'learning_rate': 0.07586036845645308, 'subsample': 0.7382887596945101, 'colsample_bytree': 0.781295713038633, 'gamma': 0.12352383278004911, 'min_child_weight': 5, 'reg_alpha': 0.274425463112833, 'reg_lambda': 0.43857971594805345}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:53,836] Trial 80 finished with value: 0.17453735227414366 and parameters: {'n_estimators': 138, 'max_depth': 6, 'learning_rate': 0.09050436466003371, 'subsample': 0.8203358861045323, 'colsample_bytree': 0.891698391462646, 'gamma': 0.18001477461202564, 'min_child_weight': 6, 'reg_alpha': 0.01973403344512159, 'reg_lambda': 0.33728918344143083}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:54,023] Trial 81 finished with value: 0.17462599946950758 and parameters: {'n_estimators': 136, 'max_depth': 6, 'learning_rate': 0.08758993746720095, 'subsample': 0.8193659757699987, 'colsample_bytree': 0.8986597963763294, 'gamma': 0.1776360795366641, 'min_child_weight': 6, 'reg_alpha': 0.015584416120039274, 'reg_lambda': 0.32667575761008794}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:54,180] Trial 82 finished with value: 0.17438018560330582 and parameters: {'n_estimators': 127, 'max_depth': 6, 'learning_rate': 0.09771760701526067, 'subsample': 0.8460281416880377, 'colsample_bytree': 0.8206693501006899, 'gamma': 0.23668174229458241, 'min_child_weight': 6, 'reg_alpha': 0.040005730752712326, 'reg_lambda': 0.4037969104773489}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:54,330] Trial 83 finished with value: 0.1745761326777658 and parameters: {'n_estimators': 146, 'max_depth': 5, 'learning_rate': 0.10763920965646627, 'subsample': 0.8514941186619538, 'colsample_bytree': 0.8192789501513801, 'gamma': 0.2388850420660184, 'min_child_weight': 5, 'reg_alpha': 0.0377832258430855, 'reg_lambda': 0.39455697447389326}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:54,498] Trial 84 finished with value: 0.17537609351233344 and parameters: {'n_estimators': 112, 'max_depth': 7, 'learning_rate': 0.09566966267323238, 'subsample': 0.8966016216688435, 'colsample_bytree': 0.83843123994767, 'gamma': 0.22140536455414384, 'min_child_weight': 7, 'reg_alpha': 0.057024975692651074, 'reg_lambda': 0.34898015578406316}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:54,641] Trial 85 finished with value: 0.17492686482648706 and parameters: {'n_estimators': 85, 'max_depth': 6, 'learning_rate': 0.09802494101913843, 'subsample': 0.8615750840712432, 'colsample_bytree': 0.9125309151561543, 'gamma': 0.20121353891690807, 'min_child_weight': 5, 'reg_alpha': 0.07911896040330621, 'reg_lambda': 0.4977827318671552}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:54,821] Trial 86 finished with value: 0.17500975267937613 and parameters: {'n_estimators': 141, 'max_depth': 5, 'learning_rate': 0.07579793469902883, 'subsample': 0.8383224660730412, 'colsample_bytree': 0.8057109747157907, 'gamma': 0.18330398797656142, 'min_child_weight': 6, 'reg_alpha': 0.37241959350768433, 'reg_lambda': 0.3185877453681274}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:55,007] Trial 87 finished with value: 0.17485021865279488 and parameters: {'n_estimators': 119, 'max_depth': 6, 'learning_rate': 0.09082190642573887, 'subsample': 0.7775954702897643, 'colsample_bytree': 0.7830985897963567, 'gamma': 0.16043534000962895, 'min_child_weight': 6, 'reg_alpha': 0.31198875142278665, 'reg_lambda': 0.16176945726117356}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:55,129] Trial 88 finished with value: 0.17503207894134148 and parameters: {'n_estimators': 99, 'max_depth': 5, 'learning_rate': 0.11454249149379693, 'subsample': 0.8793201088270477, 'colsample_bytree': 0.8194193062298066, 'gamma': 0.24542147837759887, 'min_child_weight': 5, 'reg_alpha': 0.12987947578384357, 'reg_lambda': 0.27543719386977744}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:55,239] Trial 89 finished with value: 0.17504372078782596 and parameters: {'n_estimators': 132, 'max_depth': 7, 'learning_rate': 0.10204129280586074, 'subsample': 0.8445712131335293, 'colsample_bytree': 0.9828182944075036, 'gamma': 0.260442775056402, 'min_child_weight': 7, 'reg_alpha': 0.04690301816110218, 'reg_lambda': 0.40794651528830017}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:55,402] Trial 90 finished with value: 0.1746505800839926 and parameters: {'n_estimators': 157, 'max_depth': 5, 'learning_rate': 0.15391877889883812, 'subsample': 0.8251107137930866, 'colsample_bytree': 0.9473085983664798, 'gamma': 0.16915321778043307, 'min_child_weight': 6, 'reg_alpha': 0.17469648484969166, 'reg_lambda': 0.46638621194799423}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:55,602] Trial 91 finished with value: 0.1746314523783089 and parameters: {'n_estimators': 127, 'max_depth': 6, 'learning_rate': 0.08509725338869938, 'subsample': 0.805939336623136, 'colsample_bytree': 0.8899926120795735, 'gamma': 0.1345791352578838, 'min_child_weight': 6, 'reg_alpha': 0.14797907499672322, 'reg_lambda': 0.4214813950169211}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:55,754] Trial 92 finished with value: 0.17503242128007582 and parameters: {'n_estimators': 123, 'max_depth': 6, 'learning_rate': 0.16492432040060906, 'subsample': 0.790101095580287, 'colsample_bytree': 0.8677242248209771, 'gamma': 0.14775951514415436, 'min_child_weight': 6, 'reg_alpha': 0.8534535558424584, 'reg_lambda': 0.45134837684998563}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:55,963] Trial 93 finished with value: 0.17538007310686007 and parameters: {'n_estimators': 104, 'max_depth': 6, 'learning_rate': 0.0550282156884234, 'subsample': 0.8183063443766702, 'colsample_bytree': 0.9300762690819897, 'gamma': 0.21599558454553058, 'min_child_weight': 7, 'reg_alpha': 0.03237898111013385, 'reg_lambda': 0.9869200338906535}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:56,205] Trial 94 finished with value: 0.1749694490877537 and parameters: {'n_estimators': 149, 'max_depth': 6, 'learning_rate': 0.08946700984847121, 'subsample': 0.7668890864187291, 'colsample_bytree': 0.8826649086831961, 'gamma': 0.1125909154672205, 'min_child_weight': 5, 'reg_alpha': 0.20633637643189068, 'reg_lambda': 0.12511669964485625}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:56,347] Trial 95 finished with value: 0.17446297679866013 and parameters: {'n_estimators': 112, 'max_depth': 6, 'learning_rate': 0.13522130412872613, 'subsample': 0.86219776222557, 'colsample_bytree': 0.8598718987560544, 'gamma': 0.1811727322871044, 'min_child_weight': 6, 'reg_alpha': 0.09608288090311734, 'reg_lambda': 0.3861296178545765}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:56,472] Trial 96 finished with value: 0.17485111119563498 and parameters: {'n_estimators': 113, 'max_depth': 5, 'learning_rate': 0.1609659980421984, 'subsample': 0.8558733616062201, 'colsample_bytree': 0.8423247650974552, 'gamma': 0.1903954901892842, 'min_child_weight': 5, 'reg_alpha': 0.5283355025321558, 'reg_lambda': 0.38030370298145716}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:56,589] Trial 97 finished with value: 0.1747431018586218 and parameters: {'n_estimators': 77, 'max_depth': 6, 'learning_rate': 0.13303239560595007, 'subsample': 0.9322838062060276, 'colsample_bytree': 0.854145948531214, 'gamma': 0.23146123917530023, 'min_child_weight': 7, 'reg_alpha': 0.08394097683800754, 'reg_lambda': 0.30799853498736185}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:56,728] Trial 98 finished with value: 0.17491781640863568 and parameters: {'n_estimators': 93, 'max_depth': 7, 'learning_rate': 0.14243055559269838, 'subsample': 0.8922703815589028, 'colsample_bytree': 0.8093161174511391, 'gamma': 0.18051291424596438, 'min_child_weight': 6, 'reg_alpha': 0.1063182509260644, 'reg_lambda': 0.4868988108656623}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-19 10:17:56,821] Trial 99 finished with value: 0.17550822355393836 and parameters: {'n_estimators': 59, 'max_depth': 5, 'learning_rate': 0.17304149180469047, 'subsample': 0.869858014262271, 'colsample_bytree': 0.8294675884657112, 'gamma': 0.2072351812791589, 'min_child_weight': 6, 'reg_alpha': 0.0035991338485765745, 'reg_lambda': 0.34559408220243243}. Best is trial 36 with value: 0.17423750538402558.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'n_estimators': 121, 'max_depth': 5, 'learning_rate': 0.1394570660230036, 'subsample': 0.8758915911461644, 'colsample_bytree': 0.8913524427941403, 'gamma': 0.17640457413828625, 'min_child_weight': 5, 'reg_alpha': 0.216888319111886, 'reg_lambda': 0.44045051974425187}
# Mean Absolute Error (MAE): 0.17423750538402558
# R² (Coefficient of Determination): 0.7553399287038527
# Pearson's Correlation Coefficient (R): 0.8693583666258944
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.933090431027427

# %%
target_yearDf=pd.read_csv('target_yearDf.csv')

# %%
print(len(target_yearDf))
# Out:
# 4

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
target_xDf = target_yearDf[xColumnsToKeep]


target_yDf = target_yearDf[yColumnsToKeep]

# %%
all_yearsDf=pd.read_csv("all_years.csv")

# %%
m1,r2=actualTest(all_yearsDf, target_yearDf, target_xDf, target_yDf, pipe)
# Out:
# 0.34628391617273646
# R:  0.965415895869991
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     27.42
# Date:                Sat, 19 Apr 2025   Prob (F-statistic):             0.0346
# Time:                        10:19:29   Log-Likelihood:                 3.3562
# No. Observations:                   4   AIC:                            -2.712
# Df Residuals:                       2   BIC:                            -3.940
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8436      0.201      4.193      0.052      -0.022       1.709
# x1             0.6633      0.127      5.237      0.035       0.118       1.208
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.984
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.420
# Skew:                           0.624   Prob(JB):                        0.811
# Kurtosis:                       2.021   Cond. No.                         5.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 21.325%
# skt smape: 24.992%
# skt mae: 0.346
# skt mse: 0.169
# skt rmse: 0.412
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
def actualTest(all_yearsDf, target_yearDf, xTest, yTest, model):
    #print("Length of all_yearsDf----This is used for plotting graph ", len(all_yearsDf))
    #print("Length of final_yearDf-----This is used for adjusting the predicted values: ", len(final_yearDf))
    #print("Length of target_yearDf-------This is used for comparing predicted values to true values-----these are true values ", len(target_yearDf))
    #print("boost_xDf: ",len(boost_xDf))
    #print("boost_yDf: ", len(boost_yDf))
    #print("Length of xTest: ", len(xTest))
    #print("Length of yTest: ", len(yTest))
    #print("test results on our test data: ")
    #print(yTest)
    
    #model = model.fit(boost_xDf, boost_yDf, xgb_model=model.get_booster())
    # get predictions
    pred = model.predict(xTest)
    #trainPred = model.predict(xTrain)
    #print("Length of predictions are: ", len(pred))

    #adj_pred = []
    #for i in range(len(pred)):
    #    adj_pred.append(final_yearDf['yield'][i] + pred[i])
    #print('adjusted predictions: ')
    #print(adj_pred)
    #print("Predictions are: ")
    #print(pred)
    #print("Length of adjusted predictions: ", len(adj_pred))
    pred_Df = pd.DataFrame(pred)
    #print(adj_pred_Df)
    #adj_pred_Df=pd.DataFrame(pred)
    # find errors
    meanAbsoluteError = mean_absolute_error(target_yearDf['yield'], pred_Df)
    print(meanAbsoluteError)
#     plt.scatter(yTest, pred, label='Truth vs Prediction')
#     p1 = max(max(pred), max(yTest['Yield (tons/acre)']))
#     p2 = min(min(pred), min(yTest['Yield (tons/acre)']))
#     plt.plot([p1, p2], [p1, p2], color='k', label='Perfect Predictions')
#     plt.xlabel('True Yields')
#     plt.ylabel('Predicted Yields')
#     plt.legend()
    #print("Plotting--------")
    pred_ts = []
    len_tsDf = len(all_yearsDf)
    #print("len_tsDf----Length of all_yearsDf----", len_tsDf)
    for i in range(len_tsDf - len(pred), len_tsDf):
        pred_ts.append(i)
    #print("Length of pred_ts is: ", len(pred_ts))
    #print("This is the index calculated for plotting time-series graph: ", pred_ts)    
    pred_df = pd.DataFrame(pred, index = pred_ts, columns = ['yield'])
    #print("Lengths of all_yearsDf and Lengths of pred_Df are: ", len(all_yearsDf['yield']), len(pred_df))
    #print("Head and shape of pred_Df")
    #print(pred_df.head())  # Check structure
    #print(pred_df.shape)   # Compare with all_yearsDf
    #print(all_yearsDf.index)
    plot_series(pd.Series(all_yearsDf['yield']), pred_df, labels=["y", "y_pred"])


    #plt.figure(figsize=(10, 6))

    # Plot actual yield using its index
    #plt.plot(all_yearsDf.index, all_yearsDf['yield'], label="Actual Yield", linestyle="-", color="blue")

    # Plot predicted yield using its index (from pred_df)
    #plt.plot(pred_df.index, pred_df['yield'], label="Predicted Yield", linestyle="--", color="red")

    #plt.xlabel("Index")  # The x-axis will now be the index of each DataFrame
    #plt.ylabel("Yield")
    #plt.legend()
    #plt.title("Actual vs. Predicted Yield")
    #plt.show()

    # find the R values
    r = np.corrcoef(target_yearDf['yield'], pred)[0,1]
    print("R: ",r)
    # find the R^2 coefficient of determination
    # defining the variables
#     r2x = xTest.tolist()
#     r2y = yTest.tolist()

    # adding the constant term
    r2pred = sm.add_constant(pred)

    # performing the regression
    # and fitting the model
    yTargetYield = target_yearDf['yield']
    result = sm.OLS(yTargetYield, r2pred).fit()

    # printing the summary table
    print(result.summary())
    print('skt mape: ' + str(round(skt_mape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt smape: ' + str(round(skt_smape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt mae: ' + str(round(skt_mae(yTargetYield, pred_Df), 3)))
    print('skt mse: ' + str(round(skt_mse(yTargetYield, pred_Df), 3)))
    print('skt rmse: ' + str(round(math.sqrt(skt_mse(yTargetYield, pred_Df)), 3)) + '\n\n')
    
    #accuracy = accuracy_score(yTest, pred)
    
    return(meanAbsoluteError, r)
    

#     # add the errors and R Squared to average values
#     avgMAE += meanAbsoluteError
#     avgRSq += rSq

#     # check to see which metric should be optimized
#     if metricToOptimize == 'r2':
#         # check to see if any of these are the best values
#         if (rSq > bestRSq):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     elif metricToOptimize == 'mae':
#         # check to see if any of these are the best values
#         if (meanAbsoluteError < bestMAE):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     else:
#         raise ValueError("The input 'metricToOptimize' does not have a valid input. It must be 'r2' or 'mae'.")

# %%
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import joblib
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import math

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sktime.utils.plotting import plot_series

# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, matthews_corrcoef
from sktime.performance_metrics.forecasting import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVR  # support vector machines regression
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import AdaBoostRegressor # adaboost for regression
import xgboost as xgb

skt_mape = MeanAbsolutePercentageError(symmetric=False)
skt_smape = MeanAbsolutePercentageError(symmetric=True)
skt_mae = MeanAbsoluteError()
skt_mse = MeanSquaredError()
