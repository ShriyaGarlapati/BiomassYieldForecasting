# %%
############## imports
# general
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score  
# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVC  # support vector machines classification
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.neural_network import MLPClassifier # neural network for classification
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier # adaboost for classification
import xgboost as xgb
# saving models
# from sklearn.externals import joblib
import joblib
import matplotlib.pyplot as plt

# %%
import pandas as pd
import random
import math

# read in time point 1 for training
# train on it - model 1
# test on tp 2
# read tp 2
# add it to xgb - model 2
# test on tp 3
# read tp 3
# add it to xgb - model 3
# test on tp 4
# test model 1
data = pd.read_csv('data_no_2022_synthesized_nonstationary.csv')
data.head()
# Out:
#       yield      radiation         rain  avg_min_temp  avg_max_temp  class
# 0  0.817368  145371.110000  1366.670000      4.954500     15.518700      0
# 1  0.874125  142949.843845  1344.832988      4.791971     15.344386      0
# 2  0.846525  142842.308609  1346.214549      4.914546     15.426038      0
# 3  0.877274  142900.257827  1357.085297      4.917147     15.400980      0
# 4  0.825473  144626.302874  1352.535931      4.946359     15.449849      0

# %%
print(len(data))
# Out:
# 20008

# %%
data = data.rename(columns={'Yield (tons/acre)':'yield'})

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
xDf = data[xColumnsToKeep]


yDf = data[yColumnsToKeep]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression, SelectPercentile
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error


# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# XGBoost model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Create the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb_model)
])

# Train the pipeline
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Mean Squared Error (MSE)
#mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
#rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Absolute Error (MAE): 0.1644994685915814
# R² (Coefficient of Determination): 0.8137898822389433
# Pearson's Correlation Coefficient (R): 0.9025638592644251
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.50070800298904

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array
# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Use cross-validation to evaluate the model (this ensures better generalization)
    score = cross_val_score(pipe, X_train, y_train, scoring='neg_mean_squared_error', cv=3)
    
    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return r2
    # Return the negative mean squared error (we want to minimize this)
    

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')  # Minimize RMSE or MSE
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)


# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-05 10:07:37,447] A new study created in memory with name: no-name-490b2c1f-8b47-4116-bbf0-591850e1bb5d
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:37,733] Trial 0 finished with value: 0.8321325177380559 and parameters: {'n_estimators': 76, 'max_depth': 8, 'learning_rate': 0.12623740880879084, 'subsample': 0.6800424486637715, 'colsample_bytree': 0.5250137433137501, 'gamma': 0.2716622165694399, 'min_child_weight': 10, 'reg_alpha': 0.06165974709853339, 'reg_lambda': 0.679901165591954}. Best is trial 0 with value: 0.8321325177380559.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:38,551] Trial 1 finished with value: 0.8318114135552906 and parameters: {'n_estimators': 215, 'max_depth': 10, 'learning_rate': 0.08938966840794602, 'subsample': 0.7936528117909573, 'colsample_bytree': 0.8005279757134709, 'gamma': 0.1900592859150358, 'min_child_weight': 1, 'reg_alpha': 0.1899757775868085, 'reg_lambda': 0.13718227934173777}. Best is trial 0 with value: 0.8321325177380559.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:39,140] Trial 2 finished with value: 0.8312394879301109 and parameters: {'n_estimators': 279, 'max_depth': 9, 'learning_rate': 0.16624841795741518, 'subsample': 0.7335786129413914, 'colsample_bytree': 0.812069909289792, 'gamma': 0.49455047653193607, 'min_child_weight': 6, 'reg_alpha': 0.9666085389350731, 'reg_lambda': 0.8780493445890872}. Best is trial 0 with value: 0.8321325177380559.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:39,670] Trial 3 finished with value: 0.8311664546314823 and parameters: {'n_estimators': 246, 'max_depth': 4, 'learning_rate': 0.17569886367389245, 'subsample': 0.8429043898708759, 'colsample_bytree': 0.9235043360003512, 'gamma': 0.4099765385089704, 'min_child_weight': 6, 'reg_alpha': 0.28918441441110376, 'reg_lambda': 0.3973998597047895}. Best is trial 0 with value: 0.8321325177380559.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:40,133] Trial 4 finished with value: 0.8319958781242575 and parameters: {'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.05943134748586679, 'subsample': 0.6409476479148353, 'colsample_bytree': 0.5083209592857607, 'gamma': 0.369018807039152, 'min_child_weight': 9, 'reg_alpha': 0.748456021028085, 'reg_lambda': 0.9678222371479321}. Best is trial 0 with value: 0.8321325177380559.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:40,971] Trial 5 finished with value: 0.8272735952143511 and parameters: {'n_estimators': 140, 'max_depth': 7, 'learning_rate': 0.16207925256690478, 'subsample': 0.6458566029495495, 'colsample_bytree': 0.633523750731989, 'gamma': 0.0913569037030017, 'min_child_weight': 3, 'reg_alpha': 0.12459694142719513, 'reg_lambda': 0.6404051782540248}. Best is trial 0 with value: 0.8321325177380559.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:41,513] Trial 6 finished with value: 0.8321443932933156 and parameters: {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.12035232917311725, 'subsample': 0.8516559840287938, 'colsample_bytree': 0.6940852079440067, 'gamma': 0.427026137633103, 'min_child_weight': 3, 'reg_alpha': 0.1805369142343668, 'reg_lambda': 0.09677650145135941}. Best is trial 6 with value: 0.8321443932933156.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:41,846] Trial 7 finished with value: 0.8319757738884833 and parameters: {'n_estimators': 137, 'max_depth': 4, 'learning_rate': 0.09638429730557305, 'subsample': 0.902868922701093, 'colsample_bytree': 0.9061562303906654, 'gamma': 0.26958276349219346, 'min_child_weight': 4, 'reg_alpha': 0.665206661899059, 'reg_lambda': 0.47719825172133334}. Best is trial 6 with value: 0.8321443932933156.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:42,405] Trial 8 finished with value: 0.831318847671281 and parameters: {'n_estimators': 280, 'max_depth': 5, 'learning_rate': 0.11549047902987437, 'subsample': 0.7143617865976157, 'colsample_bytree': 0.9012670157898071, 'gamma': 0.4261075153852006, 'min_child_weight': 8, 'reg_alpha': 0.3582182287844551, 'reg_lambda': 0.0263601712338265}. Best is trial 6 with value: 0.8321443932933156.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:43,184] Trial 9 finished with value: 0.8316217096085099 and parameters: {'n_estimators': 271, 'max_depth': 9, 'learning_rate': 0.16931110140203717, 'subsample': 0.6946023936823569, 'colsample_bytree': 0.5114618302356343, 'gamma': 0.14096462032135654, 'min_child_weight': 10, 'reg_alpha': 0.5858912615092063, 'reg_lambda': 0.46038015887610995}. Best is trial 6 with value: 0.8321443932933156.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:45,259] Trial 10 finished with value: 0.8279996199445705 and parameters: {'n_estimators': 199, 'max_depth': 10, 'learning_rate': 0.013149755012070025, 'subsample': 0.9903141701276511, 'colsample_bytree': 0.6785004912266464, 'gamma': 0.031680273621769006, 'min_child_weight': 1, 'reg_alpha': 0.4445182049098698, 'reg_lambda': 0.24924692506792215}. Best is trial 6 with value: 0.8321443932933156.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:45,527] Trial 11 finished with value: 0.8318839113748159 and parameters: {'n_estimators': 64, 'max_depth': 8, 'learning_rate': 0.12159821359896272, 'subsample': 0.5003282259973469, 'colsample_bytree': 0.606988142371067, 'gamma': 0.28784201871992343, 'min_child_weight': 4, 'reg_alpha': 0.027639939273916836, 'reg_lambda': 0.729058628478223}. Best is trial 6 with value: 0.8321443932933156.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:45,798] Trial 12 finished with value: 0.8319002115257177 and parameters: {'n_estimators': 60, 'max_depth': 8, 'learning_rate': 0.13465294756786825, 'subsample': 0.5677034141633119, 'colsample_bytree': 0.7163461598235565, 'gamma': 0.2843132149035286, 'min_child_weight': 7, 'reg_alpha': 0.01321789668116044, 'reg_lambda': 0.6666025509418605}. Best is trial 6 with value: 0.8321443932933156.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:46,155] Trial 13 finished with value: 0.8321643974803423 and parameters: {'n_estimators': 102, 'max_depth': 6, 'learning_rate': 0.06801677879880166, 'subsample': 0.8806166540699828, 'colsample_bytree': 0.5840835917456846, 'gamma': 0.33950062531548075, 'min_child_weight': 3, 'reg_alpha': 0.2214022972343434, 'reg_lambda': 0.3000943559166783}. Best is trial 13 with value: 0.8321643974803423.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:46,536] Trial 14 finished with value: 0.8321953170163617 and parameters: {'n_estimators': 102, 'max_depth': 6, 'learning_rate': 0.056132938345824446, 'subsample': 0.9056176078182929, 'colsample_bytree': 0.6037231737782703, 'gamma': 0.36271654282550586, 'min_child_weight': 3, 'reg_alpha': 0.2373710588663201, 'reg_lambda': 0.2634199799533566}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:46,925] Trial 15 finished with value: 0.8321723742129765 and parameters: {'n_estimators': 102, 'max_depth': 6, 'learning_rate': 0.049734616719992256, 'subsample': 0.977030960557445, 'colsample_bytree': 0.6007450204953755, 'gamma': 0.35288623577137396, 'min_child_weight': 2, 'reg_alpha': 0.3016886613373593, 'reg_lambda': 0.291992810548829}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:47,363] Trial 16 finished with value: 0.8294326880558094 and parameters: {'n_estimators': 113, 'max_depth': 3, 'learning_rate': 0.024950838171982778, 'subsample': 0.9878666080841246, 'colsample_bytree': 0.5770389325425503, 'gamma': 0.4977770341033868, 'min_child_weight': 2, 'reg_alpha': 0.4279826715565407, 'reg_lambda': 0.2805899854927238}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:47,792] Trial 17 finished with value: 0.8314480413081649 and parameters: {'n_estimators': 98, 'max_depth': 6, 'learning_rate': 0.039801760121947624, 'subsample': 0.9343963367916625, 'colsample_bytree': 0.7573357118404663, 'gamma': 0.20804209079992575, 'min_child_weight': 5, 'reg_alpha': 0.2998923329332279, 'reg_lambda': 0.18601590449302832}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:48,289] Trial 18 finished with value: 0.8319559889474489 and parameters: {'n_estimators': 187, 'max_depth': 5, 'learning_rate': 0.05953697877010615, 'subsample': 0.7902733340663033, 'colsample_bytree': 0.9911094652659984, 'gamma': 0.33720798000021923, 'min_child_weight': 2, 'reg_alpha': 0.5624065571170012, 'reg_lambda': 0.3524396846665254}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:48,711] Trial 19 finished with value: 0.8321731332084021 and parameters: {'n_estimators': 163, 'max_depth': 5, 'learning_rate': 0.07709525145228721, 'subsample': 0.9422878252110213, 'colsample_bytree': 0.6451932225426575, 'gamma': 0.37494369156067786, 'min_child_weight': 4, 'reg_alpha': 0.3409145618360893, 'reg_lambda': 0.5696651897122522}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:49,114] Trial 20 finished with value: 0.8317755906124671 and parameters: {'n_estimators': 154, 'max_depth': 5, 'learning_rate': 0.07853935735727263, 'subsample': 0.9160294909322917, 'colsample_bytree': 0.6526616915513725, 'gamma': 0.3986754533750185, 'min_child_weight': 5, 'reg_alpha': 0.8126671190777527, 'reg_lambda': 0.7818895015523744}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:49,534] Trial 21 finished with value: 0.8320996775259911 and parameters: {'n_estimators': 116, 'max_depth': 6, 'learning_rate': 0.0430267606743921, 'subsample': 0.9524396473113447, 'colsample_bytree': 0.5597718827730567, 'gamma': 0.34112025216973957, 'min_child_weight': 4, 'reg_alpha': 0.35520729315935623, 'reg_lambda': 0.5720078131974102}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:49,868] Trial 22 finished with value: 0.831742503459851 and parameters: {'n_estimators': 85, 'max_depth': 4, 'learning_rate': 0.043184021448809826, 'subsample': 0.9451934280817678, 'colsample_bytree': 0.6293672531995474, 'gamma': 0.46058945525970607, 'min_child_weight': 2, 'reg_alpha': 0.28639775043315074, 'reg_lambda': 0.5447610769150053}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:50,307] Trial 23 finished with value: 0.8320443565700082 and parameters: {'n_estimators': 174, 'max_depth': 5, 'learning_rate': 0.07906318767739141, 'subsample': 0.8619373572686346, 'colsample_bytree': 0.552333839359118, 'gamma': 0.3659857331857635, 'min_child_weight': 4, 'reg_alpha': 0.506207470577932, 'reg_lambda': 0.39502270411192386}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:50,558] Trial 24 finished with value: 0.7887820789483666 and parameters: {'n_estimators': 50, 'max_depth': 7, 'learning_rate': 0.028923845598196125, 'subsample': 0.8005389819104162, 'colsample_bytree': 0.7502083691818545, 'gamma': 0.316435881747871, 'min_child_weight': 2, 'reg_alpha': 0.4209956747488912, 'reg_lambda': 0.2135064206621041}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:51,075] Trial 25 finished with value: 0.8321857985398935 and parameters: {'n_estimators': 126, 'max_depth': 6, 'learning_rate': 0.05418961581852831, 'subsample': 0.9935606439875312, 'colsample_bytree': 0.6630805961970286, 'gamma': 0.21611785668278868, 'min_child_weight': 3, 'reg_alpha': 0.11188711596587517, 'reg_lambda': 0.3512429786299378}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:51,436] Trial 26 finished with value: 0.8316876432512046 and parameters: {'n_estimators': 164, 'max_depth': 3, 'learning_rate': 0.1991962278910968, 'subsample': 0.891825297448334, 'colsample_bytree': 0.6889050633638552, 'gamma': 0.2186190538905578, 'min_child_weight': 5, 'reg_alpha': 0.12957285962293366, 'reg_lambda': 0.573414462626223}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:51,918] Trial 27 finished with value: 0.832168202795897 and parameters: {'n_estimators': 126, 'max_depth': 5, 'learning_rate': 0.07500777403099093, 'subsample': 0.953095792362177, 'colsample_bytree': 0.657550718926584, 'gamma': 0.1774944237587918, 'min_child_weight': 3, 'reg_alpha': 0.12937466189659977, 'reg_lambda': 0.43644006990675227}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:07:52,399] Trial 28 finished with value: 0.8318934334397537 and parameters: {'n_estimators': 204, 'max_depth': 7, 'learning_rate': 0.10327768634773776, 'subsample': 0.9973071349192557, 'colsample_bytree': 0.7336146898389891, 'gamma': 0.23699824984085985, 'min_child_weight': 7, 'reg_alpha': 0.08740714715464738, 'reg_lambda': 0.5120218927731031}. Best is trial 14 with value: 0.8321953170163617.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:24,177] Trial 90 finished with value: 0.8322541501797378 and parameters: {'n_estimators': 193, 'max_depth': 10, 'learning_rate': 0.10218337418371634, 'subsample': 0.9837850546631275, 'colsample_bytree': 0.5142951101778597, 'gamma': 0.289984869601866, 'min_child_weight': 4, 'reg_alpha': 0.056527401368829965, 'reg_lambda': 0.002845975508606404}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:24,641] Trial 91 finished with value: 0.8322976621774469 and parameters: {'n_estimators': 178, 'max_depth': 10, 'learning_rate': 0.11140193093122576, 'subsample': 0.9993195806987529, 'colsample_bytree': 0.5106144921285243, 'gamma': 0.27038500064141824, 'min_child_weight': 4, 'reg_alpha': 0.08928253615724854, 'reg_lambda': 0.02734072404705816}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:25,095] Trial 92 finished with value: 0.8323508129929724 and parameters: {'n_estimators': 163, 'max_depth': 10, 'learning_rate': 0.10487315400415123, 'subsample': 0.9892507444803155, 'colsample_bytree': 0.511671555799598, 'gamma': 0.2424676681147643, 'min_child_weight': 4, 'reg_alpha': 0.02624248814651874, 'reg_lambda': 0.02520839077408573}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:25,529] Trial 93 finished with value: 0.8323562434348708 and parameters: {'n_estimators': 163, 'max_depth': 10, 'learning_rate': 0.10589569442085264, 'subsample': 0.9867835632152139, 'colsample_bytree': 0.52385645293403, 'gamma': 0.24324141571953523, 'min_child_weight': 4, 'reg_alpha': 0.019036513987170052, 'reg_lambda': 0.0009506100510180554}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:25,910] Trial 94 finished with value: 0.8318725254913317 and parameters: {'n_estimators': 146, 'max_depth': 10, 'learning_rate': 0.10520999857195486, 'subsample': 0.9829695916652064, 'colsample_bytree': 0.5252677711447795, 'gamma': 0.2558370606708641, 'min_child_weight': 5, 'reg_alpha': 0.022510841453317703, 'reg_lambda': 0.0010419816861411586}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:26,350] Trial 95 finished with value: 0.832132704815987 and parameters: {'n_estimators': 157, 'max_depth': 10, 'learning_rate': 0.09062602445982745, 'subsample': 0.9587011749632899, 'colsample_bytree': 0.5398980368884309, 'gamma': 0.2397720220212631, 'min_child_weight': 4, 'reg_alpha': 0.04669489471450057, 'reg_lambda': 0.029831239264570965}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:26,809] Trial 96 finished with value: 0.8317522709939018 and parameters: {'n_estimators': 164, 'max_depth': 10, 'learning_rate': 0.08739717291722451, 'subsample': 0.9724969012181813, 'colsample_bytree': 0.5522084912543529, 'gamma': 0.23447472477900144, 'min_child_weight': 5, 'reg_alpha': 0.06304856095411054, 'reg_lambda': 0.02452476506722052}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:27,329] Trial 97 finished with value: 0.832202272178431 and parameters: {'n_estimators': 198, 'max_depth': 10, 'learning_rate': 0.096303048935965, 'subsample': 0.9921309474406275, 'colsample_bytree': 0.524369491934465, 'gamma': 0.19122286841235495, 'min_child_weight': 4, 'reg_alpha': 0.020346232597322645, 'reg_lambda': 0.04653257893792367}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:27,721] Trial 98 finished with value: 0.8321691020189328 and parameters: {'n_estimators': 136, 'max_depth': 10, 'learning_rate': 0.08141123618620563, 'subsample': 0.9888465129439458, 'colsample_bytree': 0.5348064039384313, 'gamma': 0.27891879515078494, 'min_child_weight': 4, 'reg_alpha': 0.13333559990723093, 'reg_lambda': 0.43300945909255134}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:08:28,080] Trial 99 finished with value: 0.8319262242143932 and parameters: {'n_estimators': 151, 'max_depth': 10, 'learning_rate': 0.11418193326621519, 'subsample': 0.9740083242116908, 'colsample_bytree': 0.511983561012352, 'gamma': 0.24597108394763811, 'min_child_weight': 5, 'reg_alpha': 0.041840355931888236, 'reg_lambda': 0.10100856540868335}. Best is trial 87 with value: 0.832383169001078.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'n_estimators': 181, 'max_depth': 10, 'learning_rate': 0.10040103332436633, 'subsample': 0.9538270129764543, 'colsample_bytree': 0.5288222600623113, 'gamma': 0.27921037474297994, 'min_child_weight': 4, 'reg_alpha': 0.03145832940939054, 'reg_lambda': 0.000998521825264925}
# Mean Absolute Error (MAE): 0.15890643975692406
# R² (Coefficient of Determination): 0.832383169001078
# Pearson's Correlation Coefficient (R): 0.9123980944806638
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.364544077074473

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile
import numpy as np

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return mae

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize')  # Maximize the combined objective
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)

# Print evaluation metrics
mae = mean_absolute_error(y_test_flat, y_pred)
r2 = r2_score(y_test_flat, y_pred)
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]
smape_value = smape(y_test_flat, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-05 10:15:15,501] A new study created in memory with name: no-name-085fbd3e-ddf5-4119-bbb9-a052d62f8b61
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:15,548] Trial 0 finished with value: 0.15913600146394127 and parameters: {'n_estimators': 50, 'max_depth': 3, 'learning_rate': 0.1386605392635004, 'subsample': 0.5171358860372817, 'colsample_bytree': 0.8232523708038684, 'gamma': 0.3939955703572752, 'min_child_weight': 7, 'reg_alpha': 0.8973579547954174, 'reg_lambda': 0.8075187966693714}. Best is trial 0 with value: 0.15913600146394127.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:15,640] Trial 1 finished with value: 0.15923840943509968 and parameters: {'n_estimators': 159, 'max_depth': 4, 'learning_rate': 0.09235413047903088, 'subsample': 0.6923540838117912, 'colsample_bytree': 0.9816443251875759, 'gamma': 0.4396238272797985, 'min_child_weight': 9, 'reg_alpha': 0.14916998820521032, 'reg_lambda': 0.02949343504692592}. Best is trial 0 with value: 0.15913600146394127.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:16,004] Trial 2 finished with value: 0.15893577285126295 and parameters: {'n_estimators': 225, 'max_depth': 9, 'learning_rate': 0.03077893068043666, 'subsample': 0.7095320497157331, 'colsample_bytree': 0.5801844973816878, 'gamma': 0.12820830798734634, 'min_child_weight': 3, 'reg_alpha': 0.5183109632133308, 'reg_lambda': 0.6870849310604918}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:16,074] Trial 3 finished with value: 0.15904050198189934 and parameters: {'n_estimators': 114, 'max_depth': 4, 'learning_rate': 0.14628435089928807, 'subsample': 0.8793735171271742, 'colsample_bytree': 0.6233746830432819, 'gamma': 0.3424278609966771, 'min_child_weight': 1, 'reg_alpha': 0.889262499552324, 'reg_lambda': 0.3094077252120754}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:16,392] Trial 4 finished with value: 0.1619917102654782 and parameters: {'n_estimators': 244, 'max_depth': 5, 'learning_rate': 0.01330440821059852, 'subsample': 0.6535788731871859, 'colsample_bytree': 0.6268021341886711, 'gamma': 0.12757141903449776, 'min_child_weight': 9, 'reg_alpha': 0.7574250023100277, 'reg_lambda': 0.9303078517415606}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:16,565] Trial 5 finished with value: 0.1590366618933506 and parameters: {'n_estimators': 225, 'max_depth': 6, 'learning_rate': 0.05131316964348188, 'subsample': 0.521143441883434, 'colsample_bytree': 0.8629334753716162, 'gamma': 0.37377944078715447, 'min_child_weight': 1, 'reg_alpha': 0.6263548507568915, 'reg_lambda': 0.2650037043094372}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:16,650] Trial 6 finished with value: 0.15912793134225853 and parameters: {'n_estimators': 135, 'max_depth': 10, 'learning_rate': 0.14036403421398505, 'subsample': 0.9281676203243361, 'colsample_bytree': 0.8109324374843838, 'gamma': 0.26416846445193376, 'min_child_weight': 6, 'reg_alpha': 0.5353984628165593, 'reg_lambda': 0.37183699954939453}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:16,761] Trial 7 finished with value: 0.15920471009510492 and parameters: {'n_estimators': 77, 'max_depth': 10, 'learning_rate': 0.1429305190833782, 'subsample': 0.8772993422369446, 'colsample_bytree': 0.7014041823202609, 'gamma': 0.10038710456752248, 'min_child_weight': 6, 'reg_alpha': 0.8879429917897694, 'reg_lambda': 0.9772766821017342}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:17,017] Trial 8 finished with value: 0.15913019769605835 and parameters: {'n_estimators': 286, 'max_depth': 6, 'learning_rate': 0.021893392045062566, 'subsample': 0.7724566527638443, 'colsample_bytree': 0.6903447117403216, 'gamma': 0.3162608272228205, 'min_child_weight': 7, 'reg_alpha': 0.06667194366123763, 'reg_lambda': 0.6896184652441608}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:17,347] Trial 9 finished with value: 0.15902344068819027 and parameters: {'n_estimators': 258, 'max_depth': 8, 'learning_rate': 0.0234631585984832, 'subsample': 0.654554586474943, 'colsample_bytree': 0.5151459670856857, 'gamma': 0.16531729319893146, 'min_child_weight': 10, 'reg_alpha': 0.3900320891005581, 'reg_lambda': 0.1774394996726344}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:17,907] Trial 10 finished with value: 0.16043628239910154 and parameters: {'n_estimators': 199, 'max_depth': 8, 'learning_rate': 0.07642310757066506, 'subsample': 0.7838133018559716, 'colsample_bytree': 0.5030893409049348, 'gamma': 0.007677729144956111, 'min_child_weight': 3, 'reg_alpha': 0.34370838079075666, 'reg_lambda': 0.5386208424396156}. Best is trial 2 with value: 0.15893577285126295.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:18,256] Trial 11 finished with value: 0.15893559362993953 and parameters: {'n_estimators': 300, 'max_depth': 8, 'learning_rate': 0.04397790539474368, 'subsample': 0.6132700858442439, 'colsample_bytree': 0.5073555492484865, 'gamma': 0.17083775708066654, 'min_child_weight': 4, 'reg_alpha': 0.3463192963277943, 'reg_lambda': 0.016123268544774277}. Best is trial 11 with value: 0.15893559362993953.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:18,468] Trial 12 finished with value: 0.1589611279024507 and parameters: {'n_estimators': 295, 'max_depth': 8, 'learning_rate': 0.1955765614691632, 'subsample': 0.5967012436045049, 'colsample_bytree': 0.5829530913387033, 'gamma': 0.19282725504253923, 'min_child_weight': 4, 'reg_alpha': 0.29262262049098925, 'reg_lambda': 0.6100876613189731}. Best is trial 11 with value: 0.15893559362993953.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:18,883] Trial 13 finished with value: 0.1599863076855133 and parameters: {'n_estimators': 206, 'max_depth': 9, 'learning_rate': 0.055136488902694375, 'subsample': 0.7254598570031187, 'colsample_bytree': 0.5642814535469675, 'gamma': 0.0437841935043993, 'min_child_weight': 3, 'reg_alpha': 0.510790635534853, 'reg_lambda': 0.013318912162276875}. Best is trial 11 with value: 0.15893559362993953.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:19,111] Trial 14 finished with value: 0.15890393015690338 and parameters: {'n_estimators': 269, 'max_depth': 7, 'learning_rate': 0.05363288492869385, 'subsample': 0.5951567249998201, 'colsample_bytree': 0.6742675589363144, 'gamma': 0.23879189184078586, 'min_child_weight': 4, 'reg_alpha': 0.21646876578077434, 'reg_lambda': 0.4335087309105684}. Best is trial 14 with value: 0.15890393015690338.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:19,322] Trial 15 finished with value: 0.15888414584411523 and parameters: {'n_estimators': 271, 'max_depth': 7, 'learning_rate': 0.06145958185275231, 'subsample': 0.5846247444996441, 'colsample_bytree': 0.7373510596162376, 'gamma': 0.2399697667818829, 'min_child_weight': 4, 'reg_alpha': 0.20802890893913592, 'reg_lambda': 0.44322187759489434}. Best is trial 15 with value: 0.15888414584411523.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:19,471] Trial 16 finished with value: 0.15913185994970622 and parameters: {'n_estimators': 260, 'max_depth': 7, 'learning_rate': 0.07570370802227644, 'subsample': 0.5822416045971509, 'colsample_bytree': 0.7517089531613083, 'gamma': 0.26160343279106696, 'min_child_weight': 5, 'reg_alpha': 0.19188794264588904, 'reg_lambda': 0.4362988322814245}. Best is trial 15 with value: 0.15888414584411523.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:19,589] Trial 17 finished with value: 0.15900149704738265 and parameters: {'n_estimators': 185, 'max_depth': 7, 'learning_rate': 0.11768451185945869, 'subsample': 0.5466131344461692, 'colsample_bytree': 0.7219365820920188, 'gamma': 0.48934236508206586, 'min_child_weight': 2, 'reg_alpha': 0.03262581307097487, 'reg_lambda': 0.49196833713281024}. Best is trial 15 with value: 0.15888414584411523.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:19,770] Trial 18 finished with value: 0.15911316793994754 and parameters: {'n_estimators': 265, 'max_depth': 5, 'learning_rate': 0.07162568514774534, 'subsample': 0.8070695533009813, 'colsample_bytree': 0.7681304343053759, 'gamma': 0.22987535282222107, 'min_child_weight': 5, 'reg_alpha': 0.23074447496922035, 'reg_lambda': 0.2040042056139988}. Best is trial 15 with value: 0.15888414584411523.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:19,899] Trial 19 finished with value: 0.15909285665043488 and parameters: {'n_estimators': 165, 'max_depth': 6, 'learning_rate': 0.10395348179017701, 'subsample': 0.6450294759298865, 'colsample_bytree': 0.8951321608113232, 'gamma': 0.30021159245608475, 'min_child_weight': 4, 'reg_alpha': 0.11111432406924045, 'reg_lambda': 0.4127827125735217}. Best is trial 15 with value: 0.15888414584411523.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:20,100] Trial 20 finished with value: 0.1588171979826301 and parameters: {'n_estimators': 221, 'max_depth': 7, 'learning_rate': 0.06119958364498297, 'subsample': 0.5727470863222256, 'colsample_bytree': 0.6618991106490061, 'gamma': 0.22002715841382195, 'min_child_weight': 7, 'reg_alpha': 0.2577882710013915, 'reg_lambda': 0.5830296047547843}. Best is trial 20 with value: 0.1588171979826301.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:20,286] Trial 21 finished with value: 0.15881246323032167 and parameters: {'n_estimators': 229, 'max_depth': 7, 'learning_rate': 0.06226591822649733, 'subsample': 0.5648996976792365, 'colsample_bytree': 0.6685314036359298, 'gamma': 0.2274091478443304, 'min_child_weight': 7, 'reg_alpha': 0.2411208287942267, 'reg_lambda': 0.5785279003584719}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:20,475] Trial 22 finished with value: 0.15886124612671199 and parameters: {'n_estimators': 230, 'max_depth': 7, 'learning_rate': 0.08977506281637848, 'subsample': 0.5518543620781443, 'colsample_bytree': 0.6554046191961599, 'gamma': 0.21006434373560254, 'min_child_weight': 8, 'reg_alpha': 0.4245804922931132, 'reg_lambda': 0.5740950845265866}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:20,674] Trial 23 finished with value: 0.15884599572580999 and parameters: {'n_estimators': 230, 'max_depth': 5, 'learning_rate': 0.09349843671168581, 'subsample': 0.5475171398937516, 'colsample_bytree': 0.6436199954078168, 'gamma': 0.19820867522330907, 'min_child_weight': 8, 'reg_alpha': 0.42690243345922824, 'reg_lambda': 0.618040482357161}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:20,812] Trial 24 finished with value: 0.15889466752569817 and parameters: {'n_estimators': 199, 'max_depth': 4, 'learning_rate': 0.11533523456879916, 'subsample': 0.5176532766556284, 'colsample_bytree': 0.6211509916146541, 'gamma': 0.2885161078753439, 'min_child_weight': 8, 'reg_alpha': 0.660134916042445, 'reg_lambda': 0.7684312530463246}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:21,179] Trial 25 finished with value: 0.15897747855337444 and parameters: {'n_estimators': 213, 'max_depth': 5, 'learning_rate': 0.03960694884594384, 'subsample': 0.503612864219819, 'colsample_bytree': 0.6474006158450699, 'gamma': 0.07051228633220491, 'min_child_weight': 7, 'reg_alpha': 0.4376710050688597, 'reg_lambda': 0.6546018619000502}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:21,422] Trial 26 finished with value: 0.15901678019424537 and parameters: {'n_estimators': 240, 'max_depth': 6, 'learning_rate': 0.09174716216356522, 'subsample': 0.6302795804847242, 'colsample_bytree': 0.5569988682029517, 'gamma': 0.15577010320708967, 'min_child_weight': 8, 'reg_alpha': 0.2852969487474833, 'reg_lambda': 0.8088594365198176}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:21,614] Trial 27 finished with value: 0.15883078483812715 and parameters: {'n_estimators': 184, 'max_depth': 5, 'learning_rate': 0.0661161138557536, 'subsample': 0.5652934348884558, 'colsample_bytree': 0.7809449873192854, 'gamma': 0.18872649424708343, 'min_child_weight': 10, 'reg_alpha': 0.603268135340848, 'reg_lambda': 0.7517591324118097}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:21,886] Trial 28 finished with value: 0.15906689450972275 and parameters: {'n_estimators': 143, 'max_depth': 9, 'learning_rate': 0.06265475534665957, 'subsample': 0.6834528127271863, 'colsample_bytree': 0.7785494317942206, 'gamma': 0.11729035950373706, 'min_child_weight': 10, 'reg_alpha': 0.660338886867296, 'reg_lambda': 0.8965694081484652}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:22,034] Trial 29 finished with value: 0.15916474951794926 and parameters: {'n_estimators': 180, 'max_depth': 3, 'learning_rate': 0.03655804370986844, 'subsample': 0.5615615583380202, 'colsample_bytree': 0.80568464462782, 'gamma': 0.33673590140312426, 'min_child_weight': 9, 'reg_alpha': 0.7683027743329129, 'reg_lambda': 0.7559875994864255}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:22,120] Trial 30 finished with value: 0.15916110415625845 and parameters: {'n_estimators': 109, 'max_depth': 3, 'learning_rate': 0.159174641836013, 'subsample': 0.667964817403417, 'colsample_bytree': 0.8558764359473605, 'gamma': 0.27797132812033465, 'min_child_weight': 6, 'reg_alpha': 0.5941219032993194, 'reg_lambda': 0.879258695197312}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:22,293] Trial 31 finished with value: 0.15894025543338755 and parameters: {'n_estimators': 188, 'max_depth': 5, 'learning_rate': 0.08303388773550946, 'subsample': 0.5465084858215936, 'colsample_bytree': 0.7126423113438638, 'gamma': 0.20280376840010622, 'min_child_weight': 7, 'reg_alpha': 0.46503069668674124, 'reg_lambda': 0.6083644270131457}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:22,434] Trial 32 finished with value: 0.15914508911457745 and parameters: {'n_estimators': 217, 'max_depth': 6, 'learning_rate': 0.09939153410638188, 'subsample': 0.995033474357808, 'colsample_bytree': 0.6711042534177434, 'gamma': 0.18445841443956343, 'min_child_weight': 9, 'reg_alpha': 0.2917514753090375, 'reg_lambda': 0.5079307397525877}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:22,631] Trial 33 finished with value: 0.1592357904616485 and parameters: {'n_estimators': 244, 'max_depth': 4, 'learning_rate': 0.11918574334029029, 'subsample': 0.6230833523374573, 'colsample_bytree': 0.9113366364044759, 'gamma': 0.14868980204035176, 'min_child_weight': 8, 'reg_alpha': 0.14845866555001447, 'reg_lambda': 0.700999011509582}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:22,788] Trial 34 finished with value: 0.1589692774271266 and parameters: {'n_estimators': 166, 'max_depth': 5, 'learning_rate': 0.06845175801841583, 'subsample': 0.5726469359259581, 'colsample_bytree': 0.6071131786357822, 'gamma': 0.21771096293638903, 'min_child_weight': 10, 'reg_alpha': 0.36791932759861445, 'reg_lambda': 0.6325351996085038}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:22,988] Trial 35 finished with value: 0.15910794178332593 and parameters: {'n_estimators': 148, 'max_depth': 4, 'learning_rate': 0.08440513854325246, 'subsample': 0.5018651653664135, 'colsample_bytree': 0.6396758405241669, 'gamma': 0.0946984083768604, 'min_child_weight': 8, 'reg_alpha': 0.5605508225126463, 'reg_lambda': 0.7470686859721389}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:23,132] Trial 36 finished with value: 0.15895427302453544 and parameters: {'n_estimators': 234, 'max_depth': 5, 'learning_rate': 0.10000350283667443, 'subsample': 0.5392012207912529, 'colsample_bytree': 0.5865055735229933, 'gamma': 0.4159242374075245, 'min_child_weight': 9, 'reg_alpha': 0.7252513218392893, 'reg_lambda': 0.5487303475463924}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:23,275] Trial 37 finished with value: 0.1591559500270104 and parameters: {'n_estimators': 196, 'max_depth': 6, 'learning_rate': 0.04835934318743222, 'subsample': 0.7099913831919129, 'colsample_bytree': 0.7740069723531029, 'gamma': 0.3658983746253634, 'min_child_weight': 7, 'reg_alpha': 0.27224973250378753, 'reg_lambda': 0.8262005637882208}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:23,558] Trial 38 finished with value: 0.15937132578844107 and parameters: {'n_estimators': 225, 'max_depth': 7, 'learning_rate': 0.12922086802156993, 'subsample': 0.5291942614115468, 'colsample_bytree': 0.9721065919102386, 'gamma': 0.14067877865451406, 'min_child_weight': 6, 'reg_alpha': 0.48907605764872253, 'reg_lambda': 0.3394095761476578}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:23,635] Trial 39 finished with value: 0.16066609869393403 and parameters: {'n_estimators': 55, 'max_depth': 6, 'learning_rate': 0.06275887982174626, 'subsample': 0.5640762928749278, 'colsample_bytree': 0.7338582234562735, 'gamma': 0.26064015225284787, 'min_child_weight': 9, 'reg_alpha': 0.8285939283386599, 'reg_lambda': 0.7027435877122857}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:23,984] Trial 40 finished with value: 0.15897414739427063 and parameters: {'n_estimators': 250, 'max_depth': 9, 'learning_rate': 0.027462037038759393, 'subsample': 0.602466886207803, 'colsample_bytree': 0.6952283031143609, 'gamma': 0.18470140027695736, 'min_child_weight': 10, 'reg_alpha': 0.14206906768696442, 'reg_lambda': 0.8514094101676533}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:24,168] Trial 41 finished with value: 0.15896098946210852 and parameters: {'n_estimators': 232, 'max_depth': 7, 'learning_rate': 0.08807516821429219, 'subsample': 0.5572963693022519, 'colsample_bytree': 0.660889622854253, 'gamma': 0.2176266534124433, 'min_child_weight': 8, 'reg_alpha': 0.40829946482976337, 'reg_lambda': 0.567495534942461}. Best is trial 21 with value: 0.15881246323032167.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:24,360] Trial 42 finished with value: 0.15878853994493128 and parameters: {'n_estimators': 216, 'max_depth': 8, 'learning_rate': 0.0819321963019922, 'subsample': 0.5291883007316033, 'colsample_bytree': 0.6050621448845849, 'gamma': 0.20260454476766251, 'min_child_weight': 7, 'reg_alpha': 0.4336045431834144, 'reg_lambda': 0.578433087103741}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:24,581] Trial 43 finished with value: 0.15900196139376854 and parameters: {'n_estimators': 215, 'max_depth': 8, 'learning_rate': 0.07906133979943833, 'subsample': 0.5207974617008214, 'colsample_bytree': 0.6079572221675432, 'gamma': 0.17288007063005953, 'min_child_weight': 6, 'reg_alpha': 0.5695820854359059, 'reg_lambda': 0.6648043193866721}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:24,713] Trial 44 finished with value: 0.15896947136936057 and parameters: {'n_estimators': 176, 'max_depth': 8, 'learning_rate': 0.06851474440966314, 'subsample': 0.6287597186185861, 'colsample_bytree': 0.5356326331411192, 'gamma': 0.31977070436477084, 'min_child_weight': 7, 'reg_alpha': 0.3333870536209171, 'reg_lambda': 0.4881575132426673}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:24,926] Trial 45 finished with value: 0.16144696369260095 and parameters: {'n_estimators': 211, 'max_depth': 9, 'learning_rate': 0.01576301506904937, 'subsample': 0.8558686608297634, 'colsample_bytree': 0.6936633498080721, 'gamma': 0.1213494979895763, 'min_child_weight': 7, 'reg_alpha': 0.4655595505733129, 'reg_lambda': 0.5953969921499184}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:25,118] Trial 46 finished with value: 0.15888607536318097 and parameters: {'n_estimators': 277, 'max_depth': 8, 'learning_rate': 0.05753939723279314, 'subsample': 0.6077237667143325, 'colsample_bytree': 0.6313718341047606, 'gamma': 0.24724446382961718, 'min_child_weight': 5, 'reg_alpha': 0.9515416140472498, 'reg_lambda': 0.7261965746312603}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:25,353] Trial 47 finished with value: 0.15884631501099336 and parameters: {'n_estimators': 255, 'max_depth': 6, 'learning_rate': 0.04653192175912195, 'subsample': 0.5276604658003904, 'colsample_bytree': 0.5998914615936761, 'gamma': 0.1988128043763463, 'min_child_weight': 6, 'reg_alpha': 0.6143120701771341, 'reg_lambda': 0.5242254631803572}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:25,510] Trial 48 finished with value: 0.15889677627600737 and parameters: {'n_estimators': 194, 'max_depth': 8, 'learning_rate': 0.15534063033388995, 'subsample': 0.576073620959361, 'colsample_bytree': 0.5635632953089879, 'gamma': 0.2318357944051918, 'min_child_weight': 7, 'reg_alpha': 0.08902962038740958, 'reg_lambda': 0.65456619768845}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:25,644] Trial 49 finished with value: 0.15904285068202714 and parameters: {'n_estimators': 205, 'max_depth': 10, 'learning_rate': 0.11209043396170704, 'subsample': 0.751445158465962, 'colsample_bytree': 0.6751034884051403, 'gamma': 0.2709135731111312, 'min_child_weight': 8, 'reg_alpha': 0.5301526913064529, 'reg_lambda': 0.3739083516267342}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:25,874] Trial 50 finished with value: 0.15900968845533883 and parameters: {'n_estimators': 219, 'max_depth': 7, 'learning_rate': 0.09695641861842641, 'subsample': 0.6477432723750798, 'colsample_bytree': 0.8006430245330312, 'gamma': 0.1676125039758414, 'min_child_weight': 9, 'reg_alpha': 0.24246181496030078, 'reg_lambda': 0.467063636116471}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:26,132] Trial 51 finished with value: 0.15891184015718615 and parameters: {'n_estimators': 249, 'max_depth': 6, 'learning_rate': 0.03412668718832971, 'subsample': 0.5372879522345207, 'colsample_bytree': 0.5878756073958343, 'gamma': 0.19546738204576358, 'min_child_weight': 6, 'reg_alpha': 0.6198704729144551, 'reg_lambda': 0.5189271605957404}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:26,344] Trial 52 finished with value: 0.1588597794800435 and parameters: {'n_estimators': 252, 'max_depth': 5, 'learning_rate': 0.05131658690563955, 'subsample': 0.5013401522133821, 'colsample_bytree': 0.607266652919776, 'gamma': 0.21740012979246623, 'min_child_weight': 6, 'reg_alpha': 0.7045185697983638, 'reg_lambda': 0.5629541932506663}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:26,686] Trial 53 finished with value: 0.1589602819092834 and parameters: {'n_estimators': 285, 'max_depth': 6, 'learning_rate': 0.04570857985437387, 'subsample': 0.5839721292444084, 'colsample_bytree': 0.5445010136099001, 'gamma': 0.1384641259942288, 'min_child_weight': 7, 'reg_alpha': 0.319441544591199, 'reg_lambda': 0.6120316191612778}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:26,862] Trial 54 finished with value: 0.15892201028959238 and parameters: {'n_estimators': 239, 'max_depth': 5, 'learning_rate': 0.07383044246690129, 'subsample': 0.5314927096618874, 'colsample_bytree': 0.6244126518201852, 'gamma': 0.2517244471955663, 'min_child_weight': 5, 'reg_alpha': 0.37611520717524166, 'reg_lambda': 0.9916560208383202}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:27,073] Trial 55 finished with value: 0.15891183280727605 and parameters: {'n_estimators': 224, 'max_depth': 7, 'learning_rate': 0.06523035134608174, 'subsample': 0.6021560827361457, 'colsample_bytree': 0.716367073737416, 'gamma': 0.19039136358610004, 'min_child_weight': 6, 'reg_alpha': 0.17574407249700486, 'reg_lambda': 0.06962884195338437}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:27,230] Trial 56 finished with value: 0.15898191688497165 and parameters: {'n_estimators': 205, 'max_depth': 5, 'learning_rate': 0.08200058312622235, 'subsample': 0.5184438855898551, 'colsample_bytree': 0.8336164658016033, 'gamma': 0.3043123546769104, 'min_child_weight': 7, 'reg_alpha': 0.005968149711154225, 'reg_lambda': 0.3838690401464929}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:27,595] Trial 57 finished with value: 0.15932315222447802 and parameters: {'n_estimators': 260, 'max_depth': 6, 'learning_rate': 0.04095992490927823, 'subsample': 0.5622141473478396, 'colsample_bytree': 0.7562895828955046, 'gamma': 0.09645199810626937, 'min_child_weight': 8, 'reg_alpha': 0.6523649564714986, 'reg_lambda': 0.5383383736708821}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:27,757] Trial 58 finished with value: 0.1589067517435513 and parameters: {'n_estimators': 190, 'max_depth': 4, 'learning_rate': 0.05738430206713552, 'subsample': 0.5848595632504279, 'colsample_bytree': 0.6476463454795637, 'gamma': 0.23146253361549987, 'min_child_weight': 5, 'reg_alpha': 0.5038113123720263, 'reg_lambda': 0.7734444111524547}. Best is trial 42 with value: 0.15878853994493128.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:27,939] Trial 59 finished with value: 0.15864760096012936 and parameters: {'n_estimators': 115, 'max_depth': 7, 'learning_rate': 0.0741901094844514, 'subsample': 0.5473917646217832, 'colsample_bytree': 0.6750614435313035, 'gamma': 0.15763580532565702, 'min_child_weight': 6, 'reg_alpha': 0.2546593767973521, 'reg_lambda': 0.4577996597255612}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:28,043] Trial 60 finished with value: 0.15883500220023797 and parameters: {'n_estimators': 85, 'max_depth': 7, 'learning_rate': 0.07500237647376026, 'subsample': 0.5466311175708929, 'colsample_bytree': 0.6735031230194851, 'gamma': 0.158732217160293, 'min_child_weight': 7, 'reg_alpha': 0.31946250196534387, 'reg_lambda': 0.47718239303454973}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:28,214] Trial 61 finished with value: 0.15885090771078814 and parameters: {'n_estimators': 109, 'max_depth': 7, 'learning_rate': 0.07599325930845427, 'subsample': 0.5499031682693862, 'colsample_bytree': 0.6827706490873948, 'gamma': 0.15905468089670027, 'min_child_weight': 7, 'reg_alpha': 0.250775262856725, 'reg_lambda': 0.4408784567447749}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:28,366] Trial 62 finished with value: 0.1589608411286985 and parameters: {'n_estimators': 91, 'max_depth': 7, 'learning_rate': 0.09233409747887006, 'subsample': 0.589360091963424, 'colsample_bytree': 0.6612686471970017, 'gamma': 0.17308633503126367, 'min_child_weight': 7, 'reg_alpha': 0.40048042151571317, 'reg_lambda': 0.4063024140388233}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:28,617] Trial 63 finished with value: 0.1592715497928121 and parameters: {'n_estimators': 85, 'max_depth': 8, 'learning_rate': 0.10793407075683745, 'subsample': 0.6200510988355694, 'colsample_bytree': 0.7075581385898587, 'gamma': 0.07208930485899567, 'min_child_weight': 8, 'reg_alpha': 0.3234839653507485, 'reg_lambda': 0.47068009101680897}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:28,852] Trial 64 finished with value: 0.1587474042892306 and parameters: {'n_estimators': 126, 'max_depth': 8, 'learning_rate': 0.06909945730454974, 'subsample': 0.5692954902320231, 'colsample_bytree': 0.7395855589168627, 'gamma': 0.11789338016037314, 'min_child_weight': 6, 'reg_alpha': 0.441641009981719, 'reg_lambda': 0.28834497398833625}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:29,028] Trial 65 finished with value: 0.15919973474740265 and parameters: {'n_estimators': 70, 'max_depth': 8, 'learning_rate': 0.06948180815536861, 'subsample': 0.572517126513957, 'colsample_bytree': 0.7355832998275351, 'gamma': 0.11174032855717735, 'min_child_weight': 2, 'reg_alpha': 0.1789777693477727, 'reg_lambda': 0.9415580254585497}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:31,956] Trial 79 finished with value: 0.15913753559805818 and parameters: {'n_estimators': 183, 'max_depth': 7, 'learning_rate': 0.06187304443704416, 'subsample': 0.63599895347698, 'colsample_bytree': 0.7657660624120805, 'gamma': 0.12668994124000532, 'min_child_weight': 8, 'reg_alpha': 0.2657305062281392, 'reg_lambda': 0.41243670375689834}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:32,143] Trial 80 finished with value: 0.15895571983584403 and parameters: {'n_estimators': 228, 'max_depth': 6, 'learning_rate': 0.06643980276516494, 'subsample': 0.553680004391689, 'colsample_bytree': 0.6890902805444237, 'gamma': 0.24493576469352904, 'min_child_weight': 9, 'reg_alpha': 0.22253300047332475, 'reg_lambda': 0.5448720133230807}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:32,380] Trial 81 finished with value: 0.15887173216958825 and parameters: {'n_estimators': 222, 'max_depth': 6, 'learning_rate': 0.0456734887467212, 'subsample': 0.5293654473691966, 'colsample_bytree': 0.6044136461976792, 'gamma': 0.2078007073011364, 'min_child_weight': 6, 'reg_alpha': 0.6065624319262477, 'reg_lambda': 0.5314577442699223}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:32,590] Trial 82 finished with value: 0.1588700480042221 and parameters: {'n_estimators': 243, 'max_depth': 5, 'learning_rate': 0.05837999302436233, 'subsample': 0.5334627315403943, 'colsample_bytree': 0.6575847593021756, 'gamma': 0.19920725422983218, 'min_child_weight': 6, 'reg_alpha': 0.5456792432405067, 'reg_lambda': 0.505245976721002}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:32,777] Trial 83 finished with value: 0.15881445732203792 and parameters: {'n_estimators': 210, 'max_depth': 6, 'learning_rate': 0.08968116537547559, 'subsample': 0.5657390743942543, 'colsample_bytree': 0.593971109554978, 'gamma': 0.18032599419805023, 'min_child_weight': 7, 'reg_alpha': 0.571097426518165, 'reg_lambda': 0.5719348908682288}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:32,964] Trial 84 finished with value: 0.15883094277731868 and parameters: {'n_estimators': 202, 'max_depth': 4, 'learning_rate': 0.09029458762212988, 'subsample': 0.5707661747570235, 'colsample_bytree': 0.5906351234443652, 'gamma': 0.16637686012123035, 'min_child_weight': 7, 'reg_alpha': 0.5766207407439697, 'reg_lambda': 0.5706333687954832}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:33,157] Trial 85 finished with value: 0.1588586181745939 and parameters: {'n_estimators': 209, 'max_depth': 4, 'learning_rate': 0.08796026979895405, 'subsample': 0.5714112132555772, 'colsample_bytree': 0.5920343161897806, 'gamma': 0.16432442791570684, 'min_child_weight': 7, 'reg_alpha': 0.5630364989509629, 'reg_lambda': 0.45467617364442175}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:33,340] Trial 86 finished with value: 0.1590193949346364 and parameters: {'n_estimators': 178, 'max_depth': 7, 'learning_rate': 0.07834363724825863, 'subsample': 0.5927756799794603, 'colsample_bytree': 0.5311930538178251, 'gamma': 0.18012417740243444, 'min_child_weight': 7, 'reg_alpha': 0.6562174968013437, 'reg_lambda': 0.5727932855794601}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:33,525] Trial 87 finished with value: 0.15873043228124556 and parameters: {'n_estimators': 198, 'max_depth': 4, 'learning_rate': 0.09059407348157228, 'subsample': 0.5804762454954973, 'colsample_bytree': 0.5641694388867007, 'gamma': 0.15714817087971553, 'min_child_weight': 4, 'reg_alpha': 0.6432245662905617, 'reg_lambda': 0.6726405585462961}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:33,735] Trial 88 finished with value: 0.15886552692508454 and parameters: {'n_estimators': 201, 'max_depth': 4, 'learning_rate': 0.08975233609901913, 'subsample': 0.5821380262094233, 'colsample_bytree': 0.5658948172043516, 'gamma': 0.13292663081018988, 'min_child_weight': 3, 'reg_alpha': 0.5849801584059363, 'reg_lambda': 0.68168941966781}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:33,922] Trial 89 finished with value: 0.15909477224338178 and parameters: {'n_estimators': 172, 'max_depth': 3, 'learning_rate': 0.12619411497353075, 'subsample': 0.5623640278009882, 'colsample_bytree': 0.5293181995354034, 'gamma': 0.08416664557369308, 'min_child_weight': 4, 'reg_alpha': 0.5191683383661672, 'reg_lambda': 0.6417482646804076}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:34,121] Trial 90 finished with value: 0.1590096824771404 and parameters: {'n_estimators': 216, 'max_depth': 4, 'learning_rate': 0.10506428303418111, 'subsample': 0.6153146098311335, 'colsample_bytree': 0.5539667322027395, 'gamma': 0.1425104916429984, 'min_child_weight': 3, 'reg_alpha': 0.638005897236865, 'reg_lambda': 0.8034402662886865}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:34,304] Trial 91 finished with value: 0.15883055295089354 and parameters: {'n_estimators': 191, 'max_depth': 4, 'learning_rate': 0.08292084547687935, 'subsample': 0.5505310758565017, 'colsample_bytree': 0.572996174369706, 'gamma': 0.1606622110639876, 'min_child_weight': 4, 'reg_alpha': 0.6988608764554558, 'reg_lambda': 0.5669749048118637}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:34,453] Trial 92 finished with value: 0.1589002549209809 and parameters: {'n_estimators': 192, 'max_depth': 4, 'learning_rate': 0.09835336448327192, 'subsample': 0.5683241390155592, 'colsample_bytree': 0.5717984952569768, 'gamma': 0.22475477750200937, 'min_child_weight': 4, 'reg_alpha': 0.692489617048619, 'reg_lambda': 0.5589985479947609}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:34,622] Trial 93 finished with value: 0.15893191014094835 and parameters: {'n_estimators': 199, 'max_depth': 4, 'learning_rate': 0.08451163397223162, 'subsample': 0.590591762307274, 'colsample_bytree': 0.5473089523731816, 'gamma': 0.18870987570475906, 'min_child_weight': 3, 'reg_alpha': 0.7540334729895191, 'reg_lambda': 0.5962748326467586}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:34,748] Trial 94 finished with value: 0.1589312258921933 and parameters: {'n_estimators': 209, 'max_depth': 3, 'learning_rate': 0.081497508670817, 'subsample': 0.5578000689164168, 'colsample_bytree': 0.5141092712043652, 'gamma': 0.16675449539008114, 'min_child_weight': 5, 'reg_alpha': 0.8148853943707548, 'reg_lambda': 0.7436266404467202}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:34,886] Trial 95 finished with value: 0.158882433400047 and parameters: {'n_estimators': 186, 'max_depth': 4, 'learning_rate': 0.09346938636351376, 'subsample': 0.6049834192014127, 'colsample_bytree': 0.5939679881610668, 'gamma': 0.12053454807131393, 'min_child_weight': 2, 'reg_alpha': 0.6937158314326507, 'reg_lambda': 0.6578821441730823}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:35,043] Trial 96 finished with value: 0.1590337033896225 and parameters: {'n_estimators': 203, 'max_depth': 5, 'learning_rate': 0.07143300628482353, 'subsample': 0.5107876000854171, 'colsample_bytree': 0.5775220665194297, 'gamma': 0.45931034100198664, 'min_child_weight': 4, 'reg_alpha': 0.6704964300744418, 'reg_lambda': 0.5691454030979504}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:35,185] Trial 97 finished with value: 0.15891610706340964 and parameters: {'n_estimators': 194, 'max_depth': 4, 'learning_rate': 0.10042249909767732, 'subsample': 0.5804457941500208, 'colsample_bytree': 0.6156420756894403, 'gamma': 0.2570103645807283, 'min_child_weight': 4, 'reg_alpha': 0.6267720967444418, 'reg_lambda': 0.4979631523781121}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:35,380] Trial 98 finished with value: 0.1590693677472068 and parameters: {'n_estimators': 212, 'max_depth': 4, 'learning_rate': 0.06467742457221831, 'subsample': 0.5396109406858356, 'colsample_bytree': 0.7931066173362092, 'gamma': 0.2089647310084764, 'min_child_weight': 5, 'reg_alpha': 0.5793482669441363, 'reg_lambda': 0.618612492842509}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-05 10:15:35,558] Trial 99 finished with value: 0.1589867924158954 and parameters: {'n_estimators': 219, 'max_depth': 3, 'learning_rate': 0.08962876636551012, 'subsample': 0.6384341313358044, 'colsample_bytree': 0.5835006374165361, 'gamma': 0.14793590091621053, 'min_child_weight': 5, 'reg_alpha': 0.7153397470838744, 'reg_lambda': 0.16703162932156423}. Best is trial 59 with value: 0.15864760096012936.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'n_estimators': 115, 'max_depth': 7, 'learning_rate': 0.0741901094844514, 'subsample': 0.5473917646217832, 'colsample_bytree': 0.6750614435313035, 'gamma': 0.15763580532565702, 'min_child_weight': 6, 'reg_alpha': 0.2546593767973521, 'reg_lambda': 0.4577996597255612}
# Mean Absolute Error (MAE): 0.15864760096012936
# R² (Coefficient of Determination): 0.8319752724349689
# Pearson's Correlation Coefficient (R): 0.9121711362992384
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.354921146008443

# %%
target_yearDf=pd.read_csv('target_yearDf.csv')

# %%
print(len(target_yearDf))
# Out:
# 4

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
target_xDf = target_yearDf[xColumnsToKeep]


target_yDf = target_yearDf[yColumnsToKeep]

# %%
# Print values in the specified format
#print(f"Model: {aModelList[0][2]}")  # Model name
print(f"Test Data (x): \n{target_xDf.head()}")  # Test features
print(f"Test Data (y): \n{target_yDf.head()}")  # Test targets
#print(f"N: {N}")  # Number of iterations
print(f"Train Data (x): \n{target_xDf.head()}")  # Training features
print(f"Train Data (y): \n{target_yDf.head()}")  # Training targets
#print(f"Working Directory: {workingDir}")
#print(f"Number of Features: {numFeatures}")

# Assuming 'xgbModel' is trained earlier in the pipeline
#xgb_model = xgb.XGBRegressor()
#xgb_model.fit(target_xDf, target_yDf.values.ravel())  # Fit model with training data
y_pred = pipe.predict(target_xDf)  # Predict on test data

# Compute metrics
mae = mean_absolute_error(target_yDf, y_pred)
r_squared = r2_score(target_yDf, y_pred)
r_score = np.corrcoef(target_yDf.values.flatten(), y_pred)[0, 1]


print("\nPerformance Metrics:")
print(f"Avg MAE: {mae}")
print(f"Avg R squared: {r_squared}")

print(f"R Score (Correlation): {r_score:.4f}")

# Scatter plot of true yield vs predicted yield
plt.figure(figsize=(8, 6))
plt.scatter(target_yDf, y_pred, alpha=0.6, label="True vs Predicted")
plt.plot([target_yDf.min(), target_yDf.max()], [target_yDf.min(), target_yDf.max()], 'r--', lw=2, label="Perfect Fit")
plt.xlabel("True Yield (tons/acre)")
plt.ylabel("Predicted Yield (tons/acre)")
plt.title("Scatter Plot: True vs Predicted Yield")
plt.legend()
plt.grid()
plt.show()
# Out:
# Test Data (x):
#    radiation     rain  avg_max_temp  avg_min_temp
# 0  363261.27  3052.23       14.9885        4.3477
# 1  318176.67  2805.45       13.5742        3.1337
# 2  331522.92  2831.79       13.9352        3.4037
# 3  347385.82  2930.26       14.5251        3.9397
# Test Data (y):
#       yield
# 0  1.384737
# 1  2.904211
# 2  0.951579
# 3  0.956842
# Train Data (x):
#    radiation     rain  avg_max_temp  avg_min_temp
# 0  363261.27  3052.23       14.9885        4.3477
# 1  318176.67  2805.45       13.5742        3.1337
# 2  331522.92  2831.79       13.9352        3.4037
# 3  347385.82  2930.26       14.5251        3.9397
# Train Data (y):
#       yield
# 0  1.384737
# 1  2.904211
# 2  0.951579
# 3  0.956842
#
# Performance Metrics:
# Avg MAE: 0.8563204407691956
# Avg R squared: -0.20147454738616943
# R Score (Correlation): -0.5542

# %%
all_yearsDf=pd.read_csv("all_years.csv")

# %%
m1,r2=actualTest(all_yearsDf, target_yearDf, target_xDf, target_yDf, pipe)
# Out:
# 0.7271744010950391
# R:  0.3178270327282415
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                 -0.348
# Method:                 Least Squares   F-statistic:                    0.2247
# Date:                Sat, 05 Apr 2025   Prob (F-statistic):              0.682
# Time:                        16:14:50   Log-Likelihood:                -4.5789
# No. Observations:                   4   AIC:                             13.16
# Df Residuals:                       2   BIC:                             11.93
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0977      3.516     -0.028      0.980     -15.224      15.029
# x1             0.8723      1.840      0.474      0.682      -7.045       8.790
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.263
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.374
# Skew:                           0.425   Prob(JB):                        0.829
# Kurtosis:                       1.766   Cond. No.                         15.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 61.648%
# skt smape: 43.806%
# skt mae: 0.727
# skt mse: 0.694
# skt rmse: 0.833
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
def actualTest(all_yearsDf, target_yearDf, xTest, yTest, model):
    #print("Length of all_yearsDf----This is used for plotting graph ", len(all_yearsDf))
    #print("Length of final_yearDf-----This is used for adjusting the predicted values: ", len(final_yearDf))
    #print("Length of target_yearDf-------This is used for comparing predicted values to true values-----these are true values ", len(target_yearDf))
    #print("boost_xDf: ",len(boost_xDf))
    #print("boost_yDf: ", len(boost_yDf))
    #print("Length of xTest: ", len(xTest))
    #print("Length of yTest: ", len(yTest))
    #print("test results on our test data: ")
    #print(yTest)
    
    #model = model.fit(boost_xDf, boost_yDf, xgb_model=model.get_booster())
    # get predictions
    pred = model.predict(xTest)
    #trainPred = model.predict(xTrain)
    #print("Length of predictions are: ", len(pred))

    #adj_pred = []
    #for i in range(len(pred)):
    #    adj_pred.append(final_yearDf['yield'][i] + pred[i])
    #print('adjusted predictions: ')
    #print(adj_pred)
    #print("Predictions are: ")
    #print(pred)
    #print("Length of adjusted predictions: ", len(adj_pred))
    pred_Df = pd.DataFrame(pred)
    #print(adj_pred_Df)
    #adj_pred_Df=pd.DataFrame(pred)
    # find errors
    meanAbsoluteError = mean_absolute_error(target_yearDf['yield'], pred_Df)
    print(meanAbsoluteError)
#     plt.scatter(yTest, pred, label='Truth vs Prediction')
#     p1 = max(max(pred), max(yTest['Yield (tons/acre)']))
#     p2 = min(min(pred), min(yTest['Yield (tons/acre)']))
#     plt.plot([p1, p2], [p1, p2], color='k', label='Perfect Predictions')
#     plt.xlabel('True Yields')
#     plt.ylabel('Predicted Yields')
#     plt.legend()
    #print("Plotting--------")
    pred_ts = []
    len_tsDf = len(all_yearsDf)
    #print("len_tsDf----Length of all_yearsDf----", len_tsDf)
    for i in range(len_tsDf - len(pred), len_tsDf):
        pred_ts.append(i)
    #print("Length of pred_ts is: ", len(pred_ts))
    #print("This is the index calculated for plotting time-series graph: ", pred_ts)    
    pred_df = pd.DataFrame(pred, index = pred_ts, columns = ['yield'])
    #print("Lengths of all_yearsDf and Lengths of pred_Df are: ", len(all_yearsDf['yield']), len(pred_df))
    #print("Head and shape of pred_Df")
    #print(pred_df.head())  # Check structure
    #print(pred_df.shape)   # Compare with all_yearsDf
    #print(all_yearsDf.index)
    plot_series(pd.Series(all_yearsDf['yield']), pred_df, labels=["y", "y_pred"])


    #plt.figure(figsize=(10, 6))

    # Plot actual yield using its index
    #plt.plot(all_yearsDf.index, all_yearsDf['yield'], label="Actual Yield", linestyle="-", color="blue")

    # Plot predicted yield using its index (from pred_df)
    #plt.plot(pred_df.index, pred_df['yield'], label="Predicted Yield", linestyle="--", color="red")

    #plt.xlabel("Index")  # The x-axis will now be the index of each DataFrame
    #plt.ylabel("Yield")
    #plt.legend()
    #plt.title("Actual vs. Predicted Yield")
    #plt.show()

    # find the R values
    r = np.corrcoef(target_yearDf['yield'], pred)[0,1]
    print("R: ",r)
    # find the R^2 coefficient of determination
    # defining the variables
#     r2x = xTest.tolist()
#     r2y = yTest.tolist()

    # adding the constant term
    r2pred = sm.add_constant(pred)

    # performing the regression
    # and fitting the model
    yTargetYield = target_yearDf['yield']
    result = sm.OLS(yTargetYield, r2pred).fit()

    # printing the summary table
    print(result.summary())
    print('skt mape: ' + str(round(skt_mape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt smape: ' + str(round(skt_smape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt mae: ' + str(round(skt_mae(yTargetYield, pred_Df), 3)))
    print('skt mse: ' + str(round(skt_mse(yTargetYield, pred_Df), 3)))
    print('skt rmse: ' + str(round(math.sqrt(skt_mse(yTargetYield, pred_Df)), 3)) + '\n\n')
    
    #accuracy = accuracy_score(yTest, pred)
    
    return(meanAbsoluteError, r)
    

#     # add the errors and R Squared to average values
#     avgMAE += meanAbsoluteError
#     avgRSq += rSq

#     # check to see which metric should be optimized
#     if metricToOptimize == 'r2':
#         # check to see if any of these are the best values
#         if (rSq > bestRSq):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     elif metricToOptimize == 'mae':
#         # check to see if any of these are the best values
#         if (meanAbsoluteError < bestMAE):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     else:
#         raise ValueError("The input 'metricToOptimize' does not have a valid input. It must be 'r2' or 'mae'.")

# %%
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import joblib
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import math

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sktime.utils.plotting import plot_series

# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, matthews_corrcoef
from sktime.performance_metrics.forecasting import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVR  # support vector machines regression
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import AdaBoostRegressor # adaboost for regression
import xgboost as xgb

skt_mape = MeanAbsolutePercentageError(symmetric=False)
skt_smape = MeanAbsolutePercentageError(symmetric=True)
skt_mae = MeanAbsoluteError()
skt_mse = MeanSquaredError()

# %%
all_yearsDf_Chazy=pd.read_csv("all_years_Chazy.csv")

# %%
all_yearsDf_Cobleskill=pd.read_csv("all_years_Cobleskill.csv")

# %%
all_yearsDf_Perry=pd.read_csv("all_years_Perry.csv")

# %%
mae,r=actualTest2(all_yearsDf_Perry,pipe)
print(mae)
print(r)
# Out:
# MAE:  0.5442540020159405
# R value is:  0.041308481627424114
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.054
# Method:                 Least Squares   F-statistic:                   0.03077
# Date:                Sat, 05 Apr 2025   Prob (F-statistic):              0.863
# Time:                        16:23:14   Log-Likelihood:                -13.251
# No. Observations:                  20   AIC:                             30.50
# Df Residuals:                      18   BIC:                             32.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5517      0.417      3.722      0.002       0.676       2.428
# x1             0.0439      0.250      0.175      0.863      -0.482       0.570
# ==============================================================================
# Omnibus:                        0.081   Durbin-Watson:                   1.556
# Prob(Omnibus):                  0.961   Jarque-Bera (JB):                0.288
# Skew:                           0.091   Prob(JB):                        0.866
# Kurtosis:                       2.441   Cond. No.                         8.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 38.888%
# skt smape: 36.728%
# skt mae: 0.544
# skt mse: 0.399
# skt rmse: 0.632
#
#
# 0.5442540020159405
# 0.041308481627424114
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
mae,r=actualTest2(all_yearsDf_Cobleskill,pipe)
print(mae)
print(r)
# Out:
# MAE:  0.4816453150831935
# R value is:  0.32893621905417086
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     6.552
# Date:                Sat, 05 Apr 2025   Prob (F-statistic):             0.0133
# Time:                        16:20:28   Log-Likelihood:                -41.398
# No. Observations:                  56   AIC:                             86.80
# Df Residuals:                      54   BIC:                             90.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1718      0.305      3.846      0.000       0.561       1.783
# x1             0.4189      0.164      2.560      0.013       0.091       0.747
# ==============================================================================
# Omnibus:                        1.315   Durbin-Watson:                   1.582
# Prob(Omnibus):                  0.518   Jarque-Bera (JB):                1.099
# Skew:                          -0.124   Prob(JB):                        0.577
# Kurtosis:                       2.361   Cond. No.                         10.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 27.681%
# skt smape: 26.933%
# skt mae: 0.482
# skt mse: 0.331
# skt rmse: 0.575
#
#
# 0.4816453150831935
# 0.32893621905417086
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
mae, r=actualTest2(all_yearsDf_Chazy,pipe)
# Out:
# MAE:  0.48915505169579043
# R value is:  0.18222003220468344
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.820
# Date:                Sat, 05 Apr 2025   Prob (F-statistic):              0.183
# Time:                        16:15:53   Log-Likelihood:                -44.622
# No. Observations:                  55   AIC:                             93.24
# Df Residuals:                      53   BIC:                             97.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1816      0.417      2.834      0.006       0.345       2.018
# x1             0.2966      0.220      1.349      0.183      -0.144       0.738
# ==============================================================================
# Omnibus:                        0.054   Durbin-Watson:                   1.499
# Prob(Omnibus):                  0.973   Jarque-Bera (JB):                0.207
# Skew:                           0.059   Prob(JB):                        0.902
# Kurtosis:                       2.724   Cond. No.                         13.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 37.788%
# skt smape: 29.448%
# skt mae: 0.489
# skt mse: 0.371
# skt rmse: 0.609
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
def actualTest2(all_yearsDf, model):
    #print("Length of all_yearsDf----This is used for plotting graph ", len(all_yearsDf))
    #print("Length of final_yearDf-----This is used for adjusting the predicted values: ", len(final_yearDf))
    #print("Length of target_yearDf-------This is used for comparing predicted values to true values-----these are true values ", len(target_yearDf))
    #print("boost_xDf: ",len(boost_xDf))
    #print("boost_yDf: ", len(boost_yDf))
    #print("Length of xTest: ", len(xTest))
    #print("Length of yTest: ", len(yTest))
    #print("test results on our test data: ")
    #print(yTest)
    xTest = all_yearsDf[["radiation", "rain", "avg_max_temp", "avg_min_temp"]]
    yTest=all_yearsDf[["yield"]]
    #model = model.fit(boost_xDf, boost_yDf, xgb_model=model.get_booster())
    # get predictions
    pred = model.predict(xTest)
    #trainPred = model.predict(xTrain)
    #print("Length of predictions are: ", len(pred))

    #adj_pred = []
    #for i in range(len(pred)):
    #    adj_pred.append(final_yearDf['yield'][i] + pred[i])
    #print('adjusted predictions: ')
    #print(adj_pred)
    #print("Predictions are: ")
    #print(pred)
    #print("Length of adjusted predictions: ", len(adj_pred))
    pred_Df = pd.DataFrame(pred)
    #print(adj_pred_Df)
    #adj_pred_Df=pd.DataFrame(pred)
    # find errors
    meanAbsoluteError = mean_absolute_error(yTest, pred_Df)
    print("MAE: ", meanAbsoluteError)
#     plt.scatter(yTest, pred, label='Truth vs Prediction')
#     p1 = max(max(pred), max(yTest['Yield (tons/acre)']))
#     p2 = min(min(pred), min(yTest['Yield (tons/acre)']))
#     plt.plot([p1, p2], [p1, p2], color='k', label='Perfect Predictions')
#     plt.xlabel('True Yields')
#     plt.ylabel('Predicted Yields')
#     plt.legend()
    #print("Plotting--------")
    pred_ts = []
    len_tsDf = len(all_yearsDf)
    #print("len_tsDf----Length of all_yearsDf----", len_tsDf)
    for i in range(len_tsDf - len(pred), len_tsDf):
        pred_ts.append(i)
    #print("Length of pred_ts is: ", len(pred_ts))
    #print("This is the index calculated for plotting time-series graph: ", pred_ts)    
    pred_df = pd.DataFrame(pred, index = pred_ts, columns = ['yield'])
    #print("Lengths of all_yearsDf and Lengths of pred_Df are: ", len(all_yearsDf['yield']), len(pred_df))
    #print("Head and shape of pred_Df")
    #print(pred_df.head())  # Check structure
    #print(pred_df.shape)   # Compare with all_yearsDf
    #print(all_yearsDf.index)
    plot_series(pd.Series(all_yearsDf['yield']), pred_df, labels=["y", "y_pred"])


    #plt.figure(figsize=(10, 6))

    # Plot actual yield using its index
    #plt.plot(all_yearsDf.index, all_yearsDf['yield'], label="Actual Yield", linestyle="-", color="blue")

    # Plot predicted yield using its index (from pred_df)
    #plt.plot(pred_df.index, pred_df['yield'], label="Predicted Yield", linestyle="--", color="red")

    #plt.xlabel("Index")  # The x-axis will now be the index of each DataFrame
    #plt.ylabel("Yield")
    #plt.legend()
    #plt.title("Actual vs. Predicted Yield")
    #plt.show()

    # find the R values
    r = np.corrcoef(all_yearsDf['yield'], pred)[0,1]
    print("R value is: ", r)
    # find the R^2 coefficient of determination
    # defining the variables
#     r2x = xTest.tolist()
#     r2y = yTest.tolist()

    # adding the constant term
    r2pred = sm.add_constant(pred)
    
    # performing the regression
    # and fitting the model
    yTargetYield = all_yearsDf['yield']
    result = sm.OLS(yTargetYield, r2pred).fit()

    # printing the summary table
    print(result.summary())
    print('skt mape: ' + str(round(skt_mape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt smape: ' + str(round(skt_smape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt mae: ' + str(round(skt_mae(yTargetYield, pred_Df), 3)))
    print('skt mse: ' + str(round(skt_mse(yTargetYield, pred_Df), 3)))
    print('skt rmse: ' + str(round(math.sqrt(skt_mse(yTargetYield, pred_Df)), 3)) + '\n\n')
    
    #accuracy = accuracy_score(yTest, pred)
    
    return(meanAbsoluteError, r)
    

#     # add the errors and R Squared to average values
#     avgMAE += meanAbsoluteError
#     avgRSq += rSq

#     # check to see which metric should be optimized
#     if metricToOptimize == 'r2':
#         # check to see if any of these are the best values
#         if (rSq > bestRSq):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     elif metricToOptimize == 'mae':
#         # check to see if any of these are the best values
#         if (meanAbsoluteError < bestMAE):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     else:
#         raise ValueError("The input 'metricToOptimize' does not have a valid input. It must be 'r2' or 'mae'.")
