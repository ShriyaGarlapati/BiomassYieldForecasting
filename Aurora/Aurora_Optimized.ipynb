# %%
############## imports
# general
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score  
# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVC  # support vector machines classification
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.neural_network import MLPClassifier # neural network for classification
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier # adaboost for classification
import xgboost as xgb
# saving models
# from sklearn.externals import joblib
import joblib
import matplotlib.pyplot as plt

# %%
import pandas as pd
import random
import math

# read in time point 1 for training
# train on it - model 1
# test on tp 2
# read tp 2
# add it to xgb - model 2
# test on tp 3
# read tp 3
# add it to xgb - model 3
# test on tp 4
# test model 1
data = pd.read_csv('data_no_2022_synthesized_nonstationary.csv')
data.head()
# Out:
#       yield      radiation         rain  avg_min_temp  avg_max_temp  class
# 0  0.544118  137685.250000  1218.400000      5.486800     15.861700      1
# 1  0.602353  156512.670000  1354.890000      6.645200     17.128200      1
# 2  1.497647  234944.580000  1996.480000      5.060400     15.351300      1
# 3  0.770000  258362.870000  2282.390000      5.889800     16.195100      1
# 4  1.069494  155314.618628  1899.013296      6.293051     16.655855      1

# %%
print(len(data))
# Out:
# 13337

# %%
data = data.rename(columns={'Yield (tons/acre)':'yield'})

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
xDf = data[xColumnsToKeep]


yDf = data[yColumnsToKeep]

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression, SelectPercentile
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error


# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# XGBoost model
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Create the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb_model)
])

# Train the pipeline
pipe.fit(X_train, y_train)

# Make predictions
y_pred = pipe.predict(X_test)

# Mean Squared Error (MSE)
#mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
#rmse = np.sqrt(mse)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Absolute Error (MAE): 0.23424468635025986
# R² (Coefficient of Determination): -0.14316343262397968
# Pearson's Correlation Coefficient (R): -0.023676507783693478
# Symmetric Mean Absolute Percentage Error (SMAPE): 14.13006866354525

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array
# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Use cross-validation to evaluate the model (this ensures better generalization)
    score = cross_val_score(pipe, X_train, y_train, scoring='neg_mean_squared_error', cv=3)
    
    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return r2
    # Return the negative mean squared error (we want to minimize this)
    

# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize')  # Minimize RMSE or MSE
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)


# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_flat, y_pred)

# R-squared (R²) score
r2 = r2_score(y_test_flat, y_pred)

# Pearson's Correlation Coefficient (R)
#correlation_matrix = np.corrcoef(y_test, y_pred)



# Now calculate the correlation
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]

#correlation = correlation_matrix[0, 1]

# Symmetric Mean Absolute Percentage Error (SMAPE)
def smape(y_true, y_pred):
    denominator = np.abs(y_true) + np.abs(y_pred)
    diff = np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
    return 100 * np.mean(diff)

smape_value = smape(y_test_flat, y_pred)

# Print all the evaluation metrics
#print(f'Mean Squared Error (MSE): {mse}')
#print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-03 22:46:15,797] A new study created in memory with name: no-name-11facfe8-94c6-4aa0-8f19-dffd4f5c97c7
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:16,303] Trial 0 finished with value: -0.004576313998583492 and parameters: {'n_estimators': 148, 'max_depth': 5, 'learning_rate': 0.0320854252193675, 'subsample': 0.6266323884888816, 'colsample_bytree': 0.5209699789285371, 'gamma': 0.24458875617308895, 'min_child_weight': 3, 'reg_alpha': 0.3763413650325065, 'reg_lambda': 0.17101462236148868}. Best is trial 0 with value: -0.004576313998583492.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:16,584] Trial 1 finished with value: -0.0007239919108257276 and parameters: {'n_estimators': 136, 'max_depth': 6, 'learning_rate': 0.03492376188691819, 'subsample': 0.9453663919026852, 'colsample_bytree': 0.7883418972972907, 'gamma': 0.33250747877439685, 'min_child_weight': 7, 'reg_alpha': 0.8593747600304632, 'reg_lambda': 0.16113554964559762}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:17,091] Trial 2 finished with value: -0.002461169396634766 and parameters: {'n_estimators': 273, 'max_depth': 8, 'learning_rate': 0.16562989321374458, 'subsample': 0.8343025648201345, 'colsample_bytree': 0.5407344572286891, 'gamma': 0.37157692633579764, 'min_child_weight': 8, 'reg_alpha': 0.40039127444775313, 'reg_lambda': 0.12063310337519584}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:17,460] Trial 3 finished with value: -0.002513532564242693 and parameters: {'n_estimators': 187, 'max_depth': 9, 'learning_rate': 0.07914607233443516, 'subsample': 0.6981818293293696, 'colsample_bytree': 0.9398832557754978, 'gamma': 0.4534569156254792, 'min_child_weight': 2, 'reg_alpha': 0.28477251115425906, 'reg_lambda': 0.987918186761228}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:20,248] Trial 4 finished with value: -0.1881534004505332 and parameters: {'n_estimators': 298, 'max_depth': 9, 'learning_rate': 0.12255554369406206, 'subsample': 0.7248370835356714, 'colsample_bytree': 0.9366361266026695, 'gamma': 0.02117243711823108, 'min_child_weight': 4, 'reg_alpha': 0.06719635088707154, 'reg_lambda': 0.973021456146397}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:21,005] Trial 5 finished with value: -0.011903212143502984 and parameters: {'n_estimators': 176, 'max_depth': 3, 'learning_rate': 0.061213126268547594, 'subsample': 0.7039974083642875, 'colsample_bytree': 0.808469459667015, 'gamma': 1.850173059902982e-05, 'min_child_weight': 8, 'reg_alpha': 0.4545477039485011, 'reg_lambda': 0.5367582877856456}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:22,480] Trial 6 finished with value: -0.09172743038069675 and parameters: {'n_estimators': 233, 'max_depth': 5, 'learning_rate': 0.14073360570078053, 'subsample': 0.5337931136959955, 'colsample_bytree': 0.5999197530480986, 'gamma': 0.0033866318307634313, 'min_child_weight': 1, 'reg_alpha': 0.3101083167623844, 'reg_lambda': 0.27196033487688087}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:24,170] Trial 7 finished with value: -0.07443637203074727 and parameters: {'n_estimators': 271, 'max_depth': 5, 'learning_rate': 0.1486128408235749, 'subsample': 0.5294248682923601, 'colsample_bytree': 0.7812549977532941, 'gamma': 0.07450809723012519, 'min_child_weight': 5, 'reg_alpha': 0.9323304877831515, 'reg_lambda': 0.1288240630031262}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:24,449] Trial 8 finished with value: -0.005456505176886672 and parameters: {'n_estimators': 122, 'max_depth': 5, 'learning_rate': 0.14613309315646839, 'subsample': 0.7420001897379317, 'colsample_bytree': 0.5470076317206921, 'gamma': 0.2709107204587618, 'min_child_weight': 3, 'reg_alpha': 0.2902858063815972, 'reg_lambda': 0.43784948382337985}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:24,770] Trial 9 finished with value: -0.0011589199338526424 and parameters: {'n_estimators': 164, 'max_depth': 4, 'learning_rate': 0.062158036009525845, 'subsample': 0.7663316775399838, 'colsample_bytree': 0.5028853750495335, 'gamma': 0.40127542689360834, 'min_child_weight': 3, 'reg_alpha': 0.31959484824470286, 'reg_lambda': 0.6911761576339124}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:25,052] Trial 10 finished with value: -0.0011737681817121093 and parameters: {'n_estimators': 55, 'max_depth': 7, 'learning_rate': 0.013813969120304942, 'subsample': 0.9953803845986205, 'colsample_bytree': 0.680876684226733, 'gamma': 0.21311466402427087, 'min_child_weight': 10, 'reg_alpha': 0.8841482430131171, 'reg_lambda': 0.36430467957012824}. Best is trial 1 with value: -0.0007239919108257276.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:25,273] Trial 11 finished with value: -0.0005657828623648609 and parameters: {'n_estimators': 102, 'max_depth': 3, 'learning_rate': 0.06285297426480502, 'subsample': 0.8709723107232351, 'colsample_bytree': 0.833026723761018, 'gamma': 0.3764487134602022, 'min_child_weight': 7, 'reg_alpha': 0.6926789641180691, 'reg_lambda': 0.700798257045658}. Best is trial 11 with value: -0.0005657828623648609.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:25,468] Trial 12 finished with value: -0.0007992865886550238 and parameters: {'n_estimators': 89, 'max_depth': 3, 'learning_rate': 0.09796987182339448, 'subsample': 0.9508859807699829, 'colsample_bytree': 0.8719447803406067, 'gamma': 0.3350023677945913, 'min_child_weight': 7, 'reg_alpha': 0.7123890357467655, 'reg_lambda': 0.7258951104959659}. Best is trial 11 with value: -0.0005657828623648609.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:25,702] Trial 13 finished with value: -8.278171600273332e-05 and parameters: {'n_estimators': 105, 'max_depth': 7, 'learning_rate': 0.044312417697194295, 'subsample': 0.8826458345278713, 'colsample_bytree': 0.7042578244731228, 'gamma': 0.47800220129992743, 'min_child_weight': 6, 'reg_alpha': 0.6377320242170579, 'reg_lambda': 0.6026455097088155}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:25,891] Trial 14 finished with value: -0.0002860384020293427 and parameters: {'n_estimators': 91, 'max_depth': 7, 'learning_rate': 0.08984645391888484, 'subsample': 0.8554897661760699, 'colsample_bytree': 0.6988631331303489, 'gamma': 0.49243040342792305, 'min_child_weight': 6, 'reg_alpha': 0.6337097212807696, 'reg_lambda': 0.6636705434722285}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:26,079] Trial 15 finished with value: -0.0006458085264808844 and parameters: {'n_estimators': 57, 'max_depth': 7, 'learning_rate': 0.19412067438268535, 'subsample': 0.8460629221007482, 'colsample_bytree': 0.6992364056912556, 'gamma': 0.482974323217466, 'min_child_weight': 5, 'reg_alpha': 0.6122445455865708, 'reg_lambda': 0.551628011447656}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:26,293] Trial 16 finished with value: -0.0002482454378200938 and parameters: {'n_estimators': 99, 'max_depth': 10, 'learning_rate': 0.10172913262444389, 'subsample': 0.8956592061375789, 'colsample_bytree': 0.6620546212211429, 'gamma': 0.44853139087902405, 'min_child_weight': 6, 'reg_alpha': 0.5835822452296301, 'reg_lambda': 0.8387359460024997}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:26,802] Trial 17 finished with value: -0.006156321148939048 and parameters: {'n_estimators': 206, 'max_depth': 10, 'learning_rate': 0.11623712673205448, 'subsample': 0.9117103629124559, 'colsample_bytree': 0.6170748740623639, 'gamma': 0.16615531137608758, 'min_child_weight': 10, 'reg_alpha': 0.5440932433083131, 'reg_lambda': 0.8577132335835627}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:27,027] Trial 18 finished with value: -0.0004953708565915704 and parameters: {'n_estimators': 106, 'max_depth': 10, 'learning_rate': 0.04569529700658293, 'subsample': 0.7989334151580276, 'colsample_bytree': 0.6330558160022036, 'gamma': 0.4350476610807003, 'min_child_weight': 6, 'reg_alpha': 0.7891569728423743, 'reg_lambda': 0.826740498521624}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:27,193] Trial 19 finished with value: -0.000614097824587434 and parameters: {'n_estimators': 72, 'max_depth': 8, 'learning_rate': 0.07444975258382697, 'subsample': 0.9059984894860005, 'colsample_bytree': 0.7343180299896209, 'gamma': 0.42260925477121924, 'min_child_weight': 9, 'reg_alpha': 0.5327631171470004, 'reg_lambda': 0.8687285626922746}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:28,172] Trial 20 finished with value: -0.006123713684290211 and parameters: {'n_estimators': 127, 'max_depth': 9, 'learning_rate': 0.011835105191097886, 'subsample': 0.9964839790340746, 'colsample_bytree': 0.6502029636394637, 'gamma': 0.13843919546457345, 'min_child_weight': 4, 'reg_alpha': 0.17168162756441685, 'reg_lambda': 0.6346985683099928}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:28,352] Trial 21 finished with value: -0.0003053842932205786 and parameters: {'n_estimators': 84, 'max_depth': 8, 'learning_rate': 0.10813973779343465, 'subsample': 0.8152683625230358, 'colsample_bytree': 0.6942246991435369, 'gamma': 0.4994101362768225, 'min_child_weight': 6, 'reg_alpha': 0.639802009674536, 'reg_lambda': 0.6043093190896289}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:28,572] Trial 22 finished with value: -0.00026690856837707777 and parameters: {'n_estimators': 109, 'max_depth': 6, 'learning_rate': 0.09369796507904735, 'subsample': 0.8749979373859191, 'colsample_bytree': 0.7272176924915394, 'gamma': 0.46957447540670294, 'min_child_weight': 6, 'reg_alpha': 0.7669177322624744, 'reg_lambda': 0.789413979483702}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:28,807] Trial 23 finished with value: -0.000988431813436108 and parameters: {'n_estimators': 112, 'max_depth': 6, 'learning_rate': 0.12810011388694623, 'subsample': 0.9293930862308284, 'colsample_bytree': 0.5916021209217324, 'gamma': 0.32331451670895894, 'min_child_weight': 5, 'reg_alpha': 0.7483239872046861, 'reg_lambda': 0.8069447934313491}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:29,079] Trial 24 finished with value: -0.00019049114124802813 and parameters: {'n_estimators': 150, 'max_depth': 6, 'learning_rate': 0.08647953813169224, 'subsample': 0.8907084128191868, 'colsample_bytree': 0.7298269043959952, 'gamma': 0.4541902104459286, 'min_child_weight': 8, 'reg_alpha': 0.8193610679896002, 'reg_lambda': 0.7714249462515133}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:29,369] Trial 25 finished with value: -0.0003576192575107662 and parameters: {'n_estimators': 149, 'max_depth': 4, 'learning_rate': 0.04735801736657945, 'subsample': 0.8925377047427195, 'colsample_bytree': 0.7418139497803793, 'gamma': 0.40673178096058954, 'min_child_weight': 8, 'reg_alpha': 0.9793419329316375, 'reg_lambda': 0.905654923975353}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:29,705] Trial 26 finished with value: -0.0007355561105453212 and parameters: {'n_estimators': 193, 'max_depth': 10, 'learning_rate': 0.08200722451515201, 'subsample': 0.7857794891883433, 'colsample_bytree': 0.8763161032748912, 'gamma': 0.4459974302980305, 'min_child_weight': 9, 'reg_alpha': 0.8549964888942342, 'reg_lambda': 0.4260241372100287}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:30,057] Trial 27 finished with value: -0.0007284808655387831 and parameters: {'n_estimators': 153, 'max_depth': 8, 'learning_rate': 0.028137047721666864, 'subsample': 0.9763128186825838, 'colsample_bytree': 0.9914173705340382, 'gamma': 0.29746983564698626, 'min_child_weight': 7, 'reg_alpha': 0.5827672999150497, 'reg_lambda': 0.7388636028967112}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:30,444] Trial 28 finished with value: -0.00023450155149173924 and parameters: {'n_estimators': 213, 'max_depth': 7, 'learning_rate': 0.10593733609970717, 'subsample': 0.9485597832316629, 'colsample_bytree': 0.6542031953784625, 'gamma': 0.3839626331487202, 'min_child_weight': 9, 'reg_alpha': 0.4865549624719525, 'reg_lambda': 0.9251725436610951}. Best is trial 13 with value: -8.278171600273332e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:58,940] Trial 90 finished with value: -0.0020831036637887212 and parameters: {'n_estimators': 63, 'max_depth': 7, 'learning_rate': 0.04113516199651432, 'subsample': 0.8966786839722665, 'colsample_bytree': 0.8025356708605129, 'gamma': 0.24660410906682556, 'min_child_weight': 2, 'reg_alpha': 0.6899866933152312, 'reg_lambda': 0.5929095621586453}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:46:59,394] Trial 91 finished with value: -0.00010356251072862754 and parameters: {'n_estimators': 255, 'max_depth': 6, 'learning_rate': 0.06918449847778953, 'subsample': 0.9946872656545104, 'colsample_bytree': 0.722501427341973, 'gamma': 0.43814178723134284, 'min_child_weight': 1, 'reg_alpha': 0.593443482311713, 'reg_lambda': 0.7362057041405151}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:00,049] Trial 92 finished with value: -0.006396451880670728 and parameters: {'n_estimators': 243, 'max_depth': 6, 'learning_rate': 0.060537611568793365, 'subsample': 0.9869903902424257, 'colsample_bytree': 0.6748046170590014, 'gamma': 0.11252897901335435, 'min_child_weight': 2, 'reg_alpha': 0.6234816059213921, 'reg_lambda': 0.5404724362475289}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:00,453] Trial 93 finished with value: -0.00024376517473312376 and parameters: {'n_estimators': 219, 'max_depth': 6, 'learning_rate': 0.07849835046440998, 'subsample': 0.9710414121034733, 'colsample_bytree': 0.7372957611457033, 'gamma': 0.3949895171612192, 'min_child_weight': 4, 'reg_alpha': 0.51724987072844, 'reg_lambda': 0.4214192131070223}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:00,912] Trial 94 finished with value: -7.643918153554807e-05 and parameters: {'n_estimators': 252, 'max_depth': 5, 'learning_rate': 0.01517383832828955, 'subsample': 0.9941694610361971, 'colsample_bytree': 0.6269161330512538, 'gamma': 0.45618688950520425, 'min_child_weight': 1, 'reg_alpha': 0.40413750987563435, 'reg_lambda': 0.6674513043904685}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:01,408] Trial 95 finished with value: -9.430366695184489e-05 and parameters: {'n_estimators': 253, 'max_depth': 4, 'learning_rate': 0.015652193772558817, 'subsample': 0.949375566333257, 'colsample_bytree': 0.6206780910257451, 'gamma': 0.4900298313443356, 'min_child_weight': 2, 'reg_alpha': 0.38469959354226346, 'reg_lambda': 0.003263554160374549}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:01,685] Trial 96 finished with value: -6.5942366743732e-05 and parameters: {'n_estimators': 140, 'max_depth': 5, 'learning_rate': 0.02302476715206412, 'subsample': 0.9986854930531234, 'colsample_bytree': 0.5674913575536893, 'gamma': 0.47754529775209364, 'min_child_weight': 1, 'reg_alpha': 0.6665126114717982, 'reg_lambda': 0.6394033579875041}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:01,958] Trial 97 finished with value: -0.0001841460646105908 and parameters: {'n_estimators': 137, 'max_depth': 4, 'learning_rate': 0.023016801596734693, 'subsample': 0.9232576177577402, 'colsample_bytree': 0.5396115662930278, 'gamma': 0.47570935124560015, 'min_child_weight': 1, 'reg_alpha': 0.4296440264409609, 'reg_lambda': 0.676807580571053}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:02,164] Trial 98 finished with value: -6.979691919117847e-05 and parameters: {'n_estimators': 94, 'max_depth': 5, 'learning_rate': 0.014526912729022581, 'subsample': 0.9796033282249687, 'colsample_bytree': 0.5774054168101463, 'gamma': 0.4890369727774086, 'min_child_weight': 1, 'reg_alpha': 0.7963867019911905, 'reg_lambda': 0.6514376019683937}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:47:02,472] Trial 99 finished with value: -0.00010213205323705843 and parameters: {'n_estimators': 155, 'max_depth': 5, 'learning_rate': 0.015045656300194561, 'subsample': 0.9729745802596589, 'colsample_bytree': 0.5779720870037278, 'gamma': 0.4597880448680478, 'min_child_weight': 1, 'reg_alpha': 0.810291936949842, 'reg_lambda': 0.7531434488740689}. Best is trial 59 with value: -5.450396563122517e-05.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'n_estimators': 206, 'max_depth': 8, 'learning_rate': 0.010263070626854267, 'subsample': 0.9993172563228492, 'colsample_bytree': 0.7955439281963714, 'gamma': 0.481434853895066, 'min_child_weight': 2, 'reg_alpha': 0.5252048524828363, 'reg_lambda': 0.5343328656694386}
# Mean Absolute Error (MAE): 0.2222646207417567
# R² (Coefficient of Determination): -5.450396563122517e-05
# Pearson's Correlation Coefficient (R): -7.890663464825788e-05
# Symmetric Mean Absolute Percentage Error (SMAPE): 13.461056180074907

# %%
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectPercentile
import numpy as np

# Define the number of features to select (e.g., you can set it as an integer or a percentage)
features = 4  # Example: Select top 3 features

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(xDf, yDf, test_size=0.2, random_state=42)

# Extract the first column from y_test and flatten it
y_test_flat = y_test.iloc[:, 0].values  # Use .iloc to select the first column and convert to 1D array

# Standardization
standardScaler = preprocessing.StandardScaler()

# Feature Selection
if type(features) == int:
    featureSelection = SelectKBest(f_regression, k=features)
elif type(features) == float:
    featuresPercentile = features / 100.0
    featureSelection = SelectPercentile(f_regression, percentile=featuresPercentile)
else:
    raise ValueError("The input 'features' is not an integer or a float. It should be.")

# Define the pipeline with standardization, feature selection, and the model
pipe = Pipeline(steps=[
    ('standardization', standardScaler),
    ('feature selection', featureSelection),
    ('model', xgb.XGBRegressor(objective='reg:squarederror', eval_metric='rmse'))
])

# Define the objective function for Optuna
def objective(trial):
    # Define the hyperparameter search space
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    
    # Update the pipeline model with the hyperparameters from Optuna trial
    pipe.set_params(model__n_estimators=param['n_estimators'],
                    model__max_depth=param['max_depth'],
                    model__learning_rate=param['learning_rate'],
                    model__subsample=param['subsample'],
                    model__colsample_bytree=param['colsample_bytree'],
                    model__gamma=param['gamma'],
                    model__min_child_weight=param['min_child_weight'],
                    model__reg_alpha=param['reg_alpha'],
                    model__reg_lambda=param['reg_lambda'])

    # Train the model on the training data
    pipe.fit(X_train, y_train)

    # Make predictions
    y_pred = pipe.predict(X_test)
    
    # Evaluation metrics
    mae = mean_absolute_error(y_test_flat, y_pred)
    r2 = r2_score(y_test_flat, y_pred)
    
    # Pearson's Correlation Coefficient (R)
    correlation_matrix = np.corrcoef(y_test_flat, y_pred)
    correlation = correlation_matrix[0, 1]
    
    # Symmetric Mean Absolute Percentage Error (SMAPE)
    def smape(y_true, y_pred):
        denominator = np.abs(y_true) + np.abs(y_pred)
        diff = np.abs(y_true - y_pred) / denominator
        diff[denominator == 0] = 0.0  # Handle the case where both true and predicted values are zero
        return 100 * np.mean(diff)
    
    smape_value = smape(y_test_flat, y_pred)
    
    # Composite objective: maximize R² and correlation, minimize MAE and SMAPE
    # We subtract MAE and SMAPE to minimize them and add R² and correlation to maximize them
    
    
    # Return the objective value to Optuna
    return mae

# Create a study object and optimize the objective function
study = optuna.create_study(direction='minimize')  # Maximize the combined objective
study.optimize(objective, n_trials=100)  # Perform 100 trials

# Get the best hyperparameters found by Optuna
best_params = study.best_params
print(f"Best hyperparameters: {best_params}")

# Train the final model with the best hyperparameters
pipe.set_params(model__n_estimators=best_params['n_estimators'],
                model__max_depth=best_params['max_depth'],
                model__learning_rate=best_params['learning_rate'],
                model__subsample=best_params['subsample'],
                model__colsample_bytree=best_params['colsample_bytree'],
                model__gamma=best_params['gamma'],
                model__min_child_weight=best_params['min_child_weight'],
                model__reg_alpha=best_params['reg_alpha'],
                model__reg_lambda=best_params['reg_lambda'])

pipe.fit(X_train, y_train)

# Make predictions and evaluate the model
y_pred = pipe.predict(X_test)

# Print evaluation metrics
mae = mean_absolute_error(y_test_flat, y_pred)
r2 = r2_score(y_test_flat, y_pred)
correlation_matrix = np.corrcoef(y_test_flat, y_pred)
correlation = correlation_matrix[0, 1]
smape_value = smape(y_test_flat, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'R² (Coefficient of Determination): {r2}')
print(f'Pearson\'s Correlation Coefficient (R): {correlation}')
print(f'Symmetric Mean Absolute Percentage Error (SMAPE): {smape_value}')
# Out:
# [I 2025-04-03 22:36:25,465] A new study created in memory with name: no-name-5dba9c3c-4db1-4a13-b0c4-06dfafe4f3a8
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:25,580] Trial 0 finished with value: 0.15413169976466357 and parameters: {'n_estimators': 245, 'max_depth': 10, 'learning_rate': 0.16763957833610274, 'subsample': 0.5531057338998076, 'colsample_bytree': 0.6586386696979929, 'gamma': 0.35195994475011966, 'min_child_weight': 2, 'reg_alpha': 0.13236499479141295, 'reg_lambda': 0.6886537692754886}. Best is trial 0 with value: 0.15413169976466357.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:25,652] Trial 1 finished with value: 0.1541129493706149 and parameters: {'n_estimators': 160, 'max_depth': 5, 'learning_rate': 0.010279971759814285, 'subsample': 0.8866658181332683, 'colsample_bytree': 0.808071592333685, 'gamma': 0.4965887848035247, 'min_child_weight': 1, 'reg_alpha': 0.4926588161854525, 'reg_lambda': 0.7257341071640063}. Best is trial 1 with value: 0.1541129493706149.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:25,813] Trial 2 finished with value: 0.15436447313104945 and parameters: {'n_estimators': 275, 'max_depth': 6, 'learning_rate': 0.06732597110334594, 'subsample': 0.685221361886785, 'colsample_bytree': 0.9629856183450914, 'gamma': 0.13670893085695762, 'min_child_weight': 1, 'reg_alpha': 0.5865809208042684, 'reg_lambda': 0.4620621162838834}. Best is trial 1 with value: 0.1541129493706149.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:25,856] Trial 3 finished with value: 0.15412442906939314 and parameters: {'n_estimators': 76, 'max_depth': 4, 'learning_rate': 0.05270947156702352, 'subsample': 0.8631157422276641, 'colsample_bytree': 0.9105368054611636, 'gamma': 0.18466756263210227, 'min_child_weight': 1, 'reg_alpha': 0.3569276432181864, 'reg_lambda': 0.8645074483865388}. Best is trial 1 with value: 0.1541129493706149.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:25,984] Trial 4 finished with value: 0.15414371654503944 and parameters: {'n_estimators': 297, 'max_depth': 7, 'learning_rate': 0.19291220182021285, 'subsample': 0.5794601619720898, 'colsample_bytree': 0.9260036340951061, 'gamma': 0.4155912240877326, 'min_child_weight': 3, 'reg_alpha': 0.8672865244271712, 'reg_lambda': 0.4045904654445721}. Best is trial 1 with value: 0.1541129493706149.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:26,038] Trial 5 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 98, 'max_depth': 3, 'learning_rate': 0.19644350562005464, 'subsample': 0.6483233381560835, 'colsample_bytree': 0.7898611164943035, 'gamma': 0.402610445657326, 'min_child_weight': 2, 'reg_alpha': 0.7050438891405947, 'reg_lambda': 0.7099944034232107}. Best is trial 5 with value: 0.15411248004070546.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:26,164] Trial 6 finished with value: 0.1540931535834381 and parameters: {'n_estimators': 263, 'max_depth': 5, 'learning_rate': 0.13644924075270742, 'subsample': 0.6447095863856793, 'colsample_bytree': 0.7636644700110189, 'gamma': 0.3529064034891619, 'min_child_weight': 2, 'reg_alpha': 0.024185243271107715, 'reg_lambda': 0.24720214444048272}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:26,307] Trial 7 finished with value: 0.15497271800026283 and parameters: {'n_estimators': 261, 'max_depth': 3, 'learning_rate': 0.13748975594441668, 'subsample': 0.699495624689817, 'colsample_bytree': 0.8430407668491058, 'gamma': 0.08648791527014771, 'min_child_weight': 4, 'reg_alpha': 0.4846552633711867, 'reg_lambda': 0.7383445427597247}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:26,554] Trial 8 finished with value: 0.15468726001039648 and parameters: {'n_estimators': 291, 'max_depth': 8, 'learning_rate': 0.05282294394522253, 'subsample': 0.791256479080676, 'colsample_bytree': 0.9889871994920847, 'gamma': 0.07546061376552704, 'min_child_weight': 1, 'reg_alpha': 0.275423682225467, 'reg_lambda': 0.24184062715486232}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:26,675] Trial 9 finished with value: 0.15419728428797566 and parameters: {'n_estimators': 258, 'max_depth': 4, 'learning_rate': 0.16214441216973072, 'subsample': 0.7630137821396243, 'colsample_bytree': 0.5297681165918187, 'gamma': 0.19875050122785398, 'min_child_weight': 6, 'reg_alpha': 0.003973717014508105, 'reg_lambda': 0.19890280375146796}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:26,794] Trial 10 finished with value: 0.1541129647409281 and parameters: {'n_estimators': 209, 'max_depth': 9, 'learning_rate': 0.11257504620686072, 'subsample': 0.9777468490545824, 'colsample_bytree': 0.6819255237507528, 'gamma': 0.3220043309867838, 'min_child_weight': 9, 'reg_alpha': 0.004971654504275103, 'reg_lambda': 0.054930129593401156}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:26,862] Trial 11 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 95, 'max_depth': 3, 'learning_rate': 0.1958432243766391, 'subsample': 0.6279530575445018, 'colsample_bytree': 0.7135498748855428, 'gamma': 0.2944034740662532, 'min_child_weight': 5, 'reg_alpha': 0.807997738675295, 'reg_lambda': 0.960613374321194}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:26,944] Trial 12 finished with value: 0.15411377609543495 and parameters: {'n_estimators': 130, 'max_depth': 5, 'learning_rate': 0.11992700648707487, 'subsample': 0.5189611667925449, 'colsample_bytree': 0.7852341652125786, 'gamma': 0.4174328406447529, 'min_child_weight': 6, 'reg_alpha': 0.6723219810993949, 'reg_lambda': 0.5609630775660246}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:27,045] Trial 13 finished with value: 0.15411251650618085 and parameters: {'n_estimators': 186, 'max_depth': 5, 'learning_rate': 0.15484047159707015, 'subsample': 0.65196611443746, 'colsample_bytree': 0.6020475632634541, 'gamma': 0.40260209621104576, 'min_child_weight': 8, 'reg_alpha': 0.9759709556974945, 'reg_lambda': 0.2869755120118357}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:27,153] Trial 14 finished with value: 0.15411373052066907 and parameters: {'n_estimators': 121, 'max_depth': 3, 'learning_rate': 0.085612161270259, 'subsample': 0.6071442547547425, 'colsample_bytree': 0.8503338196050554, 'gamma': 0.4827669498895768, 'min_child_weight': 3, 'reg_alpha': 0.7041062441552475, 'reg_lambda': 0.5913590973975}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:27,197] Trial 15 finished with value: 0.1541108282760153 and parameters: {'n_estimators': 53, 'max_depth': 6, 'learning_rate': 0.17866589810432915, 'subsample': 0.7000623316661975, 'colsample_bytree': 0.7406494483350806, 'gamma': 0.2502482063075834, 'min_child_weight': 3, 'reg_alpha': 0.29622706860925174, 'reg_lambda': 0.1042296600446451}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:27,308] Trial 16 finished with value: 0.15414454924193005 and parameters: {'n_estimators': 217, 'max_depth': 7, 'learning_rate': 0.13807498812818492, 'subsample': 0.7272723281165051, 'colsample_bytree': 0.7277126917038682, 'gamma': 0.24813124984720403, 'min_child_weight': 4, 'reg_alpha': 0.23865792518527967, 'reg_lambda': 0.0062165411445975205}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:27,351] Trial 17 finished with value: 0.15410674275853725 and parameters: {'n_estimators': 53, 'max_depth': 6, 'learning_rate': 0.17351029550014033, 'subsample': 0.8095560804329642, 'colsample_bytree': 0.6019094536700069, 'gamma': 0.25877041226784553, 'min_child_weight': 3, 'reg_alpha': 0.14963226545041147, 'reg_lambda': 0.1327826943938628}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:27,784] Trial 18 finished with value: 0.15860503286269356 and parameters: {'n_estimators': 160, 'max_depth': 8, 'learning_rate': 0.1374004353789036, 'subsample': 0.8226773796519111, 'colsample_bytree': 0.5156551700933089, 'gamma': 0.0018607239096309347, 'min_child_weight': 7, 'reg_alpha': 0.14066902812346138, 'reg_lambda': 0.35150286559992416}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:27,892] Trial 19 finished with value: 0.1541097552944257 and parameters: {'n_estimators': 217, 'max_depth': 6, 'learning_rate': 0.09502909336504835, 'subsample': 0.9500926811023119, 'colsample_bytree': 0.6124319047040467, 'gamma': 0.2647203630661563, 'min_child_weight': 10, 'reg_alpha': 0.12830998991740264, 'reg_lambda': 0.16755972719355688}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:27,988] Trial 20 finished with value: 0.15411308055445078 and parameters: {'n_estimators': 185, 'max_depth': 4, 'learning_rate': 0.14988960973091534, 'subsample': 0.9104376082159811, 'colsample_bytree': 0.5893962944773375, 'gamma': 0.3488309848864565, 'min_child_weight': 4, 'reg_alpha': 0.41529251877172746, 'reg_lambda': 0.3208736226546241}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:28,100] Trial 21 finished with value: 0.1541128585785323 and parameters: {'n_estimators': 230, 'max_depth': 6, 'learning_rate': 0.09103743254782182, 'subsample': 0.9546620632943268, 'colsample_bytree': 0.616787684307976, 'gamma': 0.2886220538860581, 'min_child_weight': 10, 'reg_alpha': 0.134112887778772, 'reg_lambda': 0.1498478818753061}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:28,202] Trial 22 finished with value: 0.15411193627037828 and parameters: {'n_estimators': 198, 'max_depth': 7, 'learning_rate': 0.0984537619247621, 'subsample': 0.9353718122659658, 'colsample_bytree': 0.6576101443525098, 'gamma': 0.2271107141902909, 'min_child_weight': 10, 'reg_alpha': 0.07827416881634952, 'reg_lambda': 0.16799885326929875}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:28,293] Trial 23 finished with value: 0.15411307269056962 and parameters: {'n_estimators': 233, 'max_depth': 5, 'learning_rate': 0.12687960368014284, 'subsample': 0.9987630039866062, 'colsample_bytree': 0.5855734743161498, 'gamma': 0.27784156089236767, 'min_child_weight': 8, 'reg_alpha': 0.20879563488536537, 'reg_lambda': 0.08673945879119821}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:28,435] Trial 24 finished with value: 0.15418779827175405 and parameters: {'n_estimators': 271, 'max_depth': 6, 'learning_rate': 0.17689747632875383, 'subsample': 0.8346398647656723, 'colsample_bytree': 0.5604169042941496, 'gamma': 0.16057709504457346, 'min_child_weight': 5, 'reg_alpha': 0.07304424273702315, 'reg_lambda': 0.2504342300928636}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:28,501] Trial 25 finished with value: 0.15410854488226153 and parameters: {'n_estimators': 142, 'max_depth': 8, 'learning_rate': 0.11100927032025289, 'subsample': 0.7586590568336766, 'colsample_bytree': 0.6389915737737838, 'gamma': 0.34815469915592073, 'min_child_weight': 2, 'reg_alpha': 0.18770873873792412, 'reg_lambda': 0.0026086319751570664}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:28,544] Trial 26 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 52, 'max_depth': 8, 'learning_rate': 0.14866499022019797, 'subsample': 0.755447077302967, 'colsample_bytree': 0.6773845377405697, 'gamma': 0.36453830330062276, 'min_child_weight': 2, 'reg_alpha': 0.3366266975265757, 'reg_lambda': 0.0064020619207764695}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:28,622] Trial 27 finished with value: 0.15412601220517283 and parameters: {'n_estimators': 138, 'max_depth': 9, 'learning_rate': 0.10917893624716535, 'subsample': 0.8103857625664045, 'colsample_bytree': 0.6304513063688121, 'gamma': 0.32220294100327107, 'min_child_weight': 2, 'reg_alpha': 0.1808758845581371, 'reg_lambda': 0.09884631634742859}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:28,707] Trial 28 finished with value: 0.15411330873067905 and parameters: {'n_estimators': 157, 'max_depth': 9, 'learning_rate': 0.12547925862706485, 'subsample': 0.78088175995223, 'colsample_bytree': 0.7057062315903906, 'gamma': 0.4700202632890532, 'min_child_weight': 3, 'reg_alpha': 0.061723620921816574, 'reg_lambda': 0.006142485795406228}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:28,774] Trial 29 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 110, 'max_depth': 10, 'learning_rate': 0.07666733434858108, 'subsample': 0.7248343835521642, 'colsample_bytree': 0.6470736977456168, 'gamma': 0.3679516632004887, 'min_child_weight': 2, 'reg_alpha': 0.40422628484416107, 'reg_lambda': 0.39633984714507126}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:28,828] Trial 30 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 79, 'max_depth': 7, 'learning_rate': 0.17264789951130888, 'subsample': 0.5556510933884775, 'colsample_bytree': 0.5536028546514544, 'gamma': 0.4475408779528346, 'min_child_weight': 4, 'reg_alpha': 0.23610704748993305, 'reg_lambda': 0.22253057313676056}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:28,948] Trial 31 finished with value: 0.15412538711598212 and parameters: {'n_estimators': 244, 'max_depth': 6, 'learning_rate': 0.1120821503116464, 'subsample': 0.8796604999503769, 'colsample_bytree': 0.500264342154388, 'gamma': 0.3295030124415501, 'min_child_weight': 3, 'reg_alpha': 0.16178027817804752, 'reg_lambda': 0.1486902317635142}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,086] Trial 32 finished with value: 0.1541385599915102 and parameters: {'n_estimators': 223, 'max_depth': 5, 'learning_rate': 0.09704832644803563, 'subsample': 0.8564556932692249, 'colsample_bytree': 0.5602713795189069, 'gamma': 0.27235138917411245, 'min_child_weight': 1, 'reg_alpha': 0.07674859773545918, 'reg_lambda': 0.11929180114620935}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,179] Trial 33 finished with value: 0.15411365322229167 and parameters: {'n_estimators': 168, 'max_depth': 5, 'learning_rate': 0.011402733340368398, 'subsample': 0.9061582645074431, 'colsample_bytree': 0.7699562149931113, 'gamma': 0.23806817227997942, 'min_child_weight': 2, 'reg_alpha': 0.11171699451805411, 'reg_lambda': 0.06126844122341715}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,299] Trial 34 finished with value: 0.1541219742809167 and parameters: {'n_estimators': 244, 'max_depth': 6, 'learning_rate': 0.06356052906909945, 'subsample': 0.6715803492774871, 'colsample_bytree': 0.6788628209984472, 'gamma': 0.38131827123831635, 'min_child_weight': 1, 'reg_alpha': 0.013979084616861438, 'reg_lambda': 0.28546281514139693}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,384] Trial 35 finished with value: 0.1541140175180197 and parameters: {'n_estimators': 149, 'max_depth': 4, 'learning_rate': 0.033730348891977735, 'subsample': 0.5910588065340984, 'colsample_bytree': 0.6057536388115602, 'gamma': 0.3034366267480393, 'min_child_weight': 7, 'reg_alpha': 0.19069032860998963, 'reg_lambda': 0.45444215979677405}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,493] Trial 36 finished with value: 0.15420443169073123 and parameters: {'n_estimators': 202, 'max_depth': 7, 'learning_rate': 0.07954931459073336, 'subsample': 0.7364239485347125, 'colsample_bytree': 0.6430944971534414, 'gamma': 0.20368007700409058, 'min_child_weight': 2, 'reg_alpha': 0.3183349856507458, 'reg_lambda': 0.1853031971766574}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:29,631] Trial 37 finished with value: 0.1541135584982685 and parameters: {'n_estimators': 286, 'max_depth': 8, 'learning_rate': 0.18678898002339392, 'subsample': 0.7912989317710257, 'colsample_bytree': 0.832978535779892, 'gamma': 0.34965376636436923, 'min_child_weight': 5, 'reg_alpha': 0.3889184548567963, 'reg_lambda': 0.3653730419056779}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,699] Trial 38 finished with value: 0.15443844561910308 and parameters: {'n_estimators': 70, 'max_depth': 6, 'learning_rate': 0.15897965429614377, 'subsample': 0.5050109101278548, 'colsample_bytree': 0.8790781787694073, 'gamma': 0.16056783212555648, 'min_child_weight': 1, 'reg_alpha': 0.46650642813023824, 'reg_lambda': 0.04556182097274453}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:29,823] Trial 39 finished with value: 0.15411311704857555 and parameters: {'n_estimators': 257, 'max_depth': 7, 'learning_rate': 0.13986522579490934, 'subsample': 0.8540439201525502, 'colsample_bytree': 0.8123112811027646, 'gamma': 0.43381023010613606, 'min_child_weight': 3, 'reg_alpha': 0.24587048152317628, 'reg_lambda': 0.4601253604321087}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,921] Trial 40 finished with value: 0.1541928726642046 and parameters: {'n_estimators': 178, 'max_depth': 5, 'learning_rate': 0.10110802302955185, 'subsample': 0.698248189732785, 'colsample_bytree': 0.7657589608077416, 'gamma': 0.21797202021435108, 'min_child_weight': 9, 'reg_alpha': 0.5467674104856393, 'reg_lambda': 0.25716730882046085}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:29,976] Trial 41 finished with value: 0.1541241043389868 and parameters: {'n_estimators': 88, 'max_depth': 6, 'learning_rate': 0.1860268152701829, 'subsample': 0.6777843980510276, 'colsample_bytree': 0.755467895344604, 'gamma': 0.266067623474517, 'min_child_weight': 3, 'reg_alpha': 0.29286337049270234, 'reg_lambda': 0.12044308116999364}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,025] Trial 42 finished with value: 0.1541056132955004 and parameters: {'n_estimators': 59, 'max_depth': 6, 'learning_rate': 0.1700699036552908, 'subsample': 0.7090724286540715, 'colsample_bytree': 0.7418402565722916, 'gamma': 0.2514739583068579, 'min_child_weight': 4, 'reg_alpha': 0.10098294510328873, 'reg_lambda': 0.1978210296088772}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,073] Trial 43 finished with value: 0.15410593009790818 and parameters: {'n_estimators': 61, 'max_depth': 5, 'learning_rate': 0.1657649561282893, 'subsample': 0.6199456535169066, 'colsample_bytree': 0.707385187386412, 'gamma': 0.3073293310829918, 'min_child_weight': 4, 'reg_alpha': 0.04389487241832356, 'reg_lambda': 0.20630378083307782}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,121] Trial 44 finished with value: 0.15412769165681006 and parameters: {'n_estimators': 62, 'max_depth': 4, 'learning_rate': 0.16382689214676457, 'subsample': 0.6353878101451421, 'colsample_bytree': 0.6991548539320465, 'gamma': 0.3090830861501396, 'min_child_weight': 4, 'reg_alpha': 0.03604238193915503, 'reg_lambda': 0.21191255084709731}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,187] Trial 45 finished with value: 0.15413193114739474 and parameters: {'n_estimators': 108, 'max_depth': 4, 'learning_rate': 0.16621912321910123, 'subsample': 0.619541882456772, 'colsample_bytree': 0.795507344397361, 'gamma': 0.38766841448096157, 'min_child_weight': 4, 'reg_alpha': 0.10841539422037917, 'reg_lambda': 0.7691436371457833}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:30,236] Trial 46 finished with value: 0.15411258138320053 and parameters: {'n_estimators': 65, 'max_depth': 5, 'learning_rate': 0.18488731021095559, 'subsample': 0.6496961267639921, 'colsample_bytree': 0.7280275547836289, 'gamma': 0.3367893069693475, 'min_child_weight': 5, 'reg_alpha': 0.02902299483455243, 'reg_lambda': 0.5202639073218456}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,291] Trial 47 finished with value: 0.15412963270471716 and parameters: {'n_estimators': 77, 'max_depth': 5, 'learning_rate': 0.1995395092600677, 'subsample': 0.7692047916780788, 'colsample_bytree': 0.6905474090882396, 'gamma': 0.30358255368522646, 'min_child_weight': 3, 'reg_alpha': 0.169351701713503, 'reg_lambda': 0.32020294896424695}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,414] Trial 48 finished with value: 0.15485728628176582 and parameters: {'n_estimators': 86, 'max_depth': 7, 'learning_rate': 0.14526241485383223, 'subsample': 0.5758899031683844, 'colsample_bytree': 0.7315479121762297, 'gamma': 0.09095281753552453, 'min_child_weight': 4, 'reg_alpha': 0.09251045482156055, 'reg_lambda': 0.629740983087107}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,466] Trial 49 finished with value: 0.1542088256551789 and parameters: {'n_estimators': 59, 'max_depth': 10, 'learning_rate': 0.12929171407342796, 'subsample': 0.7045050471700242, 'colsample_bytree': 0.6652576831544503, 'gamma': 0.17336916002942906, 'min_child_weight': 1, 'reg_alpha': 0.010344560217262024, 'reg_lambda': 0.052357186383607784}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,540] Trial 50 finished with value: 0.1542206033912978 and parameters: {'n_estimators': 103, 'max_depth': 5, 'learning_rate': 0.17185880411869942, 'subsample': 0.6610191163864007, 'colsample_bytree': 0.9195678008233767, 'gamma': 0.202393549665608, 'min_child_weight': 2, 'reg_alpha': 0.04086416338990043, 'reg_lambda': 0.2055154896312781}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,613] Trial 51 finished with value: 0.15411869056337282 and parameters: {'n_estimators': 118, 'max_depth': 6, 'learning_rate': 0.11900114166368549, 'subsample': 0.6102162439691948, 'colsample_bytree': 0.631662554427815, 'gamma': 0.26137835978589125, 'min_child_weight': 5, 'reg_alpha': 0.129604812337885, 'reg_lambda': 0.16254090067601798}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,676] Trial 52 finished with value: 0.15412451576295164 and parameters: {'n_estimators': 94, 'max_depth': 6, 'learning_rate': 0.15780552148636418, 'subsample': 0.7126323018740127, 'colsample_bytree': 0.5802728697695546, 'gamma': 0.28559716605459246, 'min_child_weight': 6, 'reg_alpha': 0.12981178645604974, 'reg_lambda': 0.2853391646452445}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,821] Trial 53 finished with value: 0.1541507485638377 and parameters: {'n_estimators': 298, 'max_depth': 6, 'learning_rate': 0.15417012585620232, 'subsample': 0.7396427414837011, 'colsample_bytree': 0.711784804951681, 'gamma': 0.24631506697349753, 'min_child_weight': 3, 'reg_alpha': 0.22096033728373363, 'reg_lambda': 0.13857479028513808}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:30,875] Trial 54 finished with value: 0.15412480068149675 and parameters: {'n_estimators': 71, 'max_depth': 4, 'learning_rate': 0.1329266908526053, 'subsample': 0.6848692157589726, 'colsample_bytree': 0.6257900768677742, 'gamma': 0.2231033344759739, 'min_child_weight': 4, 'reg_alpha': 0.6254273587808019, 'reg_lambda': 0.0673936046592928}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:30,921] Trial 55 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 51, 'max_depth': 8, 'learning_rate': 0.08925411081156874, 'subsample': 0.5919801205216451, 'colsample_bytree': 0.7470642160020572, 'gamma': 0.3154730159441705, 'min_child_weight': 3, 'reg_alpha': 0.262119759730104, 'reg_lambda': 0.23110323872657182}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:31,056] Trial 56 finished with value: 0.15416641186485452 and parameters: {'n_estimators': 274, 'max_depth': 9, 'learning_rate': 0.17874693520703344, 'subsample': 0.6336391107484003, 'colsample_bytree': 0.6566782724606532, 'gamma': 0.337173799040635, 'min_child_weight': 9, 'reg_alpha': 0.1639744297606146, 'reg_lambda': 0.17950525055879946}. Best is trial 6 with value: 0.1540931535834381.
# ...
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:33,225] Trial 83 finished with value: 0.15410670696812498 and parameters: {'n_estimators': 66, 'max_depth': 7, 'learning_rate': 0.16114524117355036, 'subsample': 0.7657188067428142, 'colsample_bytree': 0.5533735647801551, 'gamma': 0.3797685524796316, 'min_child_weight': 1, 'reg_alpha': 0.0922667195727373, 'reg_lambda': 0.2434212146067456}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:33,276] Trial 84 finished with value: 0.15410658373753255 and parameters: {'n_estimators': 64, 'max_depth': 7, 'learning_rate': 0.16028309096655868, 'subsample': 0.7653301095860204, 'colsample_bytree': 0.5245475979775867, 'gamma': 0.3807586422287402, 'min_child_weight': 1, 'reg_alpha': 0.08084267798630246, 'reg_lambda': 0.24073164433833805}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:33,328] Trial 85 finished with value: 0.15410703567692502 and parameters: {'n_estimators': 65, 'max_depth': 7, 'learning_rate': 0.15983639378115727, 'subsample': 0.767222626614745, 'colsample_bytree': 0.5275957523274873, 'gamma': 0.3815224560007243, 'min_child_weight': 1, 'reg_alpha': 0.08760687946027287, 'reg_lambda': 0.24803173286698288}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,384] Trial 86 finished with value: 0.1541126215962292 and parameters: {'n_estimators': 77, 'max_depth': 7, 'learning_rate': 0.15168287577370987, 'subsample': 0.8179340425743953, 'colsample_bytree': 0.5051561564957783, 'gamma': 0.4185376729644482, 'min_child_weight': 1, 'reg_alpha': 0.026893488460095427, 'reg_lambda': 0.22625568578925123}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:33,446] Trial 87 finished with value: 0.15410640009885151 and parameters: {'n_estimators': 93, 'max_depth': 7, 'learning_rate': 0.16382342209959622, 'subsample': 0.7809752725398127, 'colsample_bytree': 0.543930212152656, 'gamma': 0.35780616412843913, 'min_child_weight': 1, 'reg_alpha': 0.06255678308083748, 'reg_lambda': 0.2911845517760154}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:33,508] Trial 88 finished with value: 0.1541059881833941 and parameters: {'n_estimators': 91, 'max_depth': 7, 'learning_rate': 0.1748672302529197, 'subsample': 0.7904623997284453, 'colsample_bytree': 0.5641004825446342, 'gamma': 0.3615264242723919, 'min_child_weight': 1, 'reg_alpha': 0.06521864938895741, 'reg_lambda': 0.3018289376412208}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:33,572] Trial 89 finished with value: 0.1541263902150774 and parameters: {'n_estimators': 93, 'max_depth': 7, 'learning_rate': 0.1646390864609685, 'subsample': 0.7812181951884993, 'colsample_bytree': 0.5491017714262869, 'gamma': 0.3582568502684043, 'min_child_weight': 1, 'reg_alpha': 0.0037501636323990645, 'reg_lambda': 0.30350214567355943}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,639] Trial 90 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 103, 'max_depth': 7, 'learning_rate': 0.13551115448703172, 'subsample': 0.7936043742283588, 'colsample_bytree': 0.5665714904056668, 'gamma': 0.3908161630342138, 'min_child_weight': 1, 'reg_alpha': 0.0580249062510508, 'reg_lambda': 0.35701265162335916}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,689] Trial 91 finished with value: 0.15411305696280728 and parameters: {'n_estimators': 57, 'max_depth': 7, 'learning_rate': 0.17118214312269098, 'subsample': 0.7754797730765489, 'colsample_bytree': 0.5372004867658119, 'gamma': 0.40829771848168767, 'min_child_weight': 1, 'reg_alpha': 0.07632336816639561, 'reg_lambda': 0.26069594458897377}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,745] Trial 92 finished with value: 0.15411265483252018 and parameters: {'n_estimators': 76, 'max_depth': 7, 'learning_rate': 0.17334944925553217, 'subsample': 0.7962421077444645, 'colsample_bytree': 0.5104853214809828, 'gamma': 0.4359088039546327, 'min_child_weight': 1, 'reg_alpha': 0.11567231161521234, 'reg_lambda': 0.27883069851238257}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,791] Trial 93 finished with value: 0.15411248004070546 and parameters: {'n_estimators': 50, 'max_depth': 8, 'learning_rate': 0.18039246247978954, 'subsample': 0.8053111254607345, 'colsample_bytree': 0.5235975235556066, 'gamma': 0.37936595437711484, 'min_child_weight': 1, 'reg_alpha': 0.04550223209883342, 'reg_lambda': 0.20228659592105988}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,844] Trial 94 finished with value: 0.15411272024571354 and parameters: {'n_estimators': 68, 'max_depth': 7, 'learning_rate': 0.15632491746757096, 'subsample': 0.846025322398152, 'colsample_bytree': 0.5404917510816752, 'gamma': 0.3730137288600559, 'min_child_weight': 1, 'reg_alpha': 0.14602178228357182, 'reg_lambda': 0.29933397557632385}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,903] Trial 95 finished with value: 0.15411248630988664 and parameters: {'n_estimators': 84, 'max_depth': 8, 'learning_rate': 0.17580750544721005, 'subsample': 0.8274258250794306, 'colsample_bytree': 0.5515505039810251, 'gamma': 0.3548181938585984, 'min_child_weight': 2, 'reg_alpha': 0.033341980519071, 'reg_lambda': 0.24594461711592716}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-04-03 22:36:33,988] Trial 96 finished with value: 0.1541128138973893 and parameters: {'n_estimators': 75, 'max_depth': 7, 'learning_rate': 0.16300292193287957, 'subsample': 0.8142991509759592, 'colsample_bytree': 0.5194981873009774, 'gamma': 0.3250991434293783, 'min_child_weight': 1, 'reg_alpha': 0.059917219150036755, 'reg_lambda': 0.4211426762004526}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:34,051] Trial 97 finished with value: 0.15410429768616948 and parameters: {'n_estimators': 91, 'max_depth': 7, 'learning_rate': 0.1827833803297637, 'subsample': 0.6408999596696602, 'colsample_bytree': 0.5681506130019288, 'gamma': 0.3074575690579797, 'min_child_weight': 2, 'reg_alpha': 0.10291536444186607, 'reg_lambda': 0.33802090888836045}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:34,117] Trial 98 finished with value: 0.1541377193079812 and parameters: {'n_estimators': 98, 'max_depth': 7, 'learning_rate': 0.18256491595007673, 'subsample': 0.6391013131876933, 'colsample_bytree': 0.5739360399590442, 'gamma': 0.34164139189448095, 'min_child_weight': 2, 'reg_alpha': 0.023739724428428297, 'reg_lambda': 0.38634922997416216}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2025-04-03 22:36:34,189] Trial 99 finished with value: 0.15412842594897203 and parameters: {'n_estimators': 114, 'max_depth': 8, 'learning_rate': 0.1499385721818374, 'subsample': 0.6159624939921932, 'colsample_bytree': 0.5564217728344275, 'gamma': 0.3139008472230907, 'min_child_weight': 1, 'reg_alpha': 0.11651416825617182, 'reg_lambda': 0.33760107762929825}. Best is trial 6 with value: 0.1540931535834381.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best hyperparameters: {'n_estimators': 263, 'max_depth': 5, 'learning_rate': 0.13644924075270742, 'subsample': 0.6447095863856793, 'colsample_bytree': 0.7636644700110189, 'gamma': 0.3529064034891619, 'min_child_weight': 2, 'reg_alpha': 0.024185243271107715, 'reg_lambda': 0.24720214444048272}
# Mean Absolute Error (MAE): 0.1540931535834381
# R² (Coefficient of Determination): -0.0004392810013831294
# Pearson's Correlation Coefficient (R): 0.03077864097840032
# Symmetric Mean Absolute Percentage Error (SMAPE): 4.80774240638755

# %%
target_yearDf=pd.read_csv('target_yearDf.csv')

# %%
print(len(target_yearDf))
# Out:
# 3

# %%
xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]

# the target to keep
yColumnsToKeep = ["yield"]

# get a dataframe containing the features and the targets
target_xDf = target_yearDf[xColumnsToKeep]


target_yDf = target_yearDf[yColumnsToKeep]

# %%
# Print values in the specified format
#print(f"Model: {aModelList[0][2]}")  # Model name
print(f"Test Data (x): \n{target_xDf.head()}")  # Test features
print(f"Test Data (y): \n{target_yDf.head()}")  # Test targets
#print(f"N: {N}")  # Number of iterations
print(f"Train Data (x): \n{target_xDf.head()}")  # Training features
print(f"Train Data (y): \n{target_yDf.head()}")  # Training targets
#print(f"Working Directory: {workingDir}")
#print(f"Number of Features: {numFeatures}")

# Assuming 'xgbModel' is trained earlier in the pipeline
#xgb_model = xgb.XGBRegressor()
#xgb_model.fit(target_xDf, target_yDf.values.ravel())  # Fit model with training data
y_pred = pipe.predict(target_xDf)  # Predict on test data

# Compute metrics
mae = mean_absolute_error(target_yDf, y_pred)
r_squared = r2_score(target_yDf, y_pred)
r_score = np.corrcoef(target_yDf.values.flatten(), y_pred)[0, 1]


print("\nPerformance Metrics:")
print(f"Avg MAE: {mae}")
print(f"Avg R squared: {r_squared}")

print(f"R Score (Correlation): {r_score:.4f}")

# Scatter plot of true yield vs predicted yield
plt.figure(figsize=(8, 6))
plt.scatter(target_yDf, y_pred, alpha=0.6, label="True vs Predicted")
plt.plot([target_yDf.min(), target_yDf.max()], [target_yDf.min(), target_yDf.max()], 'r--', lw=2, label="Perfect Fit")
plt.xlabel("True Yield (tons/acre)")
plt.ylabel("Predicted Yield (tons/acre)")
plt.title("Scatter Plot: True vs Predicted Yield")
plt.legend()
plt.grid()
plt.show()
# Out:
# Test Data (x):
#    radiation     rain  avg_max_temp  avg_min_temp
# 0  327504.91  3008.62       14.8351        4.5918
# 1  344365.89  3094.04       15.2594        4.9374
# 2  365104.62  3362.26       15.8666        5.5104
# Test Data (y):
#       yield
# 0  1.060588
# 1  0.447647
# 2  0.561176
# Train Data (x):
#    radiation     rain  avg_max_temp  avg_min_temp
# 0  327504.91  3008.62       14.8351        4.5918
# 1  344365.89  3094.04       15.2594        4.9374
# 2  365104.62  3362.26       15.8666        5.5104
# Train Data (y):
#       yield
# 0  1.060588
# 1  0.447647
# 2  0.561176
#
# Performance Metrics:
# Avg MAE: 0.3008701503276825
# Avg R squared: -0.36584794521331787
# R Score (Correlation): nan
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
all_yearsDf=pd.read_csv("all_years.csv")

# %%
m1,r2=actualTest(all_yearsDf, target_yearDf, target_xDf, target_yDf, pipe)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yield   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 03 Apr 2025   Prob (F-statistic):                nan
# Time:                        22:47:58   Log-Likelihood:               -0.28685
# No. Observations:                   3   AIC:                             2.574
# Df Residuals:                       2   BIC:                             1.672
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8107      0.221      3.664      0.067      -0.141       1.763
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.827
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.468
# Skew:                           0.612   Prob(JB):                        0.791
# Kurtosis:                       1.500   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# skt mape: 53.822%
# skt smape: 41.693%
# skt mae: 0.301
# skt mse: 0.097
# skt rmse: 0.311
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 3 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sktime/performance_metrics/forecasting/_classes.py:657: UserWarning: y_pred and y_true do not have the same column index. This may indicate incorrect objects passed to the metric. Indices of y_true will be used for y_pred.
#   warn(

# %%
def actualTest(all_yearsDf, target_yearDf, xTest, yTest, model):
    #print("Length of all_yearsDf----This is used for plotting graph ", len(all_yearsDf))
    #print("Length of final_yearDf-----This is used for adjusting the predicted values: ", len(final_yearDf))
    #print("Length of target_yearDf-------This is used for comparing predicted values to true values-----these are true values ", len(target_yearDf))
    #print("boost_xDf: ",len(boost_xDf))
    #print("boost_yDf: ", len(boost_yDf))
    #print("Length of xTest: ", len(xTest))
    #print("Length of yTest: ", len(yTest))
    #print("test results on our test data: ")
    #print(yTest)
    
    #model = model.fit(boost_xDf, boost_yDf, xgb_model=model.get_booster())
    # get predictions
    pred = model.predict(xTest)
    #trainPred = model.predict(xTrain)
    #print("Length of predictions are: ", len(pred))

    #adj_pred = []
    #for i in range(len(pred)):
    #    adj_pred.append(final_yearDf['yield'][i] + pred[i])
    #print('adjusted predictions: ')
    #print(adj_pred)
    #print("Predictions are: ")
    #print(pred)
    #print("Length of adjusted predictions: ", len(adj_pred))
    pred_Df = pd.DataFrame(pred)
    #print(adj_pred_Df)
    #adj_pred_Df=pd.DataFrame(pred)
    # find errors
    meanAbsoluteError = mean_absolute_error(target_yearDf['yield'], pred_Df)

#     plt.scatter(yTest, pred, label='Truth vs Prediction')
#     p1 = max(max(pred), max(yTest['Yield (tons/acre)']))
#     p2 = min(min(pred), min(yTest['Yield (tons/acre)']))
#     plt.plot([p1, p2], [p1, p2], color='k', label='Perfect Predictions')
#     plt.xlabel('True Yields')
#     plt.ylabel('Predicted Yields')
#     plt.legend()
    #print("Plotting--------")
    pred_ts = []
    len_tsDf = len(all_yearsDf)
    #print("len_tsDf----Length of all_yearsDf----", len_tsDf)
    for i in range(len_tsDf - len(pred), len_tsDf):
        pred_ts.append(i)
    #print("Length of pred_ts is: ", len(pred_ts))
    #print("This is the index calculated for plotting time-series graph: ", pred_ts)    
    pred_df = pd.DataFrame(pred, index = pred_ts, columns = ['yield'])
    #print("Lengths of all_yearsDf and Lengths of pred_Df are: ", len(all_yearsDf['yield']), len(pred_df))
    #print("Head and shape of pred_Df")
    #print(pred_df.head())  # Check structure
    #print(pred_df.shape)   # Compare with all_yearsDf
    #print(all_yearsDf.index)
    plot_series(pd.Series(all_yearsDf['yield']), pred_df, labels=["y", "y_pred"])


    #plt.figure(figsize=(10, 6))

    # Plot actual yield using its index
    #plt.plot(all_yearsDf.index, all_yearsDf['yield'], label="Actual Yield", linestyle="-", color="blue")

    # Plot predicted yield using its index (from pred_df)
    #plt.plot(pred_df.index, pred_df['yield'], label="Predicted Yield", linestyle="--", color="red")

    #plt.xlabel("Index")  # The x-axis will now be the index of each DataFrame
    #plt.ylabel("Yield")
    #plt.legend()
    #plt.title("Actual vs. Predicted Yield")
    #plt.show()

    # find the R values
    r = np.corrcoef(target_yearDf['yield'], pred)[0,1]
    
    # find the R^2 coefficient of determination
    # defining the variables
#     r2x = xTest.tolist()
#     r2y = yTest.tolist()

    # adding the constant term
    r2pred = sm.add_constant(pred)

    # performing the regression
    # and fitting the model
    yTargetYield = target_yearDf['yield']
    result = sm.OLS(yTargetYield, r2pred).fit()

    # printing the summary table
    print(result.summary())
    print('skt mape: ' + str(round(skt_mape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt smape: ' + str(round(skt_smape(yTargetYield, pred_Df) * 100, 3)) + '%')
    print('skt mae: ' + str(round(skt_mae(yTargetYield, pred_Df), 3)))
    print('skt mse: ' + str(round(skt_mse(yTargetYield, pred_Df), 3)))
    print('skt rmse: ' + str(round(math.sqrt(skt_mse(yTargetYield, pred_Df)), 3)) + '\n\n')
    
    #accuracy = accuracy_score(yTest, pred)
    
    return(meanAbsoluteError, r)
    

#     # add the errors and R Squared to average values
#     avgMAE += meanAbsoluteError
#     avgRSq += rSq

#     # check to see which metric should be optimized
#     if metricToOptimize == 'r2':
#         # check to see if any of these are the best values
#         if (rSq > bestRSq):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     elif metricToOptimize == 'mae':
#         # check to see if any of these are the best values
#         if (meanAbsoluteError < bestMAE):
#             bestMAE = meanAbsoluteError
#             bestModel = model
#             bestRSq = rSq

#     else:
#         raise ValueError("The input 'metricToOptimize' does not have a valid input. It must be 'r2' or 'mae'.")

# %%
import statistics
import datetime
#from sklearn.externals import joblib # save and load models
import joblib
import random
# data manipulation and exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import statsmodels.api as sm
import math

## machine learning stuff
# preprocessing
from sklearn import preprocessing
# feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile
from sklearn.feature_selection import f_regression
# pipeline
from sklearn.pipeline import Pipeline
# train/testing
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score
from sktime.utils.plotting import plot_series

# error calculations
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score, matthews_corrcoef
from sktime.performance_metrics.forecasting import MeanSquaredError, MeanAbsoluteError, MeanAbsolutePercentageError
# models
from sklearn.linear_model import LinearRegression # linear regression
from sklearn.linear_model import BayesianRidge #bayesisan ridge regression
from sklearn.svm import SVR  # support vector machines regression
from sklearn.gaussian_process import GaussianProcessRegressor # import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsRegressor # k-nearest neightbors for regression
from sklearn.neural_network import MLPRegressor # neural network for regression
from sklearn.tree import DecisionTreeRegressor # decision tree regressor
from sklearn.ensemble import RandomForestRegressor  # random forest regression
from sklearn.ensemble import AdaBoostRegressor # adaboost for regression
import xgboost as xgb

skt_mape = MeanAbsolutePercentageError(symmetric=False)
skt_smape = MeanAbsolutePercentageError(symmetric=True)
skt_mae = MeanAbsoluteError()
skt_mse = MeanSquaredError()
